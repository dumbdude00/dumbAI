# %%
#| default_exp diffusion

# %% [markdown]
# # [fail] Diffusion unet

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'

# %%
#| export
from miniai.imports import *

from einops import rearrange
from fastprogress import progress_bar

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
class GPUCUDAMissing(BaseException):
    pass
    
try:
    if torch.cuda.is_available():
        print('# of GPUs available = ', torch.cuda.device_count())
    else:
        raise GPUCUDAMissing
except:
    print("ERROR: GPU is missing")
# Out:
# # of GPUs available =  1

# %%
xl,yl = 'image','label'
name = "zh-plus/tiny-imagenet"
bs = 512
dsd = load_dataset(name)

# %%
dsd['train'] = dsd['train'].select(range(500))

# %%
dsd['valid'] = dsd['valid'].select(range(50))

# %%
class TinyHFDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hg_ds):
        self.ds = hg_ds
        # the 2 lines below must be done here because the execution of "ds['train']['image']" takes 18seconds
        # once it has executed, indexing it is very fast (5 milliseconds)
        self.image = hg_ds[xl]
        self.label = hg_ds[yl]
    def __len__(self): return self.ds.num_rows
    def __getitem__(self, i): return TF.to_tensor(self.image[i]), self.label[i]

# %%
tds = TinyHFDS(dsd['train'])

# %%
vds = TinyHFDS(dsd['valid'])

# %%
class TfmDS:
    def __init__(self, ds, tfmx=fc.noop, tfmy=fc.noop): self.ds,self.tfmx,self.tfmy = ds,tfmx,tfmy
    def __len__(self): return len(self.ds)
    def __getitem__(self, i):
        x,y = self.ds[i]
        return self.tfmx(x),self.tfmy(y)

# %%
def tfmx(x):
    try:
        if len(x.shape) == 3 and x.shape[0] == 3:
            pass
        else:
            x = torch.ones([3,1,1]) * x
        x = x-0.5
    except SomeException:
        print("ERROR: x doesn't have 3 channels")
    return x

# %%
def tfmy(y): 
    return y

# %%
tfm_tds = TfmDS(tds, tfmx, tfmy)
tfm_vds = TfmDS(vds, tfmx, tfmy)

# %%
def collate_fn(b):
    b = default_collate(b)
    return b

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_fn))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb.shape, yb.shape, xb.min(), xb.max()
# Out:
# (torch.Size([500, 3, 64, 64]),
#  torch.Size([500]),
#  tensor(-0.5000),
#  tensor(0.5000))

# %%
show_images(xb[:9]+0.5)

# %% [markdown]
# ### DDIM

# %%
#| export
def abar(t): return (t*math.pi/2).cos()**2
def inv_abar(x): return x.sqrt().acos()*2/math.pi

def noisify(x0):
    device = x0.device
    n = len(x0)
    t = torch.rand(n,).to(x0).clamp(0,0.999)
    ε = torch.randn(x0.shape, device=device)
    abar_t = abar(t).reshape(-1, 1, 1, 1).to(device)
    xt = abar_t.sqrt()*x0 + (1-abar_t).sqrt()*ε
    return (xt, t.to(device)), ε

def collate_ddpm(b): 
    b = default_collate(b)
    return noisify(b[0])
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=7)

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=7, collate_fn=collate_ddpm))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb[0].shape, xb[1].shape, yb.shape
# Out:
# (torch.Size([500, 3, 64, 64]), torch.Size([500]), torch.Size([500, 3, 64, 64]))

# %%
xb[0].min(), xb[0].max()
# Out:
# (tensor(-4.8398), tensor(5.1194))

# %%
show_images((xb[0][:9,:,:]+0.5).clamp(0,1))

# %% [markdown]
# ## Train

# %% [markdown]
# Based on Diffusers

# %%
#| export
def timestep_embedding(tsteps, emb_dim, max_period= 10000):
    exponent = -math.log(max_period) * torch.linspace(0, 1, emb_dim//2, device=tsteps.device)
    emb = tsteps[:,None].float() * exponent.exp()[None,:]
    emb = torch.cat([emb.sin(), emb.cos()], dim=-1)
    return F.pad(emb, (0,1,0,0)) if emb_dim%2==1 else emb

# %%
#| export
def pre_conv(ni, nf, ks=3, stride=1, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2, bias=bias))
    return layers

# %%
#| export
def upsample(nf): return nn.Sequential(nn.Upsample(scale_factor=2.), nn.Conv2d(nf, nf, 3, padding=1))

# %%
#| export
def lin(ni, nf, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Linear(ni, nf, bias=bias))
    return layers

# %%
# This version is giving poor results - use the cell below instead
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans):
        super().__init__()
        self.attn = nn.MultiheadAttention(ni, ni//attn_chans, batch_first=True)
        self.norm = nn.BatchNorm2d(ni)

    def forward(self, x):
        n,c,h,w = x.shape
        x = self.norm(x).view(n, c, -1).transpose(1, 2)
        x = self.attn(x, x, x, need_weights=False)[0]
        return x.transpose(1,2).reshape(n,c,h,w)

# %%
#| export
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans, transpose=True):
        super().__init__()
        self.nheads = ni//attn_chans
        self.scale = math.sqrt(ni/self.nheads)
        self.norm = nn.LayerNorm(ni)
        self.qkv = nn.Linear(ni, ni*3)
        self.proj = nn.Linear(ni, ni)
        self.t = transpose
    
    def forward(self, x):
        n,c,s = x.shape
        if self.t: x = x.transpose(1, 2)
        x = self.norm(x)
        x = self.qkv(x)
        x = rearrange(x, 'n s (h d) -> (n h) s d', h=self.nheads)
        q,k,v = torch.chunk(x, 3, dim=-1)
        s = (q@k.transpose(1,2))/self.scale
        x = s.softmax(dim=-1)@v
        x = rearrange(x, '(n h) s d -> n s (h d)', h=self.nheads)
        x = self.proj(x)
        if self.t: x = x.transpose(1, 2)
        return x

# %%
#| export
class SelfAttention2D(SelfAttention):
    def forward(self, x):
        n,c,h,w = x.shape
        return super().forward(x.view(n, c, -1)).reshape(n,c,h,w)

# %%
#| export
class EmbResBlock(nn.Module):
    def __init__(self, n_emb, ni, nf=None, ks=3, act=nn.SiLU, norm=nn.BatchNorm2d, attn_chans=0):
        super().__init__()
        if nf is None: nf = ni
        self.emb_proj = nn.Linear(n_emb, nf*2)
        self.conv1 = pre_conv(ni, nf, ks, act=None, norm=norm)
        self.conv2 = pre_conv(nf, nf, ks, act=act, norm=norm)
        self.idconv = fc.noop if ni==nf else nn.Conv2d(ni, nf, 1)
        self.attn = False
        if attn_chans: self.attn = SelfAttention2D(nf, attn_chans)

    def forward(self, x, t):
        inp = x
        x = self.conv1(x)
        emb = self.emb_proj(F.silu(t))[:, :, None, None]
        scale,shift = torch.chunk(emb, 2, dim=1)
        x = x*(1+scale) + shift
        x = self.conv2(x)
        x = x + self.idconv(inp)
        if self.attn: x = x + self.attn(x)
        return x

# %%
#| export
def saved(m, blk):
    m_ = m.forward

    @wraps(m.forward)
    def _f(*args, **kwargs):
        res = m_(*args, **kwargs)
        blk.saved.append(res)
        return res

    m.forward = _f
    return m

# %%
#| export
class DownBlock(nn.Module):
    def __init__(self, n_emb, ni, nf, add_down=True, num_layers=1, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList([saved(EmbResBlock(n_emb, ni if i==0 else nf, nf, attn_chans=attn_chans), self)
                                      for i in range(num_layers)])
        self.down = saved(nn.Conv2d(nf, nf, 3, stride=2, padding=1), self) if add_down else nn.Identity()

    def forward(self, x, t):
        self.saved = []
        for resnet in self.resnets: x = resnet(x, t)
        x = self.down(x)
        return x

# %%
#| export
class UpBlock(nn.Module):
    def __init__(self, n_emb, ni, prev_nf, nf, add_up=True, num_layers=2, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList(
            [EmbResBlock(n_emb, (prev_nf if i==0 else nf)+(ni if (i==num_layers-1) else nf), nf, attn_chans=attn_chans)
            for i in range(num_layers)])
        self.up = upsample(nf) if add_up else nn.Identity()

    def forward(self, x, t, ups):
        for resnet in self.resnets: x = resnet(torch.cat([x, ups.pop()], dim=1), t)
        return self.up(x)

# %%
class LearnEmbSS(nn.Module):
    def __init__(self, sz, ni):
        super().__init__()
        self.scale = nn.Parameter(torch.zeros(sz, ni))
        self.shift = nn.Parameter(torch.zeros(sz, ni))

    def forward(self, x): return x*self.scale + self.shift

# %%
def _mlp(ni, nh):
    return nn.Sequential(nn.Linear(ni,nh), nn.GELU(), nn.LayerNorm(nh), nn.Linear(nh,ni))

# %%
class EmbTransformerBlk(nn.Module):
    def __init__(self, n_emb, ni, attn_chans=8):
        super().__init__()
        self.attn = SelfAttention(ni, attn_chans=attn_chans, transpose=False)
        self.mlp = _mlp(ni, ni*4)
        self.nrm1 = nn.LayerNorm(ni)
        self.nrm2 = nn.LayerNorm(ni)
        self.emb_proj = nn.Linear(n_emb, ni*2)

    def forward(self, x, t):
        emb = self.emb_proj(F.silu(t))[:, None]
        scale,shift = torch.chunk(emb, 2, dim=2)
        x = x + self.attn(self.nrm1(x))
        x = x*(1+scale) + shift
        return x + self.mlp(self.nrm2(x))

# %%
img_vec_len = 16
class SimpleDiffusion(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, nfs=(224,448,672,896), num_layers=1,
                 attn_chans=8, attn_start=1, n_mids=8):
        super().__init__()
        self.conv_in = nn.Conv2d(in_channels, nfs[0], kernel_size=3, padding=1)
        self.n_temb = nf = nfs[0]
        n_emb = nf*4
        self.emb_mlp = nn.Sequential(lin(self.n_temb, n_emb, norm=nn.BatchNorm1d),
                                     lin(n_emb, n_emb))
        self.downs = nn.ModuleList()
        n = len(nfs)
        for i in range(n):
            ni = nf
            nf = nfs[i]
            self.downs.append(DownBlock(n_emb, ni, nf, add_down=i!=n-1, num_layers=num_layers,
                                        attn_chans=0 if i<attn_start else attn_chans))

        self.le = LearnEmbSS(img_vec_len, nf)
        self.mids = nn.ModuleList([EmbTransformerBlk(n_emb, nf) for _ in range(n_mids)])

        rev_nfs = list(reversed(nfs))
        nf = rev_nfs[0]
        self.ups = nn.ModuleList()
        for i in range(n):
            prev_nf = nf
            nf = rev_nfs[i]
            ni = rev_nfs[min(i+1, len(nfs)-1)]
            self.ups.append(UpBlock(n_emb, ni, prev_nf, nf, add_up=i!=n-1, num_layers=num_layers+1,
                                    attn_chans=0 if i>=n-attn_start else attn_chans))
        self.conv_out = pre_conv(nfs[0], out_channels, act=nn.SiLU, norm=nn.BatchNorm2d, bias=False)

    def forward(self, inp):
        x,t = inp
        temb = timestep_embedding(t, self.n_temb)
        emb = self.emb_mlp(temb)
        x = self.conv_in(x)
        saved = [x]
        for block in self.downs: x = block(x, emb)
        saved += [p for o in self.downs for p in o.saved]
        n,c,h,w = x.shape
        x = self.le(x.reshape(n,c,-1).transpose(1,2))
        for block in self.mids: x = block(x, emb)
        x = x.transpose(1,2).reshape(n,c,h,w)
        for block in self.ups: x = block(x, emb, saved)
        return self.conv_out(x)

# %%
#| export
def ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp=True):
    sig = ((bbar_t1/bbar_t).sqrt() * (1-abar_t/abar_t1).sqrt()) * eta
    x_0_hat = ((x_t-(1-abar_t).sqrt()*noise) / abar_t.sqrt())
    if clamp: x_0_hat = x_0_hat.clamp(-1,1)
    if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
    x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
    x_t += sig * torch.randn(x_t.shape).to(x_t)
    return x_0_hat,x_t

# %%
#| export
@torch.no_grad()
def sample(f, model, sz, steps, eta=1., clamp=True, progress=False):
    model.eval()
    ts = torch.linspace(1-1/steps,0,steps)
    x_t = torch.randn(sz).cuda()
    preds = []
    tbe = progress_bar(ts) if progress else ts 
    for i,t in enumerate(tbe):
        t = t[None].cuda()
        abar_t = abar(t)
        noise = model((x_t, t))
        abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
        x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
        preds.append(x_0_hat.float().cpu())
    return preds

# %%
import wandb

class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project='ddpm_goldfish_64x64', **metrics):
        fc.store_attr()
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d):
        #import pdb; pdb.set_trace()
        if learn.model.training: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
            wandb.log({'samples':self.sample_figure(learn)})
        print(d)

        
    def sample_figure(self, learn):
        with torch.no_grad():
            samples = sample(ddim_step, model, (16, 3, 64, 64), steps=100, eta=1.)
        s = (samples[-1]+0.5).clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16, imsize=3)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME'] = '08_diffusion-attn-cond_tin_goldfish_64x64_i3.ipynb'
lr = 1e-3
epochs = 700
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
#model = EmbUNetModel(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2)
model = SimpleDiffusion(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2, attn_chans=4, attn_start=3, n_mids=8)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# wandb: Currently logged in as: dumbdude (dumbdude-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_003211-rlqlctkm</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/rlqlctkm' target="_blank">lunar-rain-18</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/rlqlctkm' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/rlqlctkm</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'loss': '1.128', 'epoch': 0, 'train': 'train'}
# {'loss': '1.002', 'epoch': 0, 'train': 'eval'}
# {'loss': '1.111', 'epoch': 1, 'train': 'train'}
# {'loss': '1.000', 'epoch': 1, 'train': 'eval'}
# {'loss': '1.096', 'epoch': 2, 'train': 'train'}
# {'loss': '1.005', 'epoch': 2, 'train': 'eval'}
# {'loss': '1.083', 'epoch': 3, 'train': 'train'}
# {'loss': '0.999', 'epoch': 3, 'train': 'eval'}
# {'loss': '1.069', 'epoch': 4, 'train': 'train'}
# {'loss': '0.999', 'epoch': 4, 'train': 'eval'}
# {'loss': '1.053', 'epoch': 5, 'train': 'train'}
# {'loss': '0.999', 'epoch': 5, 'train': 'eval'}
# {'loss': '1.039', 'epoch': 6, 'train': 'train'}
# {'loss': '0.996', 'epoch': 6, 'train': 'eval'}
# {'loss': '1.023', 'epoch': 7, 'train': 'train'}
# {'loss': '0.997', 'epoch': 7, 'train': 'eval'}
# {'loss': '1.009', 'epoch': 8, 'train': 'train'}
# {'loss': '0.990', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.994', 'epoch': 9, 'train': 'train'}
# {'loss': '0.990', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.980', 'epoch': 10, 'train': 'train'}
# {'loss': '0.988', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.963', 'epoch': 11, 'train': 'train'}
# {'loss': '0.979', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.950', 'epoch': 12, 'train': 'train'}
# {'loss': '0.982', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.933', 'epoch': 13, 'train': 'train'}
# {'loss': '0.975', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.918', 'epoch': 14, 'train': 'train'}
# {'loss': '0.967', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.902', 'epoch': 15, 'train': 'train'}
# {'loss': '0.958', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.887', 'epoch': 16, 'train': 'train'}
# {'loss': '0.959', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.872', 'epoch': 17, 'train': 'train'}
# {'loss': '0.949', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.855', 'epoch': 18, 'train': 'train'}
# {'loss': '0.943', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.837', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.926', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.822', 'epoch': 20, 'train': 'train'}
# {'loss': '0.925', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.803', 'epoch': 21, 'train': 'train'}
# {'loss': '0.911', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.784', 'epoch': 22, 'train': 'train'}
# {'loss': '0.899', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.769', 'epoch': 23, 'train': 'train'}
# {'loss': '0.873', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.751', 'epoch': 24, 'train': 'train'}
# {'loss': '0.878', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.734', 'epoch': 25, 'train': 'train'}
# {'loss': '0.844', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.713', 'epoch': 26, 'train': 'train'}
# {'loss': '0.852', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.696', 'epoch': 27, 'train': 'train'}
# {'loss': '0.815', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.681', 'epoch': 28, 'train': 'train'}
# {'loss': '0.794', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.663', 'epoch': 29, 'train': 'train'}
# {'loss': '0.740', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.643', 'epoch': 30, 'train': 'train'}
# {'loss': '0.736', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.629', 'epoch': 31, 'train': 'train'}
# {'loss': '0.736', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.608', 'epoch': 32, 'train': 'train'}
# {'loss': '0.659', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.590', 'epoch': 33, 'train': 'train'}
# {'loss': '0.674', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.576', 'epoch': 34, 'train': 'train'}
# {'loss': '0.676', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.556', 'epoch': 35, 'train': 'train'}
# {'loss': '0.619', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.537', 'epoch': 36, 'train': 'train'}
# {'loss': '0.575', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.530', 'epoch': 37, 'train': 'train'}
# {'loss': '0.564', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.508', 'epoch': 38, 'train': 'train'}
# {'loss': '0.550', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.487', 'epoch': 39, 'train': 'train'}
# {'loss': '0.604', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.488', 'epoch': 40, 'train': 'train'}
# {'loss': '0.495', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 41, 'train': 'train'}
# {'loss': '0.460', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 42, 'train': 'train'}
# {'loss': '0.447', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 43, 'train': 'train'}
# {'loss': '0.430', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 44, 'train': 'train'}
# {'loss': '0.454', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.397', 'epoch': 45, 'train': 'train'}
# {'loss': '0.416', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 46, 'train': 'train'}
# {'loss': '0.417', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 47, 'train': 'train'}
# {'loss': '0.425', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 48, 'train': 'train'}
# {'loss': '0.329', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 49, 'train': 'train'}
# {'loss': '0.425', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 50, 'train': 'train'}
# {'loss': '0.330', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 51, 'train': 'train'}
# {'loss': '0.297', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 52, 'train': 'train'}
# {'loss': '0.248', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 53, 'train': 'train'}
# {'loss': '0.289', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.303', 'epoch': 54, 'train': 'train'}
# {'loss': '0.370', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.289', 'epoch': 55, 'train': 'train'}
# {'loss': '0.260', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.288', 'epoch': 56, 'train': 'train'}
# {'loss': '0.274', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.280', 'epoch': 57, 'train': 'train'}
# {'loss': '0.309', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.267', 'epoch': 58, 'train': 'train'}
# {'loss': '0.281', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.258', 'epoch': 59, 'train': 'train'}
# {'loss': '0.315', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.263', 'epoch': 60, 'train': 'train'}
# {'loss': '0.313', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.247', 'epoch': 61, 'train': 'train'}
# {'loss': '0.280', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.241', 'epoch': 62, 'train': 'train'}
# {'loss': '0.260', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.233', 'epoch': 63, 'train': 'train'}
# {'loss': '0.253', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.226', 'epoch': 64, 'train': 'train'}
# {'loss': '0.287', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.227', 'epoch': 65, 'train': 'train'}
# {'loss': '0.209', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.213', 'epoch': 66, 'train': 'train'}
# {'loss': '0.209', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.201', 'epoch': 67, 'train': 'train'}
# {'loss': '0.260', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.197', 'epoch': 68, 'train': 'train'}
# {'loss': '0.192', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.200', 'epoch': 69, 'train': 'train'}
# {'loss': '0.227', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.204', 'epoch': 70, 'train': 'train'}
# {'loss': '0.304', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.185', 'epoch': 71, 'train': 'train'}
# {'loss': '0.238', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.181', 'epoch': 72, 'train': 'train'}
# {'loss': '0.178', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.181', 'epoch': 73, 'train': 'train'}
# {'loss': '0.202', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.165', 'epoch': 74, 'train': 'train'}
# {'loss': '0.174', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.165', 'epoch': 75, 'train': 'train'}
# {'loss': '0.196', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.162', 'epoch': 76, 'train': 'train'}
# {'loss': '0.236', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.171', 'epoch': 77, 'train': 'train'}
# {'loss': '0.171', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.176', 'epoch': 78, 'train': 'train'}
# {'loss': '0.239', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.175', 'epoch': 79, 'train': 'train'}
# {'loss': '0.219', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.156', 'epoch': 80, 'train': 'train'}
# {'loss': '0.146', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.168', 'epoch': 81, 'train': 'train'}
# {'loss': '0.203', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.151', 'epoch': 82, 'train': 'train'}
# {'loss': '0.186', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.159', 'epoch': 83, 'train': 'train'}
# {'loss': '0.183', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.143', 'epoch': 84, 'train': 'train'}
# {'loss': '0.189', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.131', 'epoch': 85, 'train': 'train'}
# {'loss': '0.202', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.129', 'epoch': 86, 'train': 'train'}
# {'loss': '0.185', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.134', 'epoch': 87, 'train': 'train'}
# {'loss': '0.180', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.143', 'epoch': 88, 'train': 'train'}
# {'loss': '0.183', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.129', 'epoch': 89, 'train': 'train'}
# {'loss': '0.141', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.139', 'epoch': 90, 'train': 'train'}
# {'loss': '0.130', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.131', 'epoch': 91, 'train': 'train'}
# {'loss': '0.182', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.134', 'epoch': 92, 'train': 'train'}
# {'loss': '0.209', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.124', 'epoch': 93, 'train': 'train'}
# {'loss': '0.116', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.125', 'epoch': 94, 'train': 'train'}
# {'loss': '0.149', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.145', 'epoch': 95, 'train': 'train'}
# {'loss': '0.167', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.116', 'epoch': 96, 'train': 'train'}
# {'loss': '0.171', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.140', 'epoch': 97, 'train': 'train'}
# {'loss': '0.117', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.118', 'epoch': 98, 'train': 'train'}
# {'loss': '0.153', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.115', 'epoch': 99, 'train': 'train'}
# {'loss': '0.148', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.136', 'epoch': 100, 'train': 'train'}
# {'loss': '0.210', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.116', 'epoch': 101, 'train': 'train'}
# {'loss': '0.252', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.117', 'epoch': 102, 'train': 'train'}
# {'loss': '0.129', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.122', 'epoch': 103, 'train': 'train'}
# {'loss': '0.104', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.108', 'epoch': 104, 'train': 'train'}
# {'loss': '0.172', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.102', 'epoch': 105, 'train': 'train'}
# {'loss': '0.148', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.114', 'epoch': 106, 'train': 'train'}
# {'loss': '0.120', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.109', 'epoch': 107, 'train': 'train'}
# {'loss': '0.150', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.116', 'epoch': 108, 'train': 'train'}
# {'loss': '0.150', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.116', 'epoch': 109, 'train': 'train'}
# {'loss': '0.147', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.108', 'epoch': 110, 'train': 'train'}
# {'loss': '0.117', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.090', 'epoch': 111, 'train': 'train'}
# {'loss': '0.137', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.098', 'epoch': 112, 'train': 'train'}
# {'loss': '0.129', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.092', 'epoch': 113, 'train': 'train'}
# {'loss': '0.138', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.103', 'epoch': 114, 'train': 'train'}
# {'loss': '0.109', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.109', 'epoch': 115, 'train': 'train'}
# {'loss': '0.174', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.092', 'epoch': 116, 'train': 'train'}
# {'loss': '0.124', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.096', 'epoch': 117, 'train': 'train'}
# {'loss': '0.111', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.109', 'epoch': 118, 'train': 'train'}
# {'loss': '0.103', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.104', 'epoch': 119, 'train': 'train'}
# {'loss': '0.131', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.097', 'epoch': 120, 'train': 'train'}
# {'loss': '0.186', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.116', 'epoch': 121, 'train': 'train'}
# {'loss': '0.130', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.103', 'epoch': 122, 'train': 'train'}
# {'loss': '0.096', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.105', 'epoch': 123, 'train': 'train'}
# {'loss': '0.108', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.091', 'epoch': 124, 'train': 'train'}
# {'loss': '0.144', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.101', 'epoch': 125, 'train': 'train'}
# {'loss': '0.099', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.087', 'epoch': 126, 'train': 'train'}
# {'loss': '0.150', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.089', 'epoch': 127, 'train': 'train'}
# {'loss': '0.095', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.083', 'epoch': 128, 'train': 'train'}
# {'loss': '0.110', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.082', 'epoch': 129, 'train': 'train'}
# {'loss': '0.077', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.082', 'epoch': 130, 'train': 'train'}
# {'loss': '0.095', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.078', 'epoch': 131, 'train': 'train'}
# {'loss': '0.102', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.090', 'epoch': 132, 'train': 'train'}
# {'loss': '0.101', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.091', 'epoch': 133, 'train': 'train'}
# {'loss': '0.087', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.084', 'epoch': 134, 'train': 'train'}
# {'loss': '0.104', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.093', 'epoch': 135, 'train': 'train'}
# {'loss': '0.085', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.094', 'epoch': 136, 'train': 'train'}
# {'loss': '0.144', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.085', 'epoch': 137, 'train': 'train'}
# {'loss': '0.063', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.099', 'epoch': 138, 'train': 'train'}
# {'loss': '0.161', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.094', 'epoch': 139, 'train': 'train'}
# {'loss': '0.071', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.088', 'epoch': 140, 'train': 'train'}
# {'loss': '0.090', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.086', 'epoch': 141, 'train': 'train'}
# {'loss': '0.122', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.099', 'epoch': 142, 'train': 'train'}
# {'loss': '0.133', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.082', 'epoch': 143, 'train': 'train'}
# {'loss': '0.105', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.090', 'epoch': 144, 'train': 'train'}
# {'loss': '0.133', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.090', 'epoch': 145, 'train': 'train'}
# {'loss': '0.084', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.082', 'epoch': 146, 'train': 'train'}
# {'loss': '0.144', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.086', 'epoch': 147, 'train': 'train'}
# {'loss': '0.110', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.081', 'epoch': 148, 'train': 'train'}
# {'loss': '0.104', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.091', 'epoch': 149, 'train': 'train'}
# {'loss': '0.152', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.080', 'epoch': 150, 'train': 'train'}
# {'loss': '0.071', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.083', 'epoch': 151, 'train': 'train'}
# {'loss': '0.105', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.088', 'epoch': 152, 'train': 'train'}
# {'loss': '0.129', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.091', 'epoch': 153, 'train': 'train'}
# {'loss': '0.123', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.092', 'epoch': 154, 'train': 'train'}
# {'loss': '0.095', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.086', 'epoch': 155, 'train': 'train'}
# {'loss': '0.152', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.092', 'epoch': 156, 'train': 'train'}
# {'loss': '0.115', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.079', 'epoch': 157, 'train': 'train'}
# {'loss': '0.091', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.082', 'epoch': 158, 'train': 'train'}
# {'loss': '0.121', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.081', 'epoch': 159, 'train': 'train'}
# {'loss': '0.119', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.078', 'epoch': 160, 'train': 'train'}
# {'loss': '0.116', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.076', 'epoch': 161, 'train': 'train'}
# {'loss': '0.106', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 162, 'train': 'train'}
# {'loss': '0.118', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.076', 'epoch': 163, 'train': 'train'}
# {'loss': '0.070', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 164, 'train': 'train'}
# {'loss': '0.076', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 165, 'train': 'train'}
# {'loss': '0.076', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.073', 'epoch': 166, 'train': 'train'}
# {'loss': '0.058', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 167, 'train': 'train'}
# {'loss': '0.098', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.073', 'epoch': 168, 'train': 'train'}
# {'loss': '0.105', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.076', 'epoch': 169, 'train': 'train'}
# {'loss': '0.095', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 170, 'train': 'train'}
# {'loss': '0.103', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 171, 'train': 'train'}
# {'loss': '0.073', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 172, 'train': 'train'}
# {'loss': '0.054', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 173, 'train': 'train'}
# {'loss': '0.105', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.074', 'epoch': 174, 'train': 'train'}
# {'loss': '0.065', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 175, 'train': 'train'}
# {'loss': '0.066', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 176, 'train': 'train'}
# {'loss': '0.070', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 177, 'train': 'train'}
# {'loss': '0.096', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.077', 'epoch': 178, 'train': 'train'}
# {'loss': '0.098', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 179, 'train': 'train'}
# {'loss': '0.087', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 180, 'train': 'train'}
# {'loss': '0.068', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 181, 'train': 'train'}
# {'loss': '0.082', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 182, 'train': 'train'}
# {'loss': '0.115', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.073', 'epoch': 183, 'train': 'train'}
# {'loss': '0.110', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 184, 'train': 'train'}
# {'loss': '0.070', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 185, 'train': 'train'}
# {'loss': '0.056', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.083', 'epoch': 186, 'train': 'train'}
# {'loss': '0.086', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 187, 'train': 'train'}
# {'loss': '0.132', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 188, 'train': 'train'}
# {'loss': '0.049', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 189, 'train': 'train'}
# {'loss': '0.101', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 190, 'train': 'train'}
# {'loss': '0.065', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 191, 'train': 'train'}
# {'loss': '0.071', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.083', 'epoch': 192, 'train': 'train'}
# {'loss': '0.107', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 193, 'train': 'train'}
# {'loss': '0.067', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 194, 'train': 'train'}
# {'loss': '0.067', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.074', 'epoch': 195, 'train': 'train'}
# {'loss': '0.064', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 196, 'train': 'train'}
# {'loss': '0.096', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 197, 'train': 'train'}
# {'loss': '0.056', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 198, 'train': 'train'}
# {'loss': '0.047', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 199, 'train': 'train'}
# {'loss': '0.040', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 200, 'train': 'train'}
# {'loss': '0.055', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 201, 'train': 'train'}
# {'loss': '0.091', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 202, 'train': 'train'}
# {'loss': '0.061', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 203, 'train': 'train'}
# {'loss': '0.089', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 204, 'train': 'train'}
# {'loss': '0.060', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 205, 'train': 'train'}
# {'loss': '0.041', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 206, 'train': 'train'}
# {'loss': '0.050', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 207, 'train': 'train'}
# {'loss': '0.063', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 208, 'train': 'train'}
# {'loss': '0.089', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 209, 'train': 'train'}
# {'loss': '0.070', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.074', 'epoch': 210, 'train': 'train'}
# {'loss': '0.096', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.076', 'epoch': 211, 'train': 'train'}
# {'loss': '0.047', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 212, 'train': 'train'}
# {'loss': '0.067', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 213, 'train': 'train'}
# {'loss': '0.043', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 214, 'train': 'train'}
# {'loss': '0.109', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 215, 'train': 'train'}
# {'loss': '0.074', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 216, 'train': 'train'}
# {'loss': '0.047', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.074', 'epoch': 217, 'train': 'train'}
# {'loss': '0.069', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 218, 'train': 'train'}
# {'loss': '0.065', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 219, 'train': 'train'}
# {'loss': '0.096', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 220, 'train': 'train'}
# {'loss': '0.124', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 221, 'train': 'train'}
# {'loss': '0.054', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 222, 'train': 'train'}
# {'loss': '0.064', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 223, 'train': 'train'}
# {'loss': '0.068', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 224, 'train': 'train'}
# {'loss': '0.060', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 225, 'train': 'train'}
# {'loss': '0.049', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 226, 'train': 'train'}
# {'loss': '0.056', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 227, 'train': 'train'}
# {'loss': '0.042', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 228, 'train': 'train'}
# {'loss': '0.043', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 229, 'train': 'train'}
# {'loss': '0.064', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 230, 'train': 'train'}
# {'loss': '0.034', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 231, 'train': 'train'}
# {'loss': '0.035', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.073', 'epoch': 232, 'train': 'train'}
# {'loss': '0.085', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 233, 'train': 'train'}
# {'loss': '0.073', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 234, 'train': 'train'}
# {'loss': '0.055', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 235, 'train': 'train'}
# {'loss': '0.050', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 236, 'train': 'train'}
# {'loss': '0.054', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 237, 'train': 'train'}
# {'loss': '0.053', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 238, 'train': 'train'}
# {'loss': '0.040', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 239, 'train': 'train'}
# {'loss': '0.084', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 240, 'train': 'train'}
# {'loss': '0.086', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 241, 'train': 'train'}
# {'loss': '0.108', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 242, 'train': 'train'}
# {'loss': '0.094', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 243, 'train': 'train'}
# {'loss': '0.063', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 244, 'train': 'train'}
# {'loss': '0.074', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 245, 'train': 'train'}
# {'loss': '0.090', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 246, 'train': 'train'}
# {'loss': '0.053', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 247, 'train': 'train'}
# {'loss': '0.064', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 248, 'train': 'train'}
# {'loss': '0.064', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 249, 'train': 'train'}
# {'loss': '0.072', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 250, 'train': 'train'}
# {'loss': '0.050', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 251, 'train': 'train'}
# {'loss': '0.050', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 252, 'train': 'train'}
# {'loss': '0.041', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 253, 'train': 'train'}
# {'loss': '0.048', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 254, 'train': 'train'}
# {'loss': '0.079', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 255, 'train': 'train'}
# {'loss': '0.078', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 256, 'train': 'train'}
# {'loss': '0.055', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 257, 'train': 'train'}
# {'loss': '0.079', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 258, 'train': 'train'}
# {'loss': '0.049', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 259, 'train': 'train'}
# {'loss': '0.064', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 260, 'train': 'train'}
# {'loss': '0.037', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 261, 'train': 'train'}
# {'loss': '0.061', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 262, 'train': 'train'}
# {'loss': '0.087', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 263, 'train': 'train'}
# {'loss': '0.035', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 264, 'train': 'train'}
# {'loss': '0.064', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 265, 'train': 'train'}
# {'loss': '0.084', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 266, 'train': 'train'}
# {'loss': '0.101', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 267, 'train': 'train'}
# {'loss': '0.041', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 268, 'train': 'train'}
# {'loss': '0.084', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 269, 'train': 'train'}
# {'loss': '0.059', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 270, 'train': 'train'}
# {'loss': '0.055', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 271, 'train': 'train'}
# {'loss': '0.095', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 272, 'train': 'train'}
# {'loss': '0.072', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 273, 'train': 'train'}
# {'loss': '0.054', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 274, 'train': 'train'}
# {'loss': '0.078', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 275, 'train': 'train'}
# {'loss': '0.067', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 276, 'train': 'train'}
# {'loss': '0.061', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 277, 'train': 'train'}
# {'loss': '0.041', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 278, 'train': 'train'}
# {'loss': '0.117', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 279, 'train': 'train'}
# {'loss': '0.106', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 280, 'train': 'train'}
# {'loss': '0.049', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 281, 'train': 'train'}
# {'loss': '0.064', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 282, 'train': 'train'}
# {'loss': '0.066', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 283, 'train': 'train'}
# {'loss': '0.045', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 284, 'train': 'train'}
# {'loss': '0.056', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 285, 'train': 'train'}
# {'loss': '0.087', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 286, 'train': 'train'}
# {'loss': '0.050', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 287, 'train': 'train'}
# {'loss': '0.032', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 288, 'train': 'train'}
# {'loss': '0.054', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 289, 'train': 'train'}
# {'loss': '0.074', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 290, 'train': 'train'}
# {'loss': '0.068', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 291, 'train': 'train'}
# {'loss': '0.062', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 292, 'train': 'train'}
# {'loss': '0.070', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 293, 'train': 'train'}
# {'loss': '0.050', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 294, 'train': 'train'}
# {'loss': '0.045', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 295, 'train': 'train'}
# {'loss': '0.093', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 296, 'train': 'train'}
# {'loss': '0.050', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 297, 'train': 'train'}
# {'loss': '0.052', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 298, 'train': 'train'}
# {'loss': '0.037', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 299, 'train': 'train'}
# {'loss': '0.071', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 300, 'train': 'train'}
# {'loss': '0.039', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 301, 'train': 'train'}
# {'loss': '0.053', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 302, 'train': 'train'}
# {'loss': '0.076', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 303, 'train': 'train'}
# {'loss': '0.050', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 304, 'train': 'train'}
# {'loss': '0.056', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 305, 'train': 'train'}
# {'loss': '0.057', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 306, 'train': 'train'}
# {'loss': '0.039', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 307, 'train': 'train'}
# {'loss': '0.028', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 308, 'train': 'train'}
# {'loss': '0.052', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 309, 'train': 'train'}
# {'loss': '0.071', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 310, 'train': 'train'}
# {'loss': '0.081', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 311, 'train': 'train'}
# {'loss': '0.051', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 312, 'train': 'train'}
# {'loss': '0.042', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 313, 'train': 'train'}
# {'loss': '0.053', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 314, 'train': 'train'}
# {'loss': '0.050', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 315, 'train': 'train'}
# {'loss': '0.083', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 316, 'train': 'train'}
# {'loss': '0.068', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 317, 'train': 'train'}
# {'loss': '0.053', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 318, 'train': 'train'}
# {'loss': '0.027', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 319, 'train': 'train'}
# {'loss': '0.036', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 320, 'train': 'train'}
# {'loss': '0.053', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 321, 'train': 'train'}
# {'loss': '0.072', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 322, 'train': 'train'}
# {'loss': '0.054', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 323, 'train': 'train'}
# {'loss': '0.082', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 324, 'train': 'train'}
# {'loss': '0.064', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 325, 'train': 'train'}
# {'loss': '0.064', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 326, 'train': 'train'}
# {'loss': '0.046', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 327, 'train': 'train'}
# {'loss': '0.050', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 328, 'train': 'train'}
# {'loss': '0.036', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 329, 'train': 'train'}
# {'loss': '0.044', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 330, 'train': 'train'}
# {'loss': '0.067', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 331, 'train': 'train'}
# {'loss': '0.071', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 332, 'train': 'train'}
# {'loss': '0.050', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 333, 'train': 'train'}
# {'loss': '0.076', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 334, 'train': 'train'}
# {'loss': '0.041', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 335, 'train': 'train'}
# {'loss': '0.052', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 336, 'train': 'train'}
# {'loss': '0.072', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 337, 'train': 'train'}
# {'loss': '0.055', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 338, 'train': 'train'}
# {'loss': '0.098', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 339, 'train': 'train'}
# {'loss': '0.081', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 340, 'train': 'train'}
# {'loss': '0.038', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 341, 'train': 'train'}
# {'loss': '0.061', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 342, 'train': 'train'}
# {'loss': '0.055', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 343, 'train': 'train'}
# {'loss': '0.052', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 344, 'train': 'train'}
# {'loss': '0.031', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 345, 'train': 'train'}
# {'loss': '0.047', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 346, 'train': 'train'}
# {'loss': '0.080', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 347, 'train': 'train'}
# {'loss': '0.041', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 348, 'train': 'train'}
# {'loss': '0.058', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 349, 'train': 'train'}
# {'loss': '0.064', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 350, 'train': 'train'}
# {'loss': '0.069', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 351, 'train': 'train'}
# {'loss': '0.045', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 352, 'train': 'train'}
# {'loss': '0.064', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 353, 'train': 'train'}
# {'loss': '0.059', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 354, 'train': 'train'}
# {'loss': '0.054', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 355, 'train': 'train'}
# {'loss': '0.034', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 356, 'train': 'train'}
# {'loss': '0.042', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 357, 'train': 'train'}
# {'loss': '0.070', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 358, 'train': 'train'}
# {'loss': '0.068', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 359, 'train': 'train'}
# {'loss': '0.069', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 360, 'train': 'train'}
# {'loss': '0.075', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 361, 'train': 'train'}
# {'loss': '0.058', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 362, 'train': 'train'}
# {'loss': '0.077', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 363, 'train': 'train'}
# {'loss': '0.029', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 364, 'train': 'train'}
# {'loss': '0.039', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 365, 'train': 'train'}
# {'loss': '0.044', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 366, 'train': 'train'}
# {'loss': '0.040', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 367, 'train': 'train'}
# {'loss': '0.051', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 368, 'train': 'train'}
# {'loss': '0.057', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 369, 'train': 'train'}
# {'loss': '0.061', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 370, 'train': 'train'}
# {'loss': '0.030', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 371, 'train': 'train'}
# {'loss': '0.069', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 372, 'train': 'train'}
# {'loss': '0.051', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 373, 'train': 'train'}
# {'loss': '0.033', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 374, 'train': 'train'}
# {'loss': '0.039', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 375, 'train': 'train'}
# {'loss': '0.040', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 376, 'train': 'train'}
# {'loss': '0.038', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 377, 'train': 'train'}
# {'loss': '0.055', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 378, 'train': 'train'}
# {'loss': '0.056', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 379, 'train': 'train'}
# {'loss': '0.034', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 380, 'train': 'train'}
# {'loss': '0.031', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 381, 'train': 'train'}
# {'loss': '0.036', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 382, 'train': 'train'}
# {'loss': '0.037', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 383, 'train': 'train'}
# {'loss': '0.059', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 384, 'train': 'train'}
# {'loss': '0.082', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 385, 'train': 'train'}
# {'loss': '0.050', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 386, 'train': 'train'}
# {'loss': '0.054', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 387, 'train': 'train'}
# {'loss': '0.059', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 388, 'train': 'train'}
# {'loss': '0.036', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 389, 'train': 'train'}
# {'loss': '0.039', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 390, 'train': 'train'}
# {'loss': '0.054', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 391, 'train': 'train'}
# {'loss': '0.062', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 392, 'train': 'train'}
# {'loss': '0.032', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 393, 'train': 'train'}
# {'loss': '0.055', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 394, 'train': 'train'}
# {'loss': '0.030', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 395, 'train': 'train'}
# {'loss': '0.024', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 396, 'train': 'train'}
# {'loss': '0.034', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 397, 'train': 'train'}
# {'loss': '0.039', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 398, 'train': 'train'}
# {'loss': '0.061', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 399, 'train': 'train'}
# {'loss': '0.037', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 400, 'train': 'train'}
# {'loss': '0.046', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 401, 'train': 'train'}
# {'loss': '0.055', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 402, 'train': 'train'}
# {'loss': '0.038', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 403, 'train': 'train'}
# {'loss': '0.033', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 404, 'train': 'train'}
# {'loss': '0.080', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 405, 'train': 'train'}
# {'loss': '0.038', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 406, 'train': 'train'}
# {'loss': '0.043', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 407, 'train': 'train'}
# {'loss': '0.041', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 408, 'train': 'train'}
# {'loss': '0.042', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 409, 'train': 'train'}
# {'loss': '0.038', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 410, 'train': 'train'}
# {'loss': '0.077', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 411, 'train': 'train'}
# {'loss': '0.061', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 412, 'train': 'train'}
# {'loss': '0.067', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 413, 'train': 'train'}
# {'loss': '0.055', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 414, 'train': 'train'}
# {'loss': '0.036', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 415, 'train': 'train'}
# {'loss': '0.062', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 416, 'train': 'train'}
# {'loss': '0.048', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 417, 'train': 'train'}
# {'loss': '0.051', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 418, 'train': 'train'}
# {'loss': '0.045', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 419, 'train': 'train'}
# {'loss': '0.034', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 420, 'train': 'train'}
# {'loss': '0.033', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 421, 'train': 'train'}
# {'loss': '0.035', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 422, 'train': 'train'}
# {'loss': '0.063', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 423, 'train': 'train'}
# {'loss': '0.039', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 424, 'train': 'train'}
# {'loss': '0.041', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 425, 'train': 'train'}
# {'loss': '0.049', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 426, 'train': 'train'}
# {'loss': '0.044', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 427, 'train': 'train'}
# {'loss': '0.028', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 428, 'train': 'train'}
# {'loss': '0.024', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 429, 'train': 'train'}
# {'loss': '0.035', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 430, 'train': 'train'}
# {'loss': '0.052', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 431, 'train': 'train'}
# {'loss': '0.038', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 432, 'train': 'train'}
# {'loss': '0.040', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 433, 'train': 'train'}
# {'loss': '0.054', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 434, 'train': 'train'}
# {'loss': '0.037', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 435, 'train': 'train'}
# {'loss': '0.067', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 436, 'train': 'train'}
# {'loss': '0.058', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 437, 'train': 'train'}
# {'loss': '0.034', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 438, 'train': 'train'}
# {'loss': '0.056', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 439, 'train': 'train'}
# {'loss': '0.045', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 440, 'train': 'train'}
# {'loss': '0.051', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 441, 'train': 'train'}
# {'loss': '0.057', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 442, 'train': 'train'}
# {'loss': '0.068', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 443, 'train': 'train'}
# {'loss': '0.056', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 444, 'train': 'train'}
# {'loss': '0.054', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 445, 'train': 'train'}
# {'loss': '0.056', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 446, 'train': 'train'}
# {'loss': '0.054', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 447, 'train': 'train'}
# {'loss': '0.081', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 448, 'train': 'train'}
# {'loss': '0.068', 'epoch': 448, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 449, 'train': 'train'}
# {'loss': '0.070', 'epoch': 449, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 450, 'train': 'train'}
# {'loss': '0.042', 'epoch': 450, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 451, 'train': 'train'}
# {'loss': '0.041', 'epoch': 451, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 452, 'train': 'train'}
# {'loss': '0.084', 'epoch': 452, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 453, 'train': 'train'}
# {'loss': '0.070', 'epoch': 453, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 454, 'train': 'train'}
# {'loss': '0.091', 'epoch': 454, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 455, 'train': 'train'}
# {'loss': '0.046', 'epoch': 455, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 456, 'train': 'train'}
# {'loss': '0.034', 'epoch': 456, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 457, 'train': 'train'}
# {'loss': '0.035', 'epoch': 457, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 458, 'train': 'train'}
# {'loss': '0.043', 'epoch': 458, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 459, 'train': 'train'}
# {'loss': '0.054', 'epoch': 459, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 460, 'train': 'train'}
# {'loss': '0.048', 'epoch': 460, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 461, 'train': 'train'}
# {'loss': '0.048', 'epoch': 461, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 462, 'train': 'train'}
# {'loss': '0.044', 'epoch': 462, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 463, 'train': 'train'}
# {'loss': '0.077', 'epoch': 463, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 464, 'train': 'train'}
# {'loss': '0.051', 'epoch': 464, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 465, 'train': 'train'}
# {'loss': '0.062', 'epoch': 465, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 466, 'train': 'train'}
# {'loss': '0.039', 'epoch': 466, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 467, 'train': 'train'}
# {'loss': '0.076', 'epoch': 467, 'train': 'eval'}
# ...
# {'loss': '0.040', 'epoch': 556, 'train': 'train'}
# {'loss': '0.065', 'epoch': 556, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 557, 'train': 'train'}
# {'loss': '0.077', 'epoch': 557, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 558, 'train': 'train'}
# {'loss': '0.046', 'epoch': 558, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 559, 'train': 'train'}
# {'loss': '0.048', 'epoch': 559, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 560, 'train': 'train'}
# {'loss': '0.066', 'epoch': 560, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 561, 'train': 'train'}
# {'loss': '0.024', 'epoch': 561, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 562, 'train': 'train'}
# {'loss': '0.041', 'epoch': 562, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 563, 'train': 'train'}
# {'loss': '0.047', 'epoch': 563, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 564, 'train': 'train'}
# {'loss': '0.046', 'epoch': 564, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 565, 'train': 'train'}
# {'loss': '0.041', 'epoch': 565, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 566, 'train': 'train'}
# {'loss': '0.050', 'epoch': 566, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 567, 'train': 'train'}
# {'loss': '0.050', 'epoch': 567, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 568, 'train': 'train'}
# {'loss': '0.038', 'epoch': 568, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 569, 'train': 'train'}
# {'loss': '0.057', 'epoch': 569, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 570, 'train': 'train'}
# {'loss': '0.043', 'epoch': 570, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 571, 'train': 'train'}
# {'loss': '0.034', 'epoch': 571, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 572, 'train': 'train'}
# {'loss': '0.063', 'epoch': 572, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 573, 'train': 'train'}
# {'loss': '0.027', 'epoch': 573, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 574, 'train': 'train'}
# {'loss': '0.067', 'epoch': 574, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 575, 'train': 'train'}
# {'loss': '0.036', 'epoch': 575, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 576, 'train': 'train'}
# {'loss': '0.066', 'epoch': 576, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 577, 'train': 'train'}
# {'loss': '0.030', 'epoch': 577, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 578, 'train': 'train'}
# {'loss': '0.056', 'epoch': 578, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 579, 'train': 'train'}
# {'loss': '0.048', 'epoch': 579, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 580, 'train': 'train'}
# {'loss': '0.040', 'epoch': 580, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 581, 'train': 'train'}
# {'loss': '0.047', 'epoch': 581, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 582, 'train': 'train'}
# {'loss': '0.061', 'epoch': 582, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 583, 'train': 'train'}
# {'loss': '0.039', 'epoch': 583, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 584, 'train': 'train'}
# {'loss': '0.046', 'epoch': 584, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 585, 'train': 'train'}
# {'loss': '0.045', 'epoch': 585, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 586, 'train': 'train'}
# {'loss': '0.067', 'epoch': 586, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 587, 'train': 'train'}
# {'loss': '0.032', 'epoch': 587, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 588, 'train': 'train'}
# {'loss': '0.041', 'epoch': 588, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 589, 'train': 'train'}
# {'loss': '0.049', 'epoch': 589, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 590, 'train': 'train'}
# {'loss': '0.048', 'epoch': 590, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 591, 'train': 'train'}
# {'loss': '0.029', 'epoch': 591, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 592, 'train': 'train'}
# {'loss': '0.061', 'epoch': 592, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 593, 'train': 'train'}
# {'loss': '0.027', 'epoch': 593, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 594, 'train': 'train'}
# {'loss': '0.040', 'epoch': 594, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 595, 'train': 'train'}
# {'loss': '0.040', 'epoch': 595, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 596, 'train': 'train'}
# {'loss': '0.042', 'epoch': 596, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 597, 'train': 'train'}
# {'loss': '0.052', 'epoch': 597, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 598, 'train': 'train'}
# {'loss': '0.061', 'epoch': 598, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 599, 'train': 'train'}
# {'loss': '0.027', 'epoch': 599, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 600, 'train': 'train'}
# {'loss': '0.039', 'epoch': 600, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 601, 'train': 'train'}
# {'loss': '0.036', 'epoch': 601, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 602, 'train': 'train'}
# {'loss': '0.029', 'epoch': 602, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 603, 'train': 'train'}
# {'loss': '0.070', 'epoch': 603, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 604, 'train': 'train'}
# {'loss': '0.053', 'epoch': 604, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 605, 'train': 'train'}
# {'loss': '0.049', 'epoch': 605, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 606, 'train': 'train'}
# {'loss': '0.072', 'epoch': 606, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 607, 'train': 'train'}
# {'loss': '0.043', 'epoch': 607, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 608, 'train': 'train'}
# {'loss': '0.049', 'epoch': 608, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 609, 'train': 'train'}
# {'loss': '0.035', 'epoch': 609, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 610, 'train': 'train'}
# {'loss': '0.052', 'epoch': 610, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 611, 'train': 'train'}
# {'loss': '0.034', 'epoch': 611, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 612, 'train': 'train'}
# {'loss': '0.039', 'epoch': 612, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 613, 'train': 'train'}
# {'loss': '0.068', 'epoch': 613, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 614, 'train': 'train'}
# {'loss': '0.027', 'epoch': 614, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 615, 'train': 'train'}
# {'loss': '0.035', 'epoch': 615, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 616, 'train': 'train'}
# {'loss': '0.062', 'epoch': 616, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 617, 'train': 'train'}
# {'loss': '0.029', 'epoch': 617, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 618, 'train': 'train'}
# {'loss': '0.061', 'epoch': 618, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 619, 'train': 'train'}
# {'loss': '0.042', 'epoch': 619, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 620, 'train': 'train'}
# {'loss': '0.034', 'epoch': 620, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 621, 'train': 'train'}
# {'loss': '0.078', 'epoch': 621, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 622, 'train': 'train'}
# {'loss': '0.036', 'epoch': 622, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 623, 'train': 'train'}
# {'loss': '0.080', 'epoch': 623, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 624, 'train': 'train'}
# {'loss': '0.091', 'epoch': 624, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 625, 'train': 'train'}
# {'loss': '0.044', 'epoch': 625, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 626, 'train': 'train'}
# {'loss': '0.033', 'epoch': 626, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 627, 'train': 'train'}
# {'loss': '0.040', 'epoch': 627, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 628, 'train': 'train'}
# {'loss': '0.071', 'epoch': 628, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 629, 'train': 'train'}
# {'loss': '0.055', 'epoch': 629, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 630, 'train': 'train'}
# {'loss': '0.053', 'epoch': 630, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 631, 'train': 'train'}
# {'loss': '0.067', 'epoch': 631, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 632, 'train': 'train'}
# {'loss': '0.035', 'epoch': 632, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 633, 'train': 'train'}
# {'loss': '0.049', 'epoch': 633, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 634, 'train': 'train'}
# {'loss': '0.069', 'epoch': 634, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 635, 'train': 'train'}
# {'loss': '0.043', 'epoch': 635, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 636, 'train': 'train'}
# {'loss': '0.037', 'epoch': 636, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 637, 'train': 'train'}
# {'loss': '0.069', 'epoch': 637, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 638, 'train': 'train'}
# {'loss': '0.061', 'epoch': 638, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 639, 'train': 'train'}
# {'loss': '0.056', 'epoch': 639, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 640, 'train': 'train'}
# {'loss': '0.059', 'epoch': 640, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 641, 'train': 'train'}
# {'loss': '0.062', 'epoch': 641, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 642, 'train': 'train'}
# {'loss': '0.068', 'epoch': 642, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 643, 'train': 'train'}
# {'loss': '0.046', 'epoch': 643, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 644, 'train': 'train'}
# {'loss': '0.041', 'epoch': 644, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 645, 'train': 'train'}
# {'loss': '0.079', 'epoch': 645, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 646, 'train': 'train'}
# {'loss': '0.061', 'epoch': 646, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 647, 'train': 'train'}
# {'loss': '0.062', 'epoch': 647, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 648, 'train': 'train'}
# {'loss': '0.019', 'epoch': 648, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 649, 'train': 'train'}
# {'loss': '0.055', 'epoch': 649, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 650, 'train': 'train'}
# {'loss': '0.059', 'epoch': 650, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 651, 'train': 'train'}
# {'loss': '0.035', 'epoch': 651, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 652, 'train': 'train'}
# {'loss': '0.039', 'epoch': 652, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 653, 'train': 'train'}
# {'loss': '0.057', 'epoch': 653, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 654, 'train': 'train'}
# {'loss': '0.032', 'epoch': 654, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 655, 'train': 'train'}
# {'loss': '0.038', 'epoch': 655, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 656, 'train': 'train'}
# {'loss': '0.058', 'epoch': 656, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 657, 'train': 'train'}
# {'loss': '0.033', 'epoch': 657, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 658, 'train': 'train'}
# {'loss': '0.053', 'epoch': 658, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 659, 'train': 'train'}
# {'loss': '0.051', 'epoch': 659, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 660, 'train': 'train'}
# {'loss': '0.048', 'epoch': 660, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 661, 'train': 'train'}
# {'loss': '0.047', 'epoch': 661, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 662, 'train': 'train'}
# {'loss': '0.044', 'epoch': 662, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 663, 'train': 'train'}
# {'loss': '0.042', 'epoch': 663, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 664, 'train': 'train'}
# {'loss': '0.048', 'epoch': 664, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 665, 'train': 'train'}
# {'loss': '0.047', 'epoch': 665, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 666, 'train': 'train'}
# {'loss': '0.035', 'epoch': 666, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 667, 'train': 'train'}
# {'loss': '0.046', 'epoch': 667, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 668, 'train': 'train'}
# {'loss': '0.068', 'epoch': 668, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 669, 'train': 'train'}
# {'loss': '0.054', 'epoch': 669, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 670, 'train': 'train'}
# {'loss': '0.027', 'epoch': 670, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 671, 'train': 'train'}
# {'loss': '0.034', 'epoch': 671, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 672, 'train': 'train'}
# {'loss': '0.031', 'epoch': 672, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 673, 'train': 'train'}
# {'loss': '0.042', 'epoch': 673, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 674, 'train': 'train'}
# {'loss': '0.041', 'epoch': 674, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 675, 'train': 'train'}
# {'loss': '0.033', 'epoch': 675, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 676, 'train': 'train'}
# {'loss': '0.042', 'epoch': 676, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 677, 'train': 'train'}
# {'loss': '0.036', 'epoch': 677, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 678, 'train': 'train'}
# {'loss': '0.065', 'epoch': 678, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 679, 'train': 'train'}
# {'loss': '0.059', 'epoch': 679, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 680, 'train': 'train'}
# {'loss': '0.060', 'epoch': 680, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 681, 'train': 'train'}
# {'loss': '0.030', 'epoch': 681, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 682, 'train': 'train'}
# {'loss': '0.040', 'epoch': 682, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 683, 'train': 'train'}
# {'loss': '0.030', 'epoch': 683, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 684, 'train': 'train'}
# {'loss': '0.032', 'epoch': 684, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 685, 'train': 'train'}
# {'loss': '0.076', 'epoch': 685, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 686, 'train': 'train'}
# {'loss': '0.036', 'epoch': 686, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 687, 'train': 'train'}
# {'loss': '0.041', 'epoch': 687, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 688, 'train': 'train'}
# {'loss': '0.037', 'epoch': 688, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 689, 'train': 'train'}
# {'loss': '0.061', 'epoch': 689, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 690, 'train': 'train'}
# {'loss': '0.045', 'epoch': 690, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 691, 'train': 'train'}
# {'loss': '0.060', 'epoch': 691, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 692, 'train': 'train'}
# {'loss': '0.044', 'epoch': 692, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 693, 'train': 'train'}
# {'loss': '0.045', 'epoch': 693, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 694, 'train': 'train'}
# {'loss': '0.031', 'epoch': 694, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 695, 'train': 'train'}
# {'loss': '0.037', 'epoch': 695, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 696, 'train': 'train'}
# {'loss': '0.073', 'epoch': 696, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 697, 'train': 'train'}
# {'loss': '0.044', 'epoch': 697, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 698, 'train': 'train'}
# {'loss': '0.042', 'epoch': 698, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 699, 'train': 'train'}
# {'loss': '0.056', 'epoch': 699, 'train': 'eval'}
# VBox(children=(Label(value='437.851 MB of 437.851 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# W&B sync reduced upload amount by 0.0%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>█▇▅▃▃▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▅▃▃▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.05628</td></tr><tr><td>train_loss</td><td>0.053</td></tr><tr><td>val_loss</td><td>0.056</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lunar-rain-18</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/rlqlctkm' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/rlqlctkm</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64</a><br/>Synced 6 W&B file(s), 700 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_003211-rlqlctkm/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
lr = 5e-4
epochs = 1000
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_014327-5vmawaxp</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/5vmawaxp' target="_blank">firm-resonance-21</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/5vmawaxp' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64/runs/5vmawaxp</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       5.10% [51/1000 05:21&lt;1:39:39]
#     </div>
#
#
#
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00 0.041]
#     </div>
# {'loss': '0.046', 'epoch': 0, 'train': 'train'}
# {'loss': '0.046', 'epoch': 0, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 1, 'train': 'train'}
# {'loss': '0.051', 'epoch': 1, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 2, 'train': 'train'}
# {'loss': '0.045', 'epoch': 2, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 3, 'train': 'train'}
# {'loss': '0.029', 'epoch': 3, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 4, 'train': 'train'}
# {'loss': '0.038', 'epoch': 4, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 5, 'train': 'train'}
# {'loss': '0.054', 'epoch': 5, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 6, 'train': 'train'}
# {'loss': '0.053', 'epoch': 6, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 7, 'train': 'train'}
# {'loss': '0.051', 'epoch': 7, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 8, 'train': 'train'}
# {'loss': '0.049', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 9, 'train': 'train'}
# {'loss': '0.037', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 10, 'train': 'train'}
# {'loss': '0.073', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 11, 'train': 'train'}
# {'loss': '0.046', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 12, 'train': 'train'}
# {'loss': '0.047', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 13, 'train': 'train'}
# {'loss': '0.062', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 14, 'train': 'train'}
# {'loss': '0.036', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 15, 'train': 'train'}
# {'loss': '0.053', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 16, 'train': 'train'}
# {'loss': '0.047', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 17, 'train': 'train'}
# {'loss': '0.057', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 18, 'train': 'train'}
# {'loss': '0.047', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.036', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 20, 'train': 'train'}
# {'loss': '0.061', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 21, 'train': 'train'}
# {'loss': '0.044', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 22, 'train': 'train'}
# {'loss': '0.084', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 23, 'train': 'train'}
# {'loss': '0.030', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 24, 'train': 'train'}
# {'loss': '0.079', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 25, 'train': 'train'}
# {'loss': '0.064', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 26, 'train': 'train'}
# {'loss': '0.052', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 27, 'train': 'train'}
# {'loss': '0.051', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 28, 'train': 'train'}
# {'loss': '0.040', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 29, 'train': 'train'}
# {'loss': '0.052', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 30, 'train': 'train'}
# {'loss': '0.039', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 31, 'train': 'train'}
# {'loss': '0.085', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 32, 'train': 'train'}
# {'loss': '0.044', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 33, 'train': 'train'}
# {'loss': '0.052', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 34, 'train': 'train'}
# {'loss': '0.048', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 35, 'train': 'train'}
# {'loss': '0.068', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 36, 'train': 'train'}
# {'loss': '0.060', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 37, 'train': 'train'}
# {'loss': '0.049', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 38, 'train': 'train'}
# {'loss': '0.086', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 39, 'train': 'train'}
# {'loss': '0.042', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 40, 'train': 'train'}
# {'loss': '0.056', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 41, 'train': 'train'}
# {'loss': '0.031', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 42, 'train': 'train'}
# {'loss': '0.041', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 43, 'train': 'train'}
# {'loss': '0.043', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 44, 'train': 'train'}
# {'loss': '0.054', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 45, 'train': 'train'}
# {'loss': '0.047', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 46, 'train': 'train'}
# {'loss': '0.040', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 47, 'train': 'train'}
# {'loss': '0.052', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 48, 'train': 'train'}
# {'loss': '0.044', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 49, 'train': 'train'}
# {'loss': '0.021', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 50, 'train': 'train'}
# {'loss': '0.047', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 51, 'train': 'train'}

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %% [markdown]
# cmodel = torch.load('models/data_aug2.pkl')
# del(cmodel[8])
# del(cmodel[7])
#
# @inplace
# def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]
#
# bs = 2048
# tds = dsd.with_transform(transformi)
# dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)
#
# dt = dls.train
# xb,yb = next(iter(dt))
#
# ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (64,3,64,64)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = (preds[-1]+0.5)
s.min(),s.max(),s.shape

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)

# %%
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = (preds[-1]+0.5)
s.min(),s.max(),s.shape

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)
