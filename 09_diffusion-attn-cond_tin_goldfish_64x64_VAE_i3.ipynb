# %%
#| default_exp diffusion

# %% [markdown]
# # [fail] Diffusion unet

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
#| export
from miniai.imports import *

from einops import rearrange
from fastprogress import progress_bar
from diffusers import AutoencoderKL

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
class GPUCUDAMissing(BaseException):
    pass
    
try:
    if torch.cuda.is_available():
        print('# of GPUs available = ', torch.cuda.device_count())
    else:
        raise GPUCUDAMissing
except:
    print("ERROR: GPU is missing")
# Out:
# # of GPUs available =  1

# %%
xl,yl = 'image','label'
name = "zh-plus/tiny-imagenet"
bs = 1024
dsd = load_dataset(name)

# %%
dsd['train'] = dsd['train'].select(range(500))

# %%
dsd['valid'] = dsd['valid'].select(range(50))

# %%
class TinyHFDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hg_ds):
        self.ds = hg_ds
        # the 2 lines below must be done here because the execution of "ds['train']['image']" takes 18seconds
        # once it has executed, indexing it is very fast (5 milliseconds)
        self.image = hg_ds[xl]
        self.label = hg_ds[yl]
    def __len__(self): return self.ds.num_rows
    def __getitem__(self, i): return TF.to_tensor(self.image[i]), self.label[i]

# %%
tds = TinyHFDS(dsd['train'])

# %%
vds = TinyHFDS(dsd['valid'])

# %%
dl = DataLoader(tds, batch_size=bs, num_workers=0)
xb,yb = next(iter(dl))
show_images(xb[:16], imsize=2)

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").cuda().requires_grad_(False)

# %%
# %%time
lats = vae.encode(xb.cuda())
# Out:
# CPU times: user 241 ms, sys: 104 ms, total: 344 ms
# Wall time: 342 ms

# %%
class LatsDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hfds):
        lbl = hfds[yl]
        self.label = lbl + lbl
        imgs = hfds[xl]
        list_tensor = [ TF.to_tensor(x) for i, x in enumerate(imgs+imgs)]
        batch = torch.stack(list_tensor)
        #batch.shape
        lats = vae.encode(batch.cuda())
        #lats.latent_dist.mean.shape
        self.lats = lats.latent_dist.mean
        
    def __len__(self): return len(self.lats)
    def __getitem__(self, i): return self.lats[i], self.label[i]

# %%
tlds = LatsDS(dsd['train'])
vlds = LatsDS(dsd['valid'])

# %% [markdown]
# ### Defs: TfmDS, tfmx, tfmy

# %%
class TfmDS:
    def __init__(self, ds, tfmx=fc.noop, tfmy=fc.noop): self.ds,self.tfmx,self.tfmy = ds,tfmx,tfmy
    def __len__(self): return len(self.ds)
    def __getitem__(self, i):
        x,y = self.ds[i]
        return self.tfmx(x),self.tfmy(y)

# %%
def tfmx(x):
    return x

# %%
def tfmy(y): 
    return y

# %% [markdown]
# ### Generate a batch and Decode batch

# %%
tfm_tds = TfmDS(tlds, tfmx, tfmy)
tfm_vds = TfmDS(vlds, tfmx, tfmy)

# %%
def collate_fn(b):
    b = default_collate(b)
    return b

# %%
#bs=512

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_fn))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb.shape, yb.shape, xb.min(), xb.max()
# Out:
# (torch.Size([1000, 4, 8, 8]),
#  torch.Size([1000]),
#  tensor(-20.1415, device='cuda:0'),
#  tensor(26.5186, device='cuda:0'))

# %%
show_images(((xb[:16,:3])/4).sigmoid() , imsize=2)

# %%
show_images(to_cpu(vae.decode(xb[:16]))['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# ### DDIM

# %%
#| export
def abar(t): return (t*math.pi/2).cos()**2
def inv_abar(x): return x.sqrt().acos()*2/math.pi

def noisify(x0):
    device = x0.device
    n = len(x0)
    t = torch.rand(n,).to(x0).clamp(0,0.999)
    ε = torch.randn(x0.shape, device=device)
    abar_t = abar(t).reshape(-1, 1, 1, 1).to(device)
    xt = abar_t.sqrt()*x0 + (1-abar_t).sqrt()*ε
    return (xt, t.to(device)), ε

def collate_ddpm(b): 
    b = default_collate(b)
    return noisify(b[0]*0.2) # jeremy scaled the lats by 0.2
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=0)

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_ddpm))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb[0].shape, xb[1].shape, yb.shape
# Out:
# (torch.Size([1000, 4, 8, 8]), torch.Size([1000]), torch.Size([1000, 4, 8, 8]))

# %%
xb[0].min(), xb[0].max()
# Out:
# (tensor(-4.1888, device='cuda:0'), tensor(5.0195, device='cuda:0'))

# %%
show_images((xb[0][:9,0]*5).clamp(0,1))

# %% [markdown]
# ## Train

# %% [markdown]
# Based on Diffusers

# %%
#| export
def timestep_embedding(tsteps, emb_dim, max_period= 10000):
    exponent = -math.log(max_period) * torch.linspace(0, 1, emb_dim//2, device=tsteps.device)
    emb = tsteps[:,None].float() * exponent.exp()[None,:]
    emb = torch.cat([emb.sin(), emb.cos()], dim=-1)
    return F.pad(emb, (0,1,0,0)) if emb_dim%2==1 else emb

# %%
#| export
def pre_conv(ni, nf, ks=3, stride=1, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2, bias=bias))
    return layers

# %%
#| export
def upsample(nf): return nn.Sequential(nn.Upsample(scale_factor=2.), nn.Conv2d(nf, nf, 3, padding=1))

# %%
#| export
def lin(ni, nf, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Linear(ni, nf, bias=bias))
    return layers

# %%
# This version is giving poor results - use the cell below instead
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans):
        super().__init__()
        self.attn = nn.MultiheadAttention(ni, ni//attn_chans, batch_first=True)
        self.norm = nn.BatchNorm2d(ni)

    def forward(self, x):
        n,c,h,w = x.shape
        x = self.norm(x).view(n, c, -1).transpose(1, 2)
        x = self.attn(x, x, x, need_weights=False)[0]
        return x.transpose(1,2).reshape(n,c,h,w)

# %%
#| export
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans, transpose=True):
        super().__init__()
        self.nheads = ni//attn_chans
        self.scale = math.sqrt(ni/self.nheads)
        self.norm = nn.LayerNorm(ni)
        self.qkv = nn.Linear(ni, ni*3)
        self.proj = nn.Linear(ni, ni)
        self.t = transpose
    
    def forward(self, x):
        n,c,s = x.shape
        if self.t: x = x.transpose(1, 2)
        x = self.norm(x)
        x = self.qkv(x)
        x = rearrange(x, 'n s (h d) -> (n h) s d', h=self.nheads)
        q,k,v = torch.chunk(x, 3, dim=-1)
        s = (q@k.transpose(1,2))/self.scale
        x = s.softmax(dim=-1)@v
        x = rearrange(x, '(n h) s d -> n s (h d)', h=self.nheads)
        x = self.proj(x)
        if self.t: x = x.transpose(1, 2)
        return x

# %%
#| export
class SelfAttention2D(SelfAttention):
    def forward(self, x):
        n,c,h,w = x.shape
        return super().forward(x.view(n, c, -1)).reshape(n,c,h,w)

# %%
#| export
class EmbResBlock(nn.Module):
    def __init__(self, n_emb, ni, nf=None, ks=3, act=nn.SiLU, norm=nn.BatchNorm2d, attn_chans=0):
        super().__init__()
        if nf is None: nf = ni
        self.emb_proj = nn.Linear(n_emb, nf*2)
        self.conv1 = pre_conv(ni, nf, ks, act=None, norm=norm)
        self.conv2 = pre_conv(nf, nf, ks, act=act, norm=norm)
        self.idconv = fc.noop if ni==nf else nn.Conv2d(ni, nf, 1)
        self.attn = False
        if attn_chans: self.attn = SelfAttention2D(nf, attn_chans)

    def forward(self, x, t):
        inp = x
        x = self.conv1(x)
        emb = self.emb_proj(F.silu(t))[:, :, None, None]
        scale,shift = torch.chunk(emb, 2, dim=1)
        x = x*(1+scale) + shift
        x = self.conv2(x)
        x = x + self.idconv(inp)
        if self.attn: x = x + self.attn(x)
        return x

# %%
#| export
def saved(m, blk):
    m_ = m.forward

    @wraps(m.forward)
    def _f(*args, **kwargs):
        res = m_(*args, **kwargs)
        blk.saved.append(res)
        return res

    m.forward = _f
    return m

# %%
#| export
class DownBlock(nn.Module):
    def __init__(self, n_emb, ni, nf, add_down=True, num_layers=1, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList([saved(EmbResBlock(n_emb, ni if i==0 else nf, nf, attn_chans=attn_chans), self)
                                      for i in range(num_layers)])
        self.down = saved(nn.Conv2d(nf, nf, 3, stride=2, padding=1), self) if add_down else nn.Identity()

    def forward(self, x, t):
        self.saved = []
        for resnet in self.resnets: x = resnet(x, t)
        x = self.down(x)
        return x

# %%
#| export
class UpBlock(nn.Module):
    def __init__(self, n_emb, ni, prev_nf, nf, add_up=True, num_layers=2, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList(
            [EmbResBlock(n_emb, (prev_nf if i==0 else nf)+(ni if (i==num_layers-1) else nf), nf, attn_chans=attn_chans)
            for i in range(num_layers)])
        self.up = upsample(nf) if add_up else nn.Identity()

    def forward(self, x, t, ups):
        for resnet in self.resnets: x = resnet(torch.cat([x, ups.pop()], dim=1), t)
        return self.up(x)

# %%
class LearnEmbSS(nn.Module):
    def __init__(self, sz, ni):
        super().__init__()
        self.scale = nn.Parameter(torch.zeros(sz, ni))
        self.shift = nn.Parameter(torch.zeros(sz, ni))

    def forward(self, x): return x*self.scale + self.shift

# %%
def _mlp(ni, nh):
    return nn.Sequential(nn.Linear(ni,nh), nn.GELU(), nn.LayerNorm(nh), nn.Linear(nh,ni))

# %%
class EmbTransformerBlk(nn.Module):
    def __init__(self, n_emb, ni, attn_chans=8):
        super().__init__()
        self.attn = SelfAttention(ni, attn_chans=attn_chans, transpose=False)
        self.mlp = _mlp(ni, ni*4)
        self.nrm1 = nn.LayerNorm(ni)
        self.nrm2 = nn.LayerNorm(ni)
        self.emb_proj = nn.Linear(n_emb, ni*2)

    def forward(self, x, t):
        emb = self.emb_proj(F.silu(t))[:, None]
        scale,shift = torch.chunk(emb, 2, dim=2)
        x = x + self.attn(self.nrm1(x))
        x = x*(1+scale) + shift
        return x + self.mlp(self.nrm2(x))

# %%
img_vec_len = 1
class SimpleDiffusion(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, nfs=(224,448,672,896), num_layers=1,
                 attn_chans=8, attn_start=1, n_mids=8):
        super().__init__()
        self.conv_in = nn.Conv2d(in_channels, nfs[0], kernel_size=3, padding=1)
        self.n_temb = nf = nfs[0]
        n_emb = nf*4
        self.emb_mlp = nn.Sequential(lin(self.n_temb, n_emb, norm=nn.BatchNorm1d),
                                     lin(n_emb, n_emb))
        self.downs = nn.ModuleList()
        n = len(nfs)
        for i in range(n):
            ni = nf
            nf = nfs[i]
            self.downs.append(DownBlock(n_emb, ni, nf, add_down=i!=n-1, num_layers=num_layers,
                                        attn_chans=0 if i<attn_start else attn_chans))

        self.le = LearnEmbSS(img_vec_len, nf)
        self.mids = nn.ModuleList([EmbTransformerBlk(n_emb, nf) for _ in range(n_mids)])

        rev_nfs = list(reversed(nfs))
        nf = rev_nfs[0]
        self.ups = nn.ModuleList()
        for i in range(n):
            prev_nf = nf
            nf = rev_nfs[i]
            ni = rev_nfs[min(i+1, len(nfs)-1)]
            self.ups.append(UpBlock(n_emb, ni, prev_nf, nf, add_up=i!=n-1, num_layers=num_layers+1,
                                    attn_chans=0 if i>=n-attn_start else attn_chans))
        self.conv_out = pre_conv(nfs[0], out_channels, act=nn.SiLU, norm=nn.BatchNorm2d, bias=False)

    def forward(self, inp):
        x,t = inp
        temb = timestep_embedding(t, self.n_temb)
        emb = self.emb_mlp(temb)
        x = self.conv_in(x)
        saved = [x]
        for block in self.downs: x = block(x, emb)
        saved += [p for o in self.downs for p in o.saved]
        n,c,h,w = x.shape
        x = self.le(x.reshape(n,c,-1).transpose(1,2))
        for block in self.mids: x = block(x, emb)
        x = x.transpose(1,2).reshape(n,c,h,w)
        for block in self.ups: x = block(x, emb, saved)
        return self.conv_out(x)

# %%
#| export
def ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp=True):
    sig = ((bbar_t1/bbar_t).sqrt() * (1-abar_t/abar_t1).sqrt()) * eta
    x_0_hat = ((x_t-(1-abar_t).sqrt()*noise) / abar_t.sqrt())
    if clamp: x_0_hat = x_0_hat.clamp(-1,1)
    if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
    x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
    x_t += sig * torch.randn(x_t.shape).to(x_t)
    return x_0_hat,x_t

# %%
#| export
@torch.no_grad()
def sample(f, model, sz, steps, eta=1., clamp=True, progress=False):
    model.eval()
    ts = torch.linspace(1-1/steps,0,steps)
    x_t = torch.randn(sz).cuda()
    preds = []
    tbe = progress_bar(ts) if progress else ts 
    for i,t in enumerate(tbe):
        t = t[None].cuda()
        abar_t = abar(t)
        noise = model((x_t, t))
        abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
        x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
        preds.append(x_0_hat.float().cpu())
    return preds

# %%
import wandb

class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project='ddpm_goldfish_64x64_clip', **metrics):
        fc.store_attr()
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d):
        #import pdb; pdb.set_trace()
        if learn.model.training: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
            wandb.log({'samples':self.sample_figure(learn)})
        print(d)

        
    def sample_figure(self, learn):
        with torch.no_grad():
            preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
        s = to_cpu(vae.decode(preds[-1].cuda()*5))
        s = s['sample'].clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16, imsize=3)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME'] = '09_diffusion-attn-cond_tin_goldfish_64x64_CLIP_i3.ipynb'
lr = 1e-4
epochs = 2000
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512), num_layers=2, attn_chans=0, attn_start=1, n_mids=10)'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
#model = EmbUNetModel(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2)
model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512,1024), num_layers=2, attn_chans=4, attn_start=0, n_mids=1)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# wandb: Currently logged in as: dumbdude (dumbdude-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_111233-tibbqy7v</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/tibbqy7v' target="_blank">dark-galaxy-5</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/tibbqy7v' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/tibbqy7v</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'loss': '1.112', 'epoch': 0, 'train': 'train'}
# {'loss': '1.006', 'epoch': 0, 'train': 'eval'}
# {'loss': '1.101', 'epoch': 1, 'train': 'train'}
# {'loss': '1.003', 'epoch': 1, 'train': 'eval'}
# {'loss': '1.097', 'epoch': 2, 'train': 'train'}
# {'loss': '1.016', 'epoch': 2, 'train': 'eval'}
# {'loss': '1.078', 'epoch': 3, 'train': 'train'}
# {'loss': '1.014', 'epoch': 3, 'train': 'eval'}
# {'loss': '1.072', 'epoch': 4, 'train': 'train'}
# {'loss': '0.998', 'epoch': 4, 'train': 'eval'}
# {'loss': '1.065', 'epoch': 5, 'train': 'train'}
# {'loss': '0.988', 'epoch': 5, 'train': 'eval'}
# {'loss': '1.053', 'epoch': 6, 'train': 'train'}
# {'loss': '1.011', 'epoch': 6, 'train': 'eval'}
# {'loss': '1.051', 'epoch': 7, 'train': 'train'}
# {'loss': '1.008', 'epoch': 7, 'train': 'eval'}
# {'loss': '1.041', 'epoch': 8, 'train': 'train'}
# {'loss': '0.998', 'epoch': 8, 'train': 'eval'}
# {'loss': '1.043', 'epoch': 9, 'train': 'train'}
# {'loss': '1.009', 'epoch': 9, 'train': 'eval'}
# {'loss': '1.041', 'epoch': 10, 'train': 'train'}
# {'loss': '1.005', 'epoch': 10, 'train': 'eval'}
# {'loss': '1.033', 'epoch': 11, 'train': 'train'}
# {'loss': '1.002', 'epoch': 11, 'train': 'eval'}
# {'loss': '1.025', 'epoch': 12, 'train': 'train'}
# {'loss': '0.999', 'epoch': 12, 'train': 'eval'}
# {'loss': '1.023', 'epoch': 13, 'train': 'train'}
# {'loss': '1.008', 'epoch': 13, 'train': 'eval'}
# {'loss': '1.018', 'epoch': 14, 'train': 'train'}
# {'loss': '1.003', 'epoch': 14, 'train': 'eval'}
# {'loss': '1.007', 'epoch': 15, 'train': 'train'}
# {'loss': '0.981', 'epoch': 15, 'train': 'eval'}
# {'loss': '1.008', 'epoch': 16, 'train': 'train'}
# {'loss': '1.005', 'epoch': 16, 'train': 'eval'}
# {'loss': '1.004', 'epoch': 17, 'train': 'train'}
# {'loss': '0.994', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.994', 'epoch': 18, 'train': 'train'}
# {'loss': '0.993', 'epoch': 18, 'train': 'eval'}
# {'loss': '1.000', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.973', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.992', 'epoch': 20, 'train': 'train'}
# {'loss': '1.002', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.987', 'epoch': 21, 'train': 'train'}
# {'loss': '0.979', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.982', 'epoch': 22, 'train': 'train'}
# {'loss': '0.987', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.977', 'epoch': 23, 'train': 'train'}
# {'loss': '0.972', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.976', 'epoch': 24, 'train': 'train'}
# {'loss': '0.989', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.971', 'epoch': 25, 'train': 'train'}
# {'loss': '0.977', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.967', 'epoch': 26, 'train': 'train'}
# {'loss': '0.983', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.962', 'epoch': 27, 'train': 'train'}
# {'loss': '0.974', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.958', 'epoch': 28, 'train': 'train'}
# {'loss': '0.969', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.954', 'epoch': 29, 'train': 'train'}
# {'loss': '0.955', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.950', 'epoch': 30, 'train': 'train'}
# {'loss': '0.975', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.946', 'epoch': 31, 'train': 'train'}
# {'loss': '0.968', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.946', 'epoch': 32, 'train': 'train'}
# {'loss': '0.946', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.934', 'epoch': 33, 'train': 'train'}
# {'loss': '0.943', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.942', 'epoch': 34, 'train': 'train'}
# {'loss': '0.937', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.932', 'epoch': 35, 'train': 'train'}
# {'loss': '0.923', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.929', 'epoch': 36, 'train': 'train'}
# {'loss': '0.948', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.920', 'epoch': 37, 'train': 'train'}
# {'loss': '0.938', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.919', 'epoch': 38, 'train': 'train'}
# {'loss': '0.936', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.911', 'epoch': 39, 'train': 'train'}
# {'loss': '0.937', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.916', 'epoch': 40, 'train': 'train'}
# {'loss': '0.910', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.919', 'epoch': 41, 'train': 'train'}
# {'loss': '0.905', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.901', 'epoch': 42, 'train': 'train'}
# {'loss': '0.895', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.902', 'epoch': 43, 'train': 'train'}
# {'loss': '0.908', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.902', 'epoch': 44, 'train': 'train'}
# {'loss': '0.890', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.895', 'epoch': 45, 'train': 'train'}
# {'loss': '0.874', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.892', 'epoch': 46, 'train': 'train'}
# {'loss': '0.891', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.881', 'epoch': 47, 'train': 'train'}
# {'loss': '0.856', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.879', 'epoch': 48, 'train': 'train'}
# {'loss': '0.873', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.870', 'epoch': 49, 'train': 'train'}
# {'loss': '0.881', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.866', 'epoch': 50, 'train': 'train'}
# {'loss': '0.873', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.867', 'epoch': 51, 'train': 'train'}
# {'loss': '0.871', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.862', 'epoch': 52, 'train': 'train'}
# {'loss': '0.859', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.854', 'epoch': 53, 'train': 'train'}
# {'loss': '0.839', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.851', 'epoch': 54, 'train': 'train'}
# {'loss': '0.843', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.851', 'epoch': 55, 'train': 'train'}
# {'loss': '0.828', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.842', 'epoch': 56, 'train': 'train'}
# {'loss': '0.830', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.831', 'epoch': 57, 'train': 'train'}
# {'loss': '0.838', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.833', 'epoch': 58, 'train': 'train'}
# {'loss': '0.799', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.827', 'epoch': 59, 'train': 'train'}
# {'loss': '0.808', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.823', 'epoch': 60, 'train': 'train'}
# {'loss': '0.825', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.823', 'epoch': 61, 'train': 'train'}
# {'loss': '0.799', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.808', 'epoch': 62, 'train': 'train'}
# {'loss': '0.786', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.809', 'epoch': 63, 'train': 'train'}
# {'loss': '0.795', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.802', 'epoch': 64, 'train': 'train'}
# {'loss': '0.785', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.799', 'epoch': 65, 'train': 'train'}
# {'loss': '0.802', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.798', 'epoch': 66, 'train': 'train'}
# {'loss': '0.781', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.800', 'epoch': 67, 'train': 'train'}
# {'loss': '0.771', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.785', 'epoch': 68, 'train': 'train'}
# {'loss': '0.765', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.781', 'epoch': 69, 'train': 'train'}
# {'loss': '0.808', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.775', 'epoch': 70, 'train': 'train'}
# {'loss': '0.725', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.765', 'epoch': 71, 'train': 'train'}
# {'loss': '0.786', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.766', 'epoch': 72, 'train': 'train'}
# {'loss': '0.747', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.764', 'epoch': 73, 'train': 'train'}
# {'loss': '0.757', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.750', 'epoch': 74, 'train': 'train'}
# {'loss': '0.756', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.746', 'epoch': 75, 'train': 'train'}
# {'loss': '0.739', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.742', 'epoch': 76, 'train': 'train'}
# {'loss': '0.742', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.744', 'epoch': 77, 'train': 'train'}
# {'loss': '0.751', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.730', 'epoch': 78, 'train': 'train'}
# {'loss': '0.732', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.729', 'epoch': 79, 'train': 'train'}
# {'loss': '0.701', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.715', 'epoch': 80, 'train': 'train'}
# {'loss': '0.734', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.712', 'epoch': 81, 'train': 'train'}
# {'loss': '0.694', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.717', 'epoch': 82, 'train': 'train'}
# {'loss': '0.731', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.701', 'epoch': 83, 'train': 'train'}
# {'loss': '0.690', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.699', 'epoch': 84, 'train': 'train'}
# {'loss': '0.703', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.689', 'epoch': 85, 'train': 'train'}
# {'loss': '0.657', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.696', 'epoch': 86, 'train': 'train'}
# {'loss': '0.697', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.687', 'epoch': 87, 'train': 'train'}
# {'loss': '0.680', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.670', 'epoch': 88, 'train': 'train'}
# {'loss': '0.682', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.672', 'epoch': 89, 'train': 'train'}
# {'loss': '0.638', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.672', 'epoch': 90, 'train': 'train'}
# {'loss': '0.673', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.658', 'epoch': 91, 'train': 'train'}
# {'loss': '0.646', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.648', 'epoch': 92, 'train': 'train'}
# {'loss': '0.656', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.652', 'epoch': 93, 'train': 'train'}
# {'loss': '0.691', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.642', 'epoch': 94, 'train': 'train'}
# {'loss': '0.662', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.633', 'epoch': 95, 'train': 'train'}
# {'loss': '0.655', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.633', 'epoch': 96, 'train': 'train'}
# {'loss': '0.640', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.639', 'epoch': 97, 'train': 'train'}
# {'loss': '0.624', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.617', 'epoch': 98, 'train': 'train'}
# {'loss': '0.627', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.621', 'epoch': 99, 'train': 'train'}
# {'loss': '0.603', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.612', 'epoch': 100, 'train': 'train'}
# {'loss': '0.593', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.609', 'epoch': 101, 'train': 'train'}
# {'loss': '0.605', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.593', 'epoch': 102, 'train': 'train'}
# {'loss': '0.643', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.593', 'epoch': 103, 'train': 'train'}
# {'loss': '0.613', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.597', 'epoch': 104, 'train': 'train'}
# {'loss': '0.588', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.584', 'epoch': 105, 'train': 'train'}
# {'loss': '0.600', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.575', 'epoch': 106, 'train': 'train'}
# {'loss': '0.565', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.576', 'epoch': 107, 'train': 'train'}
# {'loss': '0.595', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.582', 'epoch': 108, 'train': 'train'}
# {'loss': '0.567', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.577', 'epoch': 109, 'train': 'train'}
# {'loss': '0.528', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.565', 'epoch': 110, 'train': 'train'}
# {'loss': '0.590', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.561', 'epoch': 111, 'train': 'train'}
# {'loss': '0.618', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.562', 'epoch': 112, 'train': 'train'}
# {'loss': '0.517', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.553', 'epoch': 113, 'train': 'train'}
# {'loss': '0.526', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.541', 'epoch': 114, 'train': 'train'}
# {'loss': '0.572', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.552', 'epoch': 115, 'train': 'train'}
# {'loss': '0.509', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.540', 'epoch': 116, 'train': 'train'}
# {'loss': '0.595', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.535', 'epoch': 117, 'train': 'train'}
# {'loss': '0.528', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.533', 'epoch': 118, 'train': 'train'}
# {'loss': '0.523', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.535', 'epoch': 119, 'train': 'train'}
# {'loss': '0.503', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.529', 'epoch': 120, 'train': 'train'}
# {'loss': '0.551', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.519', 'epoch': 121, 'train': 'train'}
# {'loss': '0.535', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.523', 'epoch': 122, 'train': 'train'}
# {'loss': '0.527', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.518', 'epoch': 123, 'train': 'train'}
# {'loss': '0.485', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.511', 'epoch': 124, 'train': 'train'}
# {'loss': '0.501', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.519', 'epoch': 125, 'train': 'train'}
# {'loss': '0.505', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.521', 'epoch': 126, 'train': 'train'}
# {'loss': '0.503', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.496', 'epoch': 127, 'train': 'train'}
# {'loss': '0.528', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.492', 'epoch': 128, 'train': 'train'}
# {'loss': '0.511', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.507', 'epoch': 129, 'train': 'train'}
# {'loss': '0.516', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.509', 'epoch': 130, 'train': 'train'}
# {'loss': '0.478', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.508', 'epoch': 131, 'train': 'train'}
# {'loss': '0.531', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.491', 'epoch': 132, 'train': 'train'}
# {'loss': '0.471', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.497', 'epoch': 133, 'train': 'train'}
# {'loss': '0.511', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.497', 'epoch': 134, 'train': 'train'}
# {'loss': '0.499', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.499', 'epoch': 135, 'train': 'train'}
# {'loss': '0.442', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.489', 'epoch': 136, 'train': 'train'}
# {'loss': '0.494', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.475', 'epoch': 137, 'train': 'train'}
# {'loss': '0.517', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.488', 'epoch': 138, 'train': 'train'}
# {'loss': '0.502', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.475', 'epoch': 139, 'train': 'train'}
# {'loss': '0.476', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.491', 'epoch': 140, 'train': 'train'}
# {'loss': '0.498', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.470', 'epoch': 141, 'train': 'train'}
# {'loss': '0.517', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.490', 'epoch': 142, 'train': 'train'}
# {'loss': '0.465', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.455', 'epoch': 143, 'train': 'train'}
# {'loss': '0.502', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.469', 'epoch': 144, 'train': 'train'}
# {'loss': '0.462', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.479', 'epoch': 145, 'train': 'train'}
# {'loss': '0.517', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.457', 'epoch': 146, 'train': 'train'}
# {'loss': '0.416', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.481', 'epoch': 147, 'train': 'train'}
# {'loss': '0.463', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.476', 'epoch': 148, 'train': 'train'}
# {'loss': '0.440', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.485', 'epoch': 149, 'train': 'train'}
# {'loss': '0.432', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 150, 'train': 'train'}
# {'loss': '0.403', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.469', 'epoch': 151, 'train': 'train'}
# {'loss': '0.453', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.486', 'epoch': 152, 'train': 'train'}
# {'loss': '0.495', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.469', 'epoch': 153, 'train': 'train'}
# {'loss': '0.468', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 154, 'train': 'train'}
# {'loss': '0.419', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.468', 'epoch': 155, 'train': 'train'}
# {'loss': '0.438', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.435', 'epoch': 156, 'train': 'train'}
# {'loss': '0.467', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.441', 'epoch': 157, 'train': 'train'}
# {'loss': '0.426', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.459', 'epoch': 158, 'train': 'train'}
# {'loss': '0.480', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.468', 'epoch': 159, 'train': 'train'}
# {'loss': '0.472', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 160, 'train': 'train'}
# {'loss': '0.466', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.445', 'epoch': 161, 'train': 'train'}
# {'loss': '0.468', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 162, 'train': 'train'}
# {'loss': '0.462', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.458', 'epoch': 163, 'train': 'train'}
# {'loss': '0.482', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 164, 'train': 'train'}
# {'loss': '0.447', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.449', 'epoch': 165, 'train': 'train'}
# {'loss': '0.470', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.442', 'epoch': 166, 'train': 'train'}
# {'loss': '0.460', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.450', 'epoch': 167, 'train': 'train'}
# {'loss': '0.486', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 168, 'train': 'train'}
# {'loss': '0.421', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.449', 'epoch': 169, 'train': 'train'}
# {'loss': '0.442', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.457', 'epoch': 170, 'train': 'train'}
# {'loss': '0.437', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.447', 'epoch': 171, 'train': 'train'}
# {'loss': '0.407', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.421', 'epoch': 172, 'train': 'train'}
# {'loss': '0.504', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.446', 'epoch': 173, 'train': 'train'}
# {'loss': '0.428', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 174, 'train': 'train'}
# {'loss': '0.424', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.449', 'epoch': 175, 'train': 'train'}
# {'loss': '0.476', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.441', 'epoch': 176, 'train': 'train'}
# {'loss': '0.420', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.437', 'epoch': 177, 'train': 'train'}
# {'loss': '0.403', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.428', 'epoch': 178, 'train': 'train'}
# {'loss': '0.449', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 179, 'train': 'train'}
# {'loss': '0.482', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.431', 'epoch': 180, 'train': 'train'}
# {'loss': '0.454', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.436', 'epoch': 181, 'train': 'train'}
# {'loss': '0.414', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.429', 'epoch': 182, 'train': 'train'}
# {'loss': '0.500', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.437', 'epoch': 183, 'train': 'train'}
# {'loss': '0.425', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 184, 'train': 'train'}
# {'loss': '0.409', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 185, 'train': 'train'}
# {'loss': '0.387', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.425', 'epoch': 186, 'train': 'train'}
# {'loss': '0.484', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.431', 'epoch': 187, 'train': 'train'}
# {'loss': '0.422', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.432', 'epoch': 188, 'train': 'train'}
# {'loss': '0.424', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 189, 'train': 'train'}
# {'loss': '0.467', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 190, 'train': 'train'}
# {'loss': '0.418', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 191, 'train': 'train'}
# {'loss': '0.469', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.428', 'epoch': 192, 'train': 'train'}
# {'loss': '0.510', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 193, 'train': 'train'}
# {'loss': '0.439', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 194, 'train': 'train'}
# {'loss': '0.394', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 195, 'train': 'train'}
# {'loss': '0.500', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.425', 'epoch': 196, 'train': 'train'}
# {'loss': '0.450', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.430', 'epoch': 197, 'train': 'train'}
# {'loss': '0.413', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 198, 'train': 'train'}
# {'loss': '0.423', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.427', 'epoch': 199, 'train': 'train'}
# {'loss': '0.455', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.423', 'epoch': 200, 'train': 'train'}
# {'loss': '0.394', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.430', 'epoch': 201, 'train': 'train'}
# {'loss': '0.369', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 202, 'train': 'train'}
# {'loss': '0.428', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 203, 'train': 'train'}
# {'loss': '0.404', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.418', 'epoch': 204, 'train': 'train'}
# {'loss': '0.428', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.418', 'epoch': 205, 'train': 'train'}
# {'loss': '0.460', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 206, 'train': 'train'}
# {'loss': '0.437', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.412', 'epoch': 207, 'train': 'train'}
# {'loss': '0.428', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 208, 'train': 'train'}
# {'loss': '0.468', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.411', 'epoch': 209, 'train': 'train'}
# {'loss': '0.408', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.409', 'epoch': 210, 'train': 'train'}
# {'loss': '0.460', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.420', 'epoch': 211, 'train': 'train'}
# {'loss': '0.481', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.394', 'epoch': 212, 'train': 'train'}
# {'loss': '0.450', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 213, 'train': 'train'}
# {'loss': '0.431', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.401', 'epoch': 214, 'train': 'train'}
# {'loss': '0.474', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 215, 'train': 'train'}
# {'loss': '0.452', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 216, 'train': 'train'}
# {'loss': '0.419', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.406', 'epoch': 217, 'train': 'train'}
# {'loss': '0.454', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 218, 'train': 'train'}
# {'loss': '0.437', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.405', 'epoch': 219, 'train': 'train'}
# {'loss': '0.407', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 220, 'train': 'train'}
# {'loss': '0.424', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.400', 'epoch': 221, 'train': 'train'}
# {'loss': '0.389', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 222, 'train': 'train'}
# {'loss': '0.444', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.397', 'epoch': 223, 'train': 'train'}
# {'loss': '0.374', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.389', 'epoch': 224, 'train': 'train'}
# {'loss': '0.407', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.381', 'epoch': 225, 'train': 'train'}
# {'loss': '0.423', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 226, 'train': 'train'}
# {'loss': '0.422', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.409', 'epoch': 227, 'train': 'train'}
# {'loss': '0.378', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 228, 'train': 'train'}
# {'loss': '0.430', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.409', 'epoch': 229, 'train': 'train'}
# {'loss': '0.409', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 230, 'train': 'train'}
# {'loss': '0.404', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.393', 'epoch': 231, 'train': 'train'}
# {'loss': '0.415', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.408', 'epoch': 232, 'train': 'train'}
# {'loss': '0.413', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 233, 'train': 'train'}
# {'loss': '0.336', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 234, 'train': 'train'}
# {'loss': '0.371', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 235, 'train': 'train'}
# {'loss': '0.472', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 236, 'train': 'train'}
# {'loss': '0.392', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 237, 'train': 'train'}
# {'loss': '0.408', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.409', 'epoch': 238, 'train': 'train'}
# {'loss': '0.470', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.406', 'epoch': 239, 'train': 'train'}
# {'loss': '0.422', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 240, 'train': 'train'}
# {'loss': '0.418', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 241, 'train': 'train'}
# {'loss': '0.364', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 242, 'train': 'train'}
# {'loss': '0.388', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 243, 'train': 'train'}
# {'loss': '0.362', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 244, 'train': 'train'}
# {'loss': '0.466', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 245, 'train': 'train'}
# {'loss': '0.365', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 246, 'train': 'train'}
# {'loss': '0.393', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.393', 'epoch': 247, 'train': 'train'}
# {'loss': '0.392', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 248, 'train': 'train'}
# {'loss': '0.428', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 249, 'train': 'train'}
# {'loss': '0.402', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 250, 'train': 'train'}
# {'loss': '0.435', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 251, 'train': 'train'}
# {'loss': '0.347', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.401', 'epoch': 252, 'train': 'train'}
# {'loss': '0.389', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 253, 'train': 'train'}
# {'loss': '0.388', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 254, 'train': 'train'}
# {'loss': '0.316', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 255, 'train': 'train'}
# {'loss': '0.386', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 256, 'train': 'train'}
# {'loss': '0.418', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 257, 'train': 'train'}
# {'loss': '0.410', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 258, 'train': 'train'}
# {'loss': '0.404', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 259, 'train': 'train'}
# {'loss': '0.362', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 260, 'train': 'train'}
# {'loss': '0.358', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.381', 'epoch': 261, 'train': 'train'}
# {'loss': '0.347', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 262, 'train': 'train'}
# {'loss': '0.344', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 263, 'train': 'train'}
# {'loss': '0.395', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.397', 'epoch': 264, 'train': 'train'}
# {'loss': '0.382', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 265, 'train': 'train'}
# {'loss': '0.378', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 266, 'train': 'train'}
# {'loss': '0.408', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 267, 'train': 'train'}
# {'loss': '0.401', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 268, 'train': 'train'}
# {'loss': '0.392', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 269, 'train': 'train'}
# {'loss': '0.371', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 270, 'train': 'train'}
# {'loss': '0.350', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 271, 'train': 'train'}
# {'loss': '0.411', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 272, 'train': 'train'}
# {'loss': '0.419', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 273, 'train': 'train'}
# {'loss': '0.372', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 274, 'train': 'train'}
# {'loss': '0.333', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 275, 'train': 'train'}
# {'loss': '0.358', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 276, 'train': 'train'}
# {'loss': '0.326', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 277, 'train': 'train'}
# {'loss': '0.354', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 278, 'train': 'train'}
# {'loss': '0.349', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 279, 'train': 'train'}
# {'loss': '0.326', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.381', 'epoch': 280, 'train': 'train'}
# {'loss': '0.396', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 281, 'train': 'train'}
# {'loss': '0.342', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 282, 'train': 'train'}
# {'loss': '0.398', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 283, 'train': 'train'}
# {'loss': '0.392', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 284, 'train': 'train'}
# {'loss': '0.380', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 285, 'train': 'train'}
# {'loss': '0.338', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 286, 'train': 'train'}
# {'loss': '0.362', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 287, 'train': 'train'}
# {'loss': '0.393', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 288, 'train': 'train'}
# {'loss': '0.394', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.391', 'epoch': 289, 'train': 'train'}
# {'loss': '0.382', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 290, 'train': 'train'}
# {'loss': '0.359', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 291, 'train': 'train'}
# {'loss': '0.419', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 292, 'train': 'train'}
# {'loss': '0.407', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 293, 'train': 'train'}
# {'loss': '0.341', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 294, 'train': 'train'}
# {'loss': '0.411', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 295, 'train': 'train'}
# {'loss': '0.390', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 296, 'train': 'train'}
# {'loss': '0.370', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 297, 'train': 'train'}
# {'loss': '0.379', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 298, 'train': 'train'}
# {'loss': '0.342', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 299, 'train': 'train'}
# {'loss': '0.383', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 300, 'train': 'train'}
# {'loss': '0.375', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 301, 'train': 'train'}
# {'loss': '0.390', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 302, 'train': 'train'}
# {'loss': '0.374', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 303, 'train': 'train'}
# {'loss': '0.418', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 304, 'train': 'train'}
# {'loss': '0.426', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 305, 'train': 'train'}
# {'loss': '0.404', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 306, 'train': 'train'}
# {'loss': '0.326', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 307, 'train': 'train'}
# {'loss': '0.420', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 308, 'train': 'train'}
# {'loss': '0.381', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 309, 'train': 'train'}
# {'loss': '0.391', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 310, 'train': 'train'}
# {'loss': '0.423', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 311, 'train': 'train'}
# {'loss': '0.396', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 312, 'train': 'train'}
# {'loss': '0.417', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 313, 'train': 'train'}
# {'loss': '0.408', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 314, 'train': 'train'}
# {'loss': '0.433', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 315, 'train': 'train'}
# {'loss': '0.380', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 316, 'train': 'train'}
# {'loss': '0.397', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 317, 'train': 'train'}
# {'loss': '0.370', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 318, 'train': 'train'}
# {'loss': '0.352', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 319, 'train': 'train'}
# {'loss': '0.384', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 320, 'train': 'train'}
# {'loss': '0.418', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 321, 'train': 'train'}
# {'loss': '0.396', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 322, 'train': 'train'}
# {'loss': '0.419', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 323, 'train': 'train'}
# {'loss': '0.367', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 324, 'train': 'train'}
# {'loss': '0.415', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 325, 'train': 'train'}
# {'loss': '0.353', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 326, 'train': 'train'}
# {'loss': '0.302', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 327, 'train': 'train'}
# {'loss': '0.344', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 328, 'train': 'train'}
# {'loss': '0.397', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 329, 'train': 'train'}
# {'loss': '0.385', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 330, 'train': 'train'}
# {'loss': '0.334', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 331, 'train': 'train'}
# {'loss': '0.335', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 332, 'train': 'train'}
# {'loss': '0.328', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 333, 'train': 'train'}
# {'loss': '0.333', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 334, 'train': 'train'}
# {'loss': '0.358', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 335, 'train': 'train'}
# {'loss': '0.338', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 336, 'train': 'train'}
# {'loss': '0.351', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 337, 'train': 'train'}
# {'loss': '0.402', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 338, 'train': 'train'}
# {'loss': '0.352', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 339, 'train': 'train'}
# {'loss': '0.394', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 340, 'train': 'train'}
# {'loss': '0.412', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 341, 'train': 'train'}
# {'loss': '0.395', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 342, 'train': 'train'}
# {'loss': '0.396', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 343, 'train': 'train'}
# {'loss': '0.339', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 344, 'train': 'train'}
# {'loss': '0.416', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 345, 'train': 'train'}
# {'loss': '0.365', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 346, 'train': 'train'}
# {'loss': '0.381', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 347, 'train': 'train'}
# {'loss': '0.358', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 348, 'train': 'train'}
# {'loss': '0.379', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 349, 'train': 'train'}
# {'loss': '0.395', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 350, 'train': 'train'}
# {'loss': '0.392', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 351, 'train': 'train'}
# {'loss': '0.344', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 352, 'train': 'train'}
# {'loss': '0.369', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 353, 'train': 'train'}
# {'loss': '0.366', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 354, 'train': 'train'}
# {'loss': '0.412', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 355, 'train': 'train'}
# {'loss': '0.386', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 356, 'train': 'train'}
# {'loss': '0.419', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 357, 'train': 'train'}
# {'loss': '0.364', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 358, 'train': 'train'}
# {'loss': '0.355', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 359, 'train': 'train'}
# {'loss': '0.416', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 360, 'train': 'train'}
# {'loss': '0.334', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 361, 'train': 'train'}
# {'loss': '0.327', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 362, 'train': 'train'}
# {'loss': '0.392', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 363, 'train': 'train'}
# {'loss': '0.369', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 364, 'train': 'train'}
# {'loss': '0.378', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 365, 'train': 'train'}
# {'loss': '0.403', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 366, 'train': 'train'}
# {'loss': '0.374', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 367, 'train': 'train'}
# {'loss': '0.354', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 368, 'train': 'train'}
# {'loss': '0.378', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 369, 'train': 'train'}
# {'loss': '0.407', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 370, 'train': 'train'}
# {'loss': '0.357', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 371, 'train': 'train'}
# {'loss': '0.347', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 372, 'train': 'train'}
# {'loss': '0.373', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 373, 'train': 'train'}
# {'loss': '0.394', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 374, 'train': 'train'}
# {'loss': '0.377', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 375, 'train': 'train'}
# {'loss': '0.407', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 376, 'train': 'train'}
# {'loss': '0.350', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 377, 'train': 'train'}
# {'loss': '0.379', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 378, 'train': 'train'}
# {'loss': '0.418', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 379, 'train': 'train'}
# {'loss': '0.450', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 380, 'train': 'train'}
# {'loss': '0.354', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 381, 'train': 'train'}
# {'loss': '0.417', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 382, 'train': 'train'}
# {'loss': '0.324', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 383, 'train': 'train'}
# {'loss': '0.401', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 384, 'train': 'train'}
# {'loss': '0.359', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 385, 'train': 'train'}
# {'loss': '0.389', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 386, 'train': 'train'}
# {'loss': '0.458', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 387, 'train': 'train'}
# {'loss': '0.432', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 388, 'train': 'train'}
# {'loss': '0.338', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 389, 'train': 'train'}
# {'loss': '0.423', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 390, 'train': 'train'}
# {'loss': '0.424', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 391, 'train': 'train'}
# {'loss': '0.374', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 392, 'train': 'train'}
# {'loss': '0.306', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 393, 'train': 'train'}
# {'loss': '0.401', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 394, 'train': 'train'}
# {'loss': '0.364', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 395, 'train': 'train'}
# {'loss': '0.310', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 396, 'train': 'train'}
# {'loss': '0.402', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 397, 'train': 'train'}
# {'loss': '0.390', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 398, 'train': 'train'}
# {'loss': '0.389', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 399, 'train': 'train'}
# {'loss': '0.328', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 400, 'train': 'train'}
# {'loss': '0.453', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 401, 'train': 'train'}
# {'loss': '0.349', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.321', 'epoch': 402, 'train': 'train'}
# {'loss': '0.387', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 403, 'train': 'train'}
# {'loss': '0.392', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 404, 'train': 'train'}
# {'loss': '0.408', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 405, 'train': 'train'}
# {'loss': '0.331', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 406, 'train': 'train'}
# {'loss': '0.396', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 407, 'train': 'train'}
# {'loss': '0.374', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 408, 'train': 'train'}
# {'loss': '0.387', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 409, 'train': 'train'}
# {'loss': '0.385', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 410, 'train': 'train'}
# {'loss': '0.450', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 411, 'train': 'train'}
# {'loss': '0.412', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 412, 'train': 'train'}
# {'loss': '0.363', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 413, 'train': 'train'}
# {'loss': '0.381', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 414, 'train': 'train'}
# {'loss': '0.436', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 415, 'train': 'train'}
# {'loss': '0.386', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 416, 'train': 'train'}
# {'loss': '0.329', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 417, 'train': 'train'}
# {'loss': '0.356', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 418, 'train': 'train'}
# {'loss': '0.373', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 419, 'train': 'train'}
# {'loss': '0.301', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 420, 'train': 'train'}
# {'loss': '0.410', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 421, 'train': 'train'}
# {'loss': '0.324', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 422, 'train': 'train'}
# {'loss': '0.413', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 423, 'train': 'train'}
# {'loss': '0.398', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 424, 'train': 'train'}
# {'loss': '0.341', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 425, 'train': 'train'}
# {'loss': '0.321', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 426, 'train': 'train'}
# {'loss': '0.402', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 427, 'train': 'train'}
# {'loss': '0.431', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 428, 'train': 'train'}
# {'loss': '0.311', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 429, 'train': 'train'}
# {'loss': '0.378', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 430, 'train': 'train'}
# {'loss': '0.383', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 431, 'train': 'train'}
# {'loss': '0.348', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 432, 'train': 'train'}
# {'loss': '0.437', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 433, 'train': 'train'}
# {'loss': '0.420', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 434, 'train': 'train'}
# {'loss': '0.394', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 435, 'train': 'train'}
# {'loss': '0.402', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 436, 'train': 'train'}
# {'loss': '0.349', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 437, 'train': 'train'}
# {'loss': '0.367', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 438, 'train': 'train'}
# {'loss': '0.403', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 439, 'train': 'train'}
# {'loss': '0.400', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 440, 'train': 'train'}
# {'loss': '0.374', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 441, 'train': 'train'}
# {'loss': '0.413', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 442, 'train': 'train'}
# {'loss': '0.476', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 443, 'train': 'train'}
# {'loss': '0.355', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 444, 'train': 'train'}
# {'loss': '0.363', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 445, 'train': 'train'}
# {'loss': '0.367', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 446, 'train': 'train'}
# {'loss': '0.428', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 447, 'train': 'train'}
# {'loss': '0.321', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 448, 'train': 'train'}
# {'loss': '0.423', 'epoch': 448, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 449, 'train': 'train'}
# {'loss': '0.404', 'epoch': 449, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 450, 'train': 'train'}
# {'loss': '0.385', 'epoch': 450, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 451, 'train': 'train'}
# {'loss': '0.375', 'epoch': 451, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 452, 'train': 'train'}
# {'loss': '0.328', 'epoch': 452, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 453, 'train': 'train'}
# {'loss': '0.432', 'epoch': 453, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 454, 'train': 'train'}
# {'loss': '0.355', 'epoch': 454, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 455, 'train': 'train'}
# {'loss': '0.366', 'epoch': 455, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 456, 'train': 'train'}
# {'loss': '0.356', 'epoch': 456, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 457, 'train': 'train'}
# {'loss': '0.323', 'epoch': 457, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 458, 'train': 'train'}
# {'loss': '0.394', 'epoch': 458, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 459, 'train': 'train'}
# {'loss': '0.342', 'epoch': 459, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 460, 'train': 'train'}
# {'loss': '0.379', 'epoch': 460, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 461, 'train': 'train'}
# {'loss': '0.367', 'epoch': 461, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 462, 'train': 'train'}
# {'loss': '0.329', 'epoch': 462, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 463, 'train': 'train'}
# {'loss': '0.394', 'epoch': 463, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 464, 'train': 'train'}
# {'loss': '0.389', 'epoch': 464, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 465, 'train': 'train'}
# {'loss': '0.378', 'epoch': 465, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 466, 'train': 'train'}
# {'loss': '0.313', 'epoch': 466, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 467, 'train': 'train'}
# {'loss': '0.293', 'epoch': 467, 'train': 'eval'}
# ...
# {'loss': '0.042', 'epoch': 1859, 'train': 'train'}
# {'loss': '1.692', 'epoch': 1859, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1860, 'train': 'train'}
# {'loss': '2.094', 'epoch': 1860, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1861, 'train': 'train'}
# {'loss': '1.735', 'epoch': 1861, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1862, 'train': 'train'}
# {'loss': '1.707', 'epoch': 1862, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1863, 'train': 'train'}
# {'loss': '1.400', 'epoch': 1863, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1864, 'train': 'train'}
# {'loss': '1.956', 'epoch': 1864, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1865, 'train': 'train'}
# {'loss': '1.697', 'epoch': 1865, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1866, 'train': 'train'}
# {'loss': '1.728', 'epoch': 1866, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1867, 'train': 'train'}
# {'loss': '1.694', 'epoch': 1867, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1868, 'train': 'train'}
# {'loss': '2.142', 'epoch': 1868, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1869, 'train': 'train'}
# {'loss': '1.944', 'epoch': 1869, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1870, 'train': 'train'}
# {'loss': '1.983', 'epoch': 1870, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1871, 'train': 'train'}
# {'loss': '1.859', 'epoch': 1871, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1872, 'train': 'train'}
# {'loss': '2.058', 'epoch': 1872, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1873, 'train': 'train'}
# {'loss': '1.674', 'epoch': 1873, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1874, 'train': 'train'}
# {'loss': '1.801', 'epoch': 1874, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1875, 'train': 'train'}
# {'loss': '1.320', 'epoch': 1875, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1876, 'train': 'train'}
# {'loss': '2.961', 'epoch': 1876, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1877, 'train': 'train'}
# {'loss': '2.687', 'epoch': 1877, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1878, 'train': 'train'}
# {'loss': '1.883', 'epoch': 1878, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1879, 'train': 'train'}
# {'loss': '2.131', 'epoch': 1879, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1880, 'train': 'train'}
# {'loss': '2.627', 'epoch': 1880, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1881, 'train': 'train'}
# {'loss': '1.748', 'epoch': 1881, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1882, 'train': 'train'}
# {'loss': '1.933', 'epoch': 1882, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1883, 'train': 'train'}
# {'loss': '2.837', 'epoch': 1883, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1884, 'train': 'train'}
# {'loss': '1.211', 'epoch': 1884, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1885, 'train': 'train'}
# {'loss': '1.990', 'epoch': 1885, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1886, 'train': 'train'}
# {'loss': '1.643', 'epoch': 1886, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1887, 'train': 'train'}
# {'loss': '2.073', 'epoch': 1887, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1888, 'train': 'train'}
# {'loss': '1.737', 'epoch': 1888, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1889, 'train': 'train'}
# {'loss': '2.390', 'epoch': 1889, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1890, 'train': 'train'}
# {'loss': '1.891', 'epoch': 1890, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1891, 'train': 'train'}
# {'loss': '1.559', 'epoch': 1891, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1892, 'train': 'train'}
# {'loss': '2.773', 'epoch': 1892, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1893, 'train': 'train'}
# {'loss': '2.539', 'epoch': 1893, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1894, 'train': 'train'}
# {'loss': '1.811', 'epoch': 1894, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1895, 'train': 'train'}
# {'loss': '2.334', 'epoch': 1895, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1896, 'train': 'train'}
# {'loss': '1.625', 'epoch': 1896, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1897, 'train': 'train'}
# {'loss': '2.131', 'epoch': 1897, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1898, 'train': 'train'}
# {'loss': '2.140', 'epoch': 1898, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1899, 'train': 'train'}
# {'loss': '1.805', 'epoch': 1899, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1900, 'train': 'train'}
# {'loss': '2.101', 'epoch': 1900, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1901, 'train': 'train'}
# {'loss': '2.100', 'epoch': 1901, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1902, 'train': 'train'}
# {'loss': '1.812', 'epoch': 1902, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1903, 'train': 'train'}
# {'loss': '1.896', 'epoch': 1903, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1904, 'train': 'train'}
# {'loss': '1.399', 'epoch': 1904, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1905, 'train': 'train'}
# {'loss': '1.500', 'epoch': 1905, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1906, 'train': 'train'}
# {'loss': '1.902', 'epoch': 1906, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1907, 'train': 'train'}
# {'loss': '1.762', 'epoch': 1907, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1908, 'train': 'train'}
# {'loss': '2.491', 'epoch': 1908, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1909, 'train': 'train'}
# {'loss': '1.730', 'epoch': 1909, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 1910, 'train': 'train'}
# {'loss': '2.040', 'epoch': 1910, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1911, 'train': 'train'}
# {'loss': '1.524', 'epoch': 1911, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1912, 'train': 'train'}
# {'loss': '2.831', 'epoch': 1912, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1913, 'train': 'train'}
# {'loss': '2.213', 'epoch': 1913, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 1914, 'train': 'train'}
# {'loss': '2.344', 'epoch': 1914, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1915, 'train': 'train'}
# {'loss': '1.894', 'epoch': 1915, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1916, 'train': 'train'}
# {'loss': '1.827', 'epoch': 1916, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1917, 'train': 'train'}
# {'loss': '2.569', 'epoch': 1917, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1918, 'train': 'train'}
# {'loss': '1.673', 'epoch': 1918, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1919, 'train': 'train'}
# {'loss': '2.215', 'epoch': 1919, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1920, 'train': 'train'}
# {'loss': '2.257', 'epoch': 1920, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1921, 'train': 'train'}
# {'loss': '1.957', 'epoch': 1921, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1922, 'train': 'train'}
# {'loss': '2.004', 'epoch': 1922, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1923, 'train': 'train'}
# {'loss': '2.166', 'epoch': 1923, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1924, 'train': 'train'}
# {'loss': '1.587', 'epoch': 1924, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1925, 'train': 'train'}
# {'loss': '1.936', 'epoch': 1925, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1926, 'train': 'train'}
# {'loss': '1.717', 'epoch': 1926, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1927, 'train': 'train'}
# {'loss': '2.814', 'epoch': 1927, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1928, 'train': 'train'}
# {'loss': '1.712', 'epoch': 1928, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1929, 'train': 'train'}
# {'loss': '1.934', 'epoch': 1929, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1930, 'train': 'train'}
# {'loss': '1.688', 'epoch': 1930, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1931, 'train': 'train'}
# {'loss': '1.861', 'epoch': 1931, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1932, 'train': 'train'}
# {'loss': '1.755', 'epoch': 1932, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 1933, 'train': 'train'}
# {'loss': '1.659', 'epoch': 1933, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1934, 'train': 'train'}
# {'loss': '1.802', 'epoch': 1934, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1935, 'train': 'train'}
# {'loss': '1.733', 'epoch': 1935, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1936, 'train': 'train'}
# {'loss': '2.237', 'epoch': 1936, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1937, 'train': 'train'}
# {'loss': '1.340', 'epoch': 1937, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1938, 'train': 'train'}
# {'loss': '1.708', 'epoch': 1938, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1939, 'train': 'train'}
# {'loss': '1.751', 'epoch': 1939, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1940, 'train': 'train'}
# {'loss': '1.289', 'epoch': 1940, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1941, 'train': 'train'}
# {'loss': '1.960', 'epoch': 1941, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1942, 'train': 'train'}
# {'loss': '2.416', 'epoch': 1942, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1943, 'train': 'train'}
# {'loss': '1.397', 'epoch': 1943, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1944, 'train': 'train'}
# {'loss': '1.365', 'epoch': 1944, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1945, 'train': 'train'}
# {'loss': '1.361', 'epoch': 1945, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1946, 'train': 'train'}
# {'loss': '2.329', 'epoch': 1946, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1947, 'train': 'train'}
# {'loss': '1.975', 'epoch': 1947, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1948, 'train': 'train'}
# {'loss': '1.471', 'epoch': 1948, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1949, 'train': 'train'}
# {'loss': '1.747', 'epoch': 1949, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1950, 'train': 'train'}
# {'loss': '1.402', 'epoch': 1950, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1951, 'train': 'train'}
# {'loss': '1.661', 'epoch': 1951, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1952, 'train': 'train'}
# {'loss': '2.068', 'epoch': 1952, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1953, 'train': 'train'}
# {'loss': '2.457', 'epoch': 1953, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1954, 'train': 'train'}
# {'loss': '2.605', 'epoch': 1954, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1955, 'train': 'train'}
# {'loss': '1.830', 'epoch': 1955, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1956, 'train': 'train'}
# {'loss': '1.938', 'epoch': 1956, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1957, 'train': 'train'}
# {'loss': '2.800', 'epoch': 1957, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1958, 'train': 'train'}
# {'loss': '2.581', 'epoch': 1958, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1959, 'train': 'train'}
# {'loss': '2.140', 'epoch': 1959, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1960, 'train': 'train'}
# {'loss': '2.356', 'epoch': 1960, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1961, 'train': 'train'}
# {'loss': '2.381', 'epoch': 1961, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1962, 'train': 'train'}
# {'loss': '2.222', 'epoch': 1962, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1963, 'train': 'train'}
# {'loss': '1.302', 'epoch': 1963, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1964, 'train': 'train'}
# {'loss': '2.505', 'epoch': 1964, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1965, 'train': 'train'}
# {'loss': '1.474', 'epoch': 1965, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1966, 'train': 'train'}
# {'loss': '2.095', 'epoch': 1966, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1967, 'train': 'train'}
# {'loss': '2.673', 'epoch': 1967, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1968, 'train': 'train'}
# {'loss': '2.171', 'epoch': 1968, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1969, 'train': 'train'}
# {'loss': '2.011', 'epoch': 1969, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1970, 'train': 'train'}
# {'loss': '1.293', 'epoch': 1970, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1971, 'train': 'train'}
# {'loss': '1.742', 'epoch': 1971, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 1972, 'train': 'train'}
# {'loss': '2.135', 'epoch': 1972, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1973, 'train': 'train'}
# {'loss': '2.111', 'epoch': 1973, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1974, 'train': 'train'}
# {'loss': '3.105', 'epoch': 1974, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1975, 'train': 'train'}
# {'loss': '2.106', 'epoch': 1975, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1976, 'train': 'train'}
# {'loss': '1.630', 'epoch': 1976, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1977, 'train': 'train'}
# {'loss': '1.705', 'epoch': 1977, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1978, 'train': 'train'}
# {'loss': '2.392', 'epoch': 1978, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1979, 'train': 'train'}
# {'loss': '1.909', 'epoch': 1979, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1980, 'train': 'train'}
# {'loss': '2.324', 'epoch': 1980, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1981, 'train': 'train'}
# {'loss': '2.311', 'epoch': 1981, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1982, 'train': 'train'}
# {'loss': '1.931', 'epoch': 1982, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1983, 'train': 'train'}
# {'loss': '2.397', 'epoch': 1983, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1984, 'train': 'train'}
# {'loss': '2.601', 'epoch': 1984, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1985, 'train': 'train'}
# {'loss': '2.082', 'epoch': 1985, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1986, 'train': 'train'}
# {'loss': '1.714', 'epoch': 1986, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1987, 'train': 'train'}
# {'loss': '1.225', 'epoch': 1987, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1988, 'train': 'train'}
# {'loss': '2.916', 'epoch': 1988, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1989, 'train': 'train'}
# {'loss': '2.062', 'epoch': 1989, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1990, 'train': 'train'}
# {'loss': '1.624', 'epoch': 1990, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1991, 'train': 'train'}
# {'loss': '2.345', 'epoch': 1991, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1992, 'train': 'train'}
# {'loss': '1.588', 'epoch': 1992, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1993, 'train': 'train'}
# {'loss': '1.435', 'epoch': 1993, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1994, 'train': 'train'}
# {'loss': '2.111', 'epoch': 1994, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1995, 'train': 'train'}
# {'loss': '2.236', 'epoch': 1995, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1996, 'train': 'train'}
# {'loss': '2.117', 'epoch': 1996, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1997, 'train': 'train'}
# {'loss': '1.885', 'epoch': 1997, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1998, 'train': 'train'}
# {'loss': '1.766', 'epoch': 1998, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1999, 'train': 'train'}
# {'loss': '2.087', 'epoch': 1999, 'train': 'eval'}
# VBox(children=(Label(value='1059.098 MB of 1059.098 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▃▂▂▁▁▁▁▁▁▁▁▁▁▂▂▂▂▃▂▃▂▃▂▄▃▃▄▄▅▅▄▄▄▆▇▅█▆▅▇</td></tr><tr><td>train_loss</td><td>█▇▅▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃▂▂▁▁▁▁▁▁▁▁▁▁▂▂▂▂▃▂▃▂▃▂▄▃▃▄▄▅▅▄▄▄▆▇▅█▆▅▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>2.08697</td></tr><tr><td>train_loss</td><td>0.04</td></tr><tr><td>val_loss</td><td>2.087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dark-galaxy-5</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/tibbqy7v' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/tibbqy7v</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a><br/>Synced 6 W&B file(s), 2000 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_111233-tibbqy7v/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
lr = 0.5e-4
epochs = 2000
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
#wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_122938-gb0zvcfn</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/gb0zvcfn' target="_blank">rare-pond-6</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/gb0zvcfn' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/gb0zvcfn</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='797' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       39.85% [797/2000 23:41&lt;35:44]
#     </div>
#
#
#
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00 0.899]
#     </div>
# {'loss': '0.039', 'epoch': 0, 'train': 'train'}
# {'loss': '2.174', 'epoch': 0, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1, 'train': 'train'}
# {'loss': '1.833', 'epoch': 1, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 2, 'train': 'train'}
# {'loss': '2.119', 'epoch': 2, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 3, 'train': 'train'}
# {'loss': '2.052', 'epoch': 3, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 4, 'train': 'train'}
# {'loss': '1.735', 'epoch': 4, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 5, 'train': 'train'}
# {'loss': '2.023', 'epoch': 5, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 6, 'train': 'train'}
# {'loss': '1.002', 'epoch': 6, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 7, 'train': 'train'}
# {'loss': '1.797', 'epoch': 7, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 8, 'train': 'train'}
# {'loss': '2.197', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 9, 'train': 'train'}
# {'loss': '1.692', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 10, 'train': 'train'}
# {'loss': '1.797', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 11, 'train': 'train'}
# {'loss': '1.904', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 12, 'train': 'train'}
# {'loss': '2.308', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 13, 'train': 'train'}
# {'loss': '2.189', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 14, 'train': 'train'}
# {'loss': '2.429', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 15, 'train': 'train'}
# {'loss': '2.467', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 16, 'train': 'train'}
# {'loss': '2.163', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 17, 'train': 'train'}
# {'loss': '1.787', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 18, 'train': 'train'}
# {'loss': '2.566', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '2.197', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 20, 'train': 'train'}
# {'loss': '2.315', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 21, 'train': 'train'}
# {'loss': '2.013', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 22, 'train': 'train'}
# {'loss': '1.951', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 23, 'train': 'train'}
# {'loss': '2.050', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 24, 'train': 'train'}
# {'loss': '2.351', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 25, 'train': 'train'}
# {'loss': '1.205', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 26, 'train': 'train'}
# {'loss': '2.596', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 27, 'train': 'train'}
# {'loss': '2.673', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 28, 'train': 'train'}
# {'loss': '1.398', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 29, 'train': 'train'}
# {'loss': '2.393', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 30, 'train': 'train'}
# {'loss': '2.174', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 31, 'train': 'train'}
# {'loss': '2.044', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 32, 'train': 'train'}
# {'loss': '1.454', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 33, 'train': 'train'}
# {'loss': '1.667', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 34, 'train': 'train'}
# {'loss': '1.995', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 35, 'train': 'train'}
# {'loss': '1.663', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 36, 'train': 'train'}
# {'loss': '1.970', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 37, 'train': 'train'}
# {'loss': '2.035', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 38, 'train': 'train'}
# {'loss': '2.241', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 39, 'train': 'train'}
# {'loss': '1.443', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 40, 'train': 'train'}
# {'loss': '2.715', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 41, 'train': 'train'}
# {'loss': '2.102', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 42, 'train': 'train'}
# {'loss': '2.094', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 43, 'train': 'train'}
# {'loss': '1.465', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 44, 'train': 'train'}
# {'loss': '1.907', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 45, 'train': 'train'}
# {'loss': '2.641', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 46, 'train': 'train'}
# {'loss': '2.116', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 47, 'train': 'train'}
# {'loss': '2.168', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 48, 'train': 'train'}
# {'loss': '1.531', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 49, 'train': 'train'}
# {'loss': '2.215', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 50, 'train': 'train'}
# {'loss': '2.474', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 51, 'train': 'train'}
# {'loss': '1.588', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 52, 'train': 'train'}
# {'loss': '1.254', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 53, 'train': 'train'}
# {'loss': '2.088', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 54, 'train': 'train'}
# {'loss': '1.813', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 55, 'train': 'train'}
# {'loss': '2.347', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 56, 'train': 'train'}
# {'loss': '1.732', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 57, 'train': 'train'}
# {'loss': '2.350', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 58, 'train': 'train'}
# {'loss': '2.163', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 59, 'train': 'train'}
# {'loss': '1.952', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 60, 'train': 'train'}
# {'loss': '1.351', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 61, 'train': 'train'}
# {'loss': '1.950', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 62, 'train': 'train'}
# {'loss': '1.430', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 63, 'train': 'train'}
# {'loss': '1.771', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 64, 'train': 'train'}
# {'loss': '1.750', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 65, 'train': 'train'}
# {'loss': '2.271', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 66, 'train': 'train'}
# {'loss': '1.573', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 67, 'train': 'train'}
# {'loss': '1.627', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 68, 'train': 'train'}
# {'loss': '1.095', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 69, 'train': 'train'}
# {'loss': '2.708', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 70, 'train': 'train'}
# {'loss': '2.346', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 71, 'train': 'train'}
# {'loss': '2.455', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 72, 'train': 'train'}
# {'loss': '2.207', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 73, 'train': 'train'}
# {'loss': '1.818', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 74, 'train': 'train'}
# {'loss': '2.972', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 75, 'train': 'train'}
# {'loss': '1.776', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 76, 'train': 'train'}
# {'loss': '2.010', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 77, 'train': 'train'}
# {'loss': '2.771', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 78, 'train': 'train'}
# {'loss': '2.464', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 79, 'train': 'train'}
# {'loss': '2.337', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 80, 'train': 'train'}
# {'loss': '2.865', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 81, 'train': 'train'}
# {'loss': '2.393', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 82, 'train': 'train'}
# {'loss': '2.645', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 83, 'train': 'train'}
# {'loss': '2.910', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 84, 'train': 'train'}
# {'loss': '2.243', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 85, 'train': 'train'}
# {'loss': '1.964', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 86, 'train': 'train'}
# {'loss': '1.666', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 87, 'train': 'train'}
# {'loss': '1.707', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 88, 'train': 'train'}
# {'loss': '2.483', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 89, 'train': 'train'}
# {'loss': '2.012', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 90, 'train': 'train'}
# {'loss': '1.703', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 91, 'train': 'train'}
# {'loss': '1.310', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 92, 'train': 'train'}
# {'loss': '2.574', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 93, 'train': 'train'}
# {'loss': '1.870', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 94, 'train': 'train'}
# {'loss': '2.306', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 95, 'train': 'train'}
# {'loss': '1.984', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 96, 'train': 'train'}
# {'loss': '3.378', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 97, 'train': 'train'}
# {'loss': '2.380', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 98, 'train': 'train'}
# {'loss': '1.714', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 99, 'train': 'train'}
# {'loss': '2.434', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 100, 'train': 'train'}
# {'loss': '1.905', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 101, 'train': 'train'}
# {'loss': '1.438', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 102, 'train': 'train'}
# {'loss': '2.123', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 103, 'train': 'train'}
# {'loss': '2.217', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 104, 'train': 'train'}
# {'loss': '2.790', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 105, 'train': 'train'}
# {'loss': '1.798', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 106, 'train': 'train'}
# {'loss': '2.020', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 107, 'train': 'train'}
# {'loss': '2.194', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 108, 'train': 'train'}
# {'loss': '2.598', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 109, 'train': 'train'}
# {'loss': '2.078', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 110, 'train': 'train'}
# {'loss': '1.458', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 111, 'train': 'train'}
# {'loss': '2.173', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 112, 'train': 'train'}
# {'loss': '2.118', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 113, 'train': 'train'}
# {'loss': '1.830', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 114, 'train': 'train'}
# {'loss': '1.737', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 115, 'train': 'train'}
# {'loss': '2.156', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 116, 'train': 'train'}
# {'loss': '1.965', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 117, 'train': 'train'}
# {'loss': '1.666', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 118, 'train': 'train'}
# {'loss': '2.768', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 119, 'train': 'train'}
# {'loss': '2.478', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 120, 'train': 'train'}
# {'loss': '2.305', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 121, 'train': 'train'}
# {'loss': '2.773', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 122, 'train': 'train'}
# {'loss': '1.797', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 123, 'train': 'train'}
# {'loss': '1.808', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 124, 'train': 'train'}
# {'loss': '1.836', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 125, 'train': 'train'}
# {'loss': '1.259', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 126, 'train': 'train'}
# {'loss': '2.417', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 127, 'train': 'train'}
# {'loss': '1.270', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 128, 'train': 'train'}
# {'loss': '1.684', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 129, 'train': 'train'}
# {'loss': '1.691', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 130, 'train': 'train'}
# {'loss': '1.541', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 131, 'train': 'train'}
# {'loss': '1.209', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 132, 'train': 'train'}
# {'loss': '1.550', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 133, 'train': 'train'}
# {'loss': '1.700', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 134, 'train': 'train'}
# {'loss': '1.705', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 135, 'train': 'train'}
# {'loss': '1.246', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 136, 'train': 'train'}
# {'loss': '1.779', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 137, 'train': 'train'}
# {'loss': '1.655', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 138, 'train': 'train'}
# {'loss': '1.742', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 139, 'train': 'train'}
# {'loss': '2.110', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 140, 'train': 'train'}
# {'loss': '1.593', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 141, 'train': 'train'}
# {'loss': '1.658', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 142, 'train': 'train'}
# {'loss': '1.698', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 143, 'train': 'train'}
# {'loss': '1.745', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 144, 'train': 'train'}
# {'loss': '1.798', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 145, 'train': 'train'}
# {'loss': '0.947', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 146, 'train': 'train'}
# {'loss': '1.837', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 147, 'train': 'train'}
# {'loss': '1.693', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 148, 'train': 'train'}
# {'loss': '1.070', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 149, 'train': 'train'}
# {'loss': '1.225', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 150, 'train': 'train'}
# {'loss': '1.711', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 151, 'train': 'train'}
# {'loss': '2.027', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 152, 'train': 'train'}
# {'loss': '1.995', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 153, 'train': 'train'}
# {'loss': '1.726', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 154, 'train': 'train'}
# {'loss': '2.265', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 155, 'train': 'train'}
# {'loss': '1.727', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 156, 'train': 'train'}
# {'loss': '1.197', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 157, 'train': 'train'}
# {'loss': '2.168', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 158, 'train': 'train'}
# {'loss': '2.773', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 159, 'train': 'train'}
# {'loss': '2.843', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 160, 'train': 'train'}
# {'loss': '2.184', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 161, 'train': 'train'}
# {'loss': '2.260', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 162, 'train': 'train'}
# {'loss': '1.780', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 163, 'train': 'train'}
# {'loss': '1.596', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 164, 'train': 'train'}
# {'loss': '1.602', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 165, 'train': 'train'}
# {'loss': '2.510', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 166, 'train': 'train'}
# {'loss': '1.560', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 167, 'train': 'train'}
# {'loss': '1.900', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 168, 'train': 'train'}
# {'loss': '2.312', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 169, 'train': 'train'}
# {'loss': '1.856', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 170, 'train': 'train'}
# {'loss': '1.726', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 171, 'train': 'train'}
# {'loss': '2.255', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 172, 'train': 'train'}
# {'loss': '1.639', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 173, 'train': 'train'}
# {'loss': '1.689', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 174, 'train': 'train'}
# {'loss': '1.996', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 175, 'train': 'train'}
# {'loss': '2.794', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 176, 'train': 'train'}
# {'loss': '1.398', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 177, 'train': 'train'}
# {'loss': '1.955', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 178, 'train': 'train'}
# {'loss': '1.876', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 179, 'train': 'train'}
# {'loss': '1.457', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 180, 'train': 'train'}
# {'loss': '2.536', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 181, 'train': 'train'}
# {'loss': '1.895', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 182, 'train': 'train'}
# {'loss': '1.792', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 183, 'train': 'train'}
# {'loss': '1.425', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 184, 'train': 'train'}
# {'loss': '1.074', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 185, 'train': 'train'}
# {'loss': '2.205', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 186, 'train': 'train'}
# {'loss': '1.823', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 187, 'train': 'train'}
# {'loss': '2.125', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 188, 'train': 'train'}
# {'loss': '1.795', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 189, 'train': 'train'}
# {'loss': '3.183', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 190, 'train': 'train'}
# {'loss': '1.029', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 191, 'train': 'train'}
# {'loss': '1.498', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 192, 'train': 'train'}
# {'loss': '1.764', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 193, 'train': 'train'}
# {'loss': '1.983', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 194, 'train': 'train'}
# {'loss': '1.986', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 195, 'train': 'train'}
# {'loss': '1.831', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 196, 'train': 'train'}
# {'loss': '1.496', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 197, 'train': 'train'}
# {'loss': '1.949', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 198, 'train': 'train'}
# {'loss': '2.448', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 199, 'train': 'train'}
# {'loss': '2.258', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 200, 'train': 'train'}
# {'loss': '2.157', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 201, 'train': 'train'}
# {'loss': '1.744', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 202, 'train': 'train'}
# {'loss': '2.562', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 203, 'train': 'train'}
# {'loss': '2.181', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 204, 'train': 'train'}
# {'loss': '1.553', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 205, 'train': 'train'}
# {'loss': '1.244', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 206, 'train': 'train'}
# {'loss': '2.091', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 207, 'train': 'train'}
# {'loss': '2.482', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 208, 'train': 'train'}
# {'loss': '1.750', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 209, 'train': 'train'}
# {'loss': '2.028', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 210, 'train': 'train'}
# {'loss': '2.685', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 211, 'train': 'train'}
# {'loss': '2.501', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 212, 'train': 'train'}
# {'loss': '2.022', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 213, 'train': 'train'}
# {'loss': '1.581', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 214, 'train': 'train'}
# {'loss': '1.578', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 215, 'train': 'train'}
# {'loss': '1.983', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 216, 'train': 'train'}
# {'loss': '2.438', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 217, 'train': 'train'}
# {'loss': '1.103', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 218, 'train': 'train'}
# {'loss': '2.085', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 219, 'train': 'train'}
# {'loss': '2.083', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 220, 'train': 'train'}
# {'loss': '2.271', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 221, 'train': 'train'}
# {'loss': '2.187', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 222, 'train': 'train'}
# {'loss': '1.480', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 223, 'train': 'train'}
# {'loss': '1.211', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 224, 'train': 'train'}
# {'loss': '2.070', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 225, 'train': 'train'}
# {'loss': '1.244', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 226, 'train': 'train'}
# {'loss': '2.265', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 227, 'train': 'train'}
# {'loss': '1.404', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 228, 'train': 'train'}
# {'loss': '1.980', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 229, 'train': 'train'}
# {'loss': '1.219', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 230, 'train': 'train'}
# {'loss': '1.494', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 231, 'train': 'train'}
# {'loss': '1.795', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 232, 'train': 'train'}
# {'loss': '1.706', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 233, 'train': 'train'}
# {'loss': '1.770', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 234, 'train': 'train'}
# {'loss': '1.976', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 235, 'train': 'train'}
# {'loss': '1.566', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 236, 'train': 'train'}
# {'loss': '1.893', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 237, 'train': 'train'}
# {'loss': '1.811', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 238, 'train': 'train'}
# {'loss': '1.537', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 239, 'train': 'train'}
# {'loss': '1.358', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 240, 'train': 'train'}
# {'loss': '2.051', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 241, 'train': 'train'}
# {'loss': '1.508', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 242, 'train': 'train'}
# {'loss': '1.397', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 243, 'train': 'train'}
# {'loss': '1.169', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 244, 'train': 'train'}
# {'loss': '1.464', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 245, 'train': 'train'}
# {'loss': '1.388', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 246, 'train': 'train'}
# {'loss': '1.192', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 247, 'train': 'train'}
# {'loss': '1.279', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 248, 'train': 'train'}
# {'loss': '1.438', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 249, 'train': 'train'}
# {'loss': '1.524', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 250, 'train': 'train'}
# {'loss': '1.981', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 251, 'train': 'train'}
# {'loss': '1.668', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 252, 'train': 'train'}
# {'loss': '1.525', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 253, 'train': 'train'}
# {'loss': '1.195', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 254, 'train': 'train'}
# {'loss': '1.334', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 255, 'train': 'train'}
# {'loss': '1.123', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 256, 'train': 'train'}
# {'loss': '1.441', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 257, 'train': 'train'}
# {'loss': '2.459', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 258, 'train': 'train'}
# {'loss': '1.938', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 259, 'train': 'train'}
# {'loss': '1.354', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 260, 'train': 'train'}
# {'loss': '1.389', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 261, 'train': 'train'}
# {'loss': '1.364', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 262, 'train': 'train'}
# {'loss': '1.456', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 263, 'train': 'train'}
# {'loss': '1.870', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 264, 'train': 'train'}
# {'loss': '1.286', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 265, 'train': 'train'}
# {'loss': '1.556', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 266, 'train': 'train'}
# {'loss': '1.674', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 267, 'train': 'train'}
# {'loss': '1.381', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 268, 'train': 'train'}
# {'loss': '1.046', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 269, 'train': 'train'}
# {'loss': '1.934', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 270, 'train': 'train'}
# {'loss': '1.537', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 271, 'train': 'train'}
# {'loss': '1.684', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 272, 'train': 'train'}
# {'loss': '1.827', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 273, 'train': 'train'}
# {'loss': '2.552', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 274, 'train': 'train'}
# {'loss': '1.938', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 275, 'train': 'train'}
# {'loss': '2.077', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 276, 'train': 'train'}
# {'loss': '1.738', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 277, 'train': 'train'}
# {'loss': '1.673', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 278, 'train': 'train'}
# {'loss': '1.316', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 279, 'train': 'train'}
# {'loss': '1.911', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 280, 'train': 'train'}
# {'loss': '1.378', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 281, 'train': 'train'}
# {'loss': '1.309', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 282, 'train': 'train'}
# {'loss': '1.748', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 283, 'train': 'train'}
# {'loss': '1.564', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 284, 'train': 'train'}
# {'loss': '1.424', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 285, 'train': 'train'}
# {'loss': '1.305', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 286, 'train': 'train'}
# {'loss': '1.169', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 287, 'train': 'train'}
# {'loss': '0.892', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 288, 'train': 'train'}
# {'loss': '1.270', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 289, 'train': 'train'}
# {'loss': '1.381', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 290, 'train': 'train'}
# {'loss': '1.016', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 291, 'train': 'train'}
# {'loss': '1.461', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 292, 'train': 'train'}
# {'loss': '1.194', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 293, 'train': 'train'}
# {'loss': '1.467', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 294, 'train': 'train'}
# {'loss': '1.958', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 295, 'train': 'train'}
# {'loss': '1.091', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 296, 'train': 'train'}
# {'loss': '1.364', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 297, 'train': 'train'}
# {'loss': '1.136', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 298, 'train': 'train'}
# {'loss': '2.436', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 299, 'train': 'train'}
# {'loss': '1.724', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 300, 'train': 'train'}
# {'loss': '1.615', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 301, 'train': 'train'}
# {'loss': '1.367', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 302, 'train': 'train'}
# {'loss': '1.438', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 303, 'train': 'train'}
# {'loss': '1.115', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 304, 'train': 'train'}
# {'loss': '0.798', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 305, 'train': 'train'}
# {'loss': '1.020', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 306, 'train': 'train'}
# {'loss': '1.008', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 307, 'train': 'train'}
# {'loss': '1.208', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 308, 'train': 'train'}
# {'loss': '1.459', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 309, 'train': 'train'}
# {'loss': '1.628', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 310, 'train': 'train'}
# {'loss': '1.439', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 311, 'train': 'train'}
# {'loss': '1.095', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 312, 'train': 'train'}
# {'loss': '1.120', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 313, 'train': 'train'}
# {'loss': '0.987', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 314, 'train': 'train'}
# {'loss': '1.584', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 315, 'train': 'train'}
# {'loss': '0.951', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 316, 'train': 'train'}
# {'loss': '1.198', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 317, 'train': 'train'}
# {'loss': '1.125', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 318, 'train': 'train'}
# {'loss': '1.220', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 319, 'train': 'train'}
# {'loss': '1.357', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 320, 'train': 'train'}
# {'loss': '1.071', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 321, 'train': 'train'}
# {'loss': '1.394', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 322, 'train': 'train'}
# {'loss': '1.002', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 323, 'train': 'train'}
# {'loss': '1.223', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 324, 'train': 'train'}
# {'loss': '0.908', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 325, 'train': 'train'}
# {'loss': '1.774', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 326, 'train': 'train'}
# {'loss': '1.421', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 327, 'train': 'train'}
# {'loss': '1.999', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 328, 'train': 'train'}
# {'loss': '1.007', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 329, 'train': 'train'}
# {'loss': '1.184', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 330, 'train': 'train'}
# {'loss': '1.316', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 331, 'train': 'train'}
# {'loss': '1.190', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 332, 'train': 'train'}
# {'loss': '1.576', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 333, 'train': 'train'}
# {'loss': '1.286', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 334, 'train': 'train'}
# {'loss': '0.858', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 335, 'train': 'train'}
# {'loss': '0.876', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 336, 'train': 'train'}
# {'loss': '1.258', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 337, 'train': 'train'}
# {'loss': '1.233', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 338, 'train': 'train'}
# {'loss': '1.319', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 339, 'train': 'train'}
# {'loss': '1.257', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 340, 'train': 'train'}
# {'loss': '0.804', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 341, 'train': 'train'}
# {'loss': '1.291', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 342, 'train': 'train'}
# {'loss': '1.656', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 343, 'train': 'train'}
# {'loss': '1.351', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 344, 'train': 'train'}
# {'loss': '1.002', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 345, 'train': 'train'}
# {'loss': '1.223', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 346, 'train': 'train'}
# {'loss': '1.111', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 347, 'train': 'train'}
# {'loss': '0.835', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 348, 'train': 'train'}
# {'loss': '0.954', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 349, 'train': 'train'}
# {'loss': '0.815', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 350, 'train': 'train'}
# {'loss': '0.852', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 351, 'train': 'train'}
# {'loss': '1.004', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 352, 'train': 'train'}
# {'loss': '1.235', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 353, 'train': 'train'}
# {'loss': '1.044', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 354, 'train': 'train'}
# {'loss': '1.001', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 355, 'train': 'train'}
# {'loss': '0.933', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 356, 'train': 'train'}
# {'loss': '1.236', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 357, 'train': 'train'}
# {'loss': '1.168', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 358, 'train': 'train'}
# {'loss': '1.435', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 359, 'train': 'train'}
# {'loss': '1.934', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 360, 'train': 'train'}
# {'loss': '1.033', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 361, 'train': 'train'}
# {'loss': '1.215', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 362, 'train': 'train'}
# {'loss': '1.188', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 363, 'train': 'train'}
# {'loss': '1.103', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 364, 'train': 'train'}
# {'loss': '1.005', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 365, 'train': 'train'}
# {'loss': '1.071', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 366, 'train': 'train'}
# {'loss': '1.087', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 367, 'train': 'train'}
# {'loss': '1.459', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 368, 'train': 'train'}
# {'loss': '1.580', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 369, 'train': 'train'}
# {'loss': '1.343', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 370, 'train': 'train'}
# {'loss': '1.490', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 371, 'train': 'train'}
# {'loss': '1.198', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 372, 'train': 'train'}
# {'loss': '1.436', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 373, 'train': 'train'}
# {'loss': '0.858', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 374, 'train': 'train'}
# {'loss': '1.068', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 375, 'train': 'train'}
# {'loss': '1.171', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 376, 'train': 'train'}
# {'loss': '1.671', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 377, 'train': 'train'}
# {'loss': '1.663', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 378, 'train': 'train'}
# {'loss': '1.025', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 379, 'train': 'train'}
# {'loss': '1.093', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 380, 'train': 'train'}
# {'loss': '1.214', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 381, 'train': 'train'}
# {'loss': '1.881', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 382, 'train': 'train'}
# {'loss': '1.433', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 383, 'train': 'train'}
# {'loss': '1.638', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 384, 'train': 'train'}
# {'loss': '1.364', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 385, 'train': 'train'}
# {'loss': '0.913', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 386, 'train': 'train'}
# {'loss': '0.962', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 387, 'train': 'train'}
# {'loss': '0.961', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 388, 'train': 'train'}
# {'loss': '0.854', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 389, 'train': 'train'}
# {'loss': '1.184', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 390, 'train': 'train'}
# {'loss': '1.425', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 391, 'train': 'train'}
# {'loss': '1.038', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 392, 'train': 'train'}
# {'loss': '1.012', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 393, 'train': 'train'}
# {'loss': '1.023', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 394, 'train': 'train'}
# {'loss': '1.377', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 395, 'train': 'train'}
# {'loss': '1.098', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 396, 'train': 'train'}
# {'loss': '0.877', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 397, 'train': 'train'}
# {'loss': '0.656', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 398, 'train': 'train'}
# {'loss': '0.989', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 399, 'train': 'train'}
# {'loss': '1.159', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 400, 'train': 'train'}
# {'loss': '0.786', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 401, 'train': 'train'}
# {'loss': '1.087', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 402, 'train': 'train'}
# {'loss': '1.203', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 403, 'train': 'train'}
# {'loss': '1.266', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 404, 'train': 'train'}
# {'loss': '1.211', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 405, 'train': 'train'}
# {'loss': '1.434', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 406, 'train': 'train'}
# {'loss': '1.028', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 407, 'train': 'train'}
# {'loss': '1.549', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 408, 'train': 'train'}
# {'loss': '1.205', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 409, 'train': 'train'}
# {'loss': '1.139', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 410, 'train': 'train'}
# {'loss': '1.146', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 411, 'train': 'train'}
# {'loss': '1.425', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 412, 'train': 'train'}
# {'loss': '1.117', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 413, 'train': 'train'}
# {'loss': '1.255', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 414, 'train': 'train'}
# {'loss': '1.164', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 415, 'train': 'train'}
# {'loss': '1.420', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 416, 'train': 'train'}
# {'loss': '1.200', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 417, 'train': 'train'}
# {'loss': '1.159', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 418, 'train': 'train'}
# {'loss': '1.461', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 419, 'train': 'train'}
# {'loss': '1.233', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 420, 'train': 'train'}
# {'loss': '1.020', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 421, 'train': 'train'}
# {'loss': '0.844', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 422, 'train': 'train'}
# {'loss': '1.368', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 423, 'train': 'train'}
# {'loss': '0.916', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 424, 'train': 'train'}
# {'loss': '0.877', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 425, 'train': 'train'}
# {'loss': '1.243', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 426, 'train': 'train'}
# {'loss': '0.943', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 427, 'train': 'train'}
# {'loss': '0.967', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 428, 'train': 'train'}
# {'loss': '1.069', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 429, 'train': 'train'}
# {'loss': '0.829', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 430, 'train': 'train'}
# {'loss': '1.143', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 431, 'train': 'train'}
# {'loss': '0.825', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 432, 'train': 'train'}
# {'loss': '1.098', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 433, 'train': 'train'}
# {'loss': '1.155', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 434, 'train': 'train'}
# {'loss': '1.177', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 435, 'train': 'train'}
# {'loss': '0.974', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 436, 'train': 'train'}
# {'loss': '1.325', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 437, 'train': 'train'}
# {'loss': '1.763', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 438, 'train': 'train'}
# {'loss': '1.242', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 439, 'train': 'train'}
# {'loss': '0.824', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 440, 'train': 'train'}
# {'loss': '1.229', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 441, 'train': 'train'}
# {'loss': '1.029', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 442, 'train': 'train'}
# {'loss': '0.914', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 443, 'train': 'train'}
# {'loss': '1.027', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 444, 'train': 'train'}
# {'loss': '1.187', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 445, 'train': 'train'}
# {'loss': '1.028', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 446, 'train': 'train'}
# {'loss': '1.439', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 447, 'train': 'train'}
# {'loss': '1.104', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 448, 'train': 'train'}
# {'loss': '1.194', 'epoch': 448, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 449, 'train': 'train'}
# {'loss': '0.796', 'epoch': 449, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 450, 'train': 'train'}
# {'loss': '1.124', 'epoch': 450, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 451, 'train': 'train'}
# {'loss': '0.862', 'epoch': 451, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 452, 'train': 'train'}
# {'loss': '1.263', 'epoch': 452, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 453, 'train': 'train'}
# {'loss': '1.354', 'epoch': 453, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 454, 'train': 'train'}
# {'loss': '1.120', 'epoch': 454, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 455, 'train': 'train'}
# {'loss': '0.979', 'epoch': 455, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 456, 'train': 'train'}
# {'loss': '1.238', 'epoch': 456, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 457, 'train': 'train'}
# {'loss': '1.253', 'epoch': 457, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 458, 'train': 'train'}
# {'loss': '1.462', 'epoch': 458, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 459, 'train': 'train'}
# {'loss': '1.145', 'epoch': 459, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 460, 'train': 'train'}
# {'loss': '1.385', 'epoch': 460, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 461, 'train': 'train'}
# {'loss': '1.400', 'epoch': 461, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 462, 'train': 'train'}
# {'loss': '1.246', 'epoch': 462, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 463, 'train': 'train'}
# {'loss': '1.331', 'epoch': 463, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 464, 'train': 'train'}
# {'loss': '1.267', 'epoch': 464, 'train': 'eval'}
# ...
# {'loss': '1.264', 'epoch': 715, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 716, 'train': 'train'}
# {'loss': '1.386', 'epoch': 716, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 717, 'train': 'train'}
# {'loss': '1.106', 'epoch': 717, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 718, 'train': 'train'}
# {'loss': '1.016', 'epoch': 718, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 719, 'train': 'train'}
# {'loss': '1.186', 'epoch': 719, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 720, 'train': 'train'}
# {'loss': '1.516', 'epoch': 720, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 721, 'train': 'train'}
# {'loss': '1.058', 'epoch': 721, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 722, 'train': 'train'}
# {'loss': '0.927', 'epoch': 722, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 723, 'train': 'train'}
# {'loss': '1.211', 'epoch': 723, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 724, 'train': 'train'}
# {'loss': '1.314', 'epoch': 724, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 725, 'train': 'train'}
# {'loss': '0.854', 'epoch': 725, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 726, 'train': 'train'}
# {'loss': '0.956', 'epoch': 726, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 727, 'train': 'train'}
# {'loss': '1.051', 'epoch': 727, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 728, 'train': 'train'}
# {'loss': '1.317', 'epoch': 728, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 729, 'train': 'train'}
# {'loss': '0.863', 'epoch': 729, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 730, 'train': 'train'}
# {'loss': '1.102', 'epoch': 730, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 731, 'train': 'train'}
# {'loss': '0.988', 'epoch': 731, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 732, 'train': 'train'}
# {'loss': '1.217', 'epoch': 732, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 733, 'train': 'train'}
# {'loss': '1.000', 'epoch': 733, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 734, 'train': 'train'}
# {'loss': '1.139', 'epoch': 734, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 735, 'train': 'train'}
# {'loss': '0.986', 'epoch': 735, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 736, 'train': 'train'}
# {'loss': '0.864', 'epoch': 736, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 737, 'train': 'train'}
# {'loss': '0.790', 'epoch': 737, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 738, 'train': 'train'}
# {'loss': '0.943', 'epoch': 738, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 739, 'train': 'train'}
# {'loss': '1.093', 'epoch': 739, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 740, 'train': 'train'}
# {'loss': '1.093', 'epoch': 740, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 741, 'train': 'train'}
# {'loss': '1.070', 'epoch': 741, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 742, 'train': 'train'}
# {'loss': '1.325', 'epoch': 742, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 743, 'train': 'train'}
# {'loss': '0.991', 'epoch': 743, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 744, 'train': 'train'}
# {'loss': '1.114', 'epoch': 744, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 745, 'train': 'train'}
# {'loss': '1.169', 'epoch': 745, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 746, 'train': 'train'}
# {'loss': '1.065', 'epoch': 746, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 747, 'train': 'train'}
# {'loss': '0.906', 'epoch': 747, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 748, 'train': 'train'}
# {'loss': '1.187', 'epoch': 748, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 749, 'train': 'train'}
# {'loss': '0.905', 'epoch': 749, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 750, 'train': 'train'}
# {'loss': '1.067', 'epoch': 750, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 751, 'train': 'train'}
# {'loss': '1.105', 'epoch': 751, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 752, 'train': 'train'}
# {'loss': '1.281', 'epoch': 752, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 753, 'train': 'train'}
# {'loss': '1.273', 'epoch': 753, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 754, 'train': 'train'}
# {'loss': '0.831', 'epoch': 754, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 755, 'train': 'train'}
# {'loss': '1.400', 'epoch': 755, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 756, 'train': 'train'}
# {'loss': '1.062', 'epoch': 756, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 757, 'train': 'train'}
# {'loss': '1.094', 'epoch': 757, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 758, 'train': 'train'}
# {'loss': '1.307', 'epoch': 758, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 759, 'train': 'train'}
# {'loss': '1.172', 'epoch': 759, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 760, 'train': 'train'}
# {'loss': '0.920', 'epoch': 760, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 761, 'train': 'train'}
# {'loss': '1.193', 'epoch': 761, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 762, 'train': 'train'}
# {'loss': '1.266', 'epoch': 762, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 763, 'train': 'train'}
# {'loss': '1.617', 'epoch': 763, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 764, 'train': 'train'}
# {'loss': '0.796', 'epoch': 764, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 765, 'train': 'train'}
# {'loss': '0.791', 'epoch': 765, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 766, 'train': 'train'}
# {'loss': '0.769', 'epoch': 766, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 767, 'train': 'train'}
# {'loss': '0.933', 'epoch': 767, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 768, 'train': 'train'}
# {'loss': '0.964', 'epoch': 768, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 769, 'train': 'train'}
# {'loss': '0.781', 'epoch': 769, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 770, 'train': 'train'}
# {'loss': '1.171', 'epoch': 770, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 771, 'train': 'train'}
# {'loss': '1.044', 'epoch': 771, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 772, 'train': 'train'}
# {'loss': '1.139', 'epoch': 772, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 773, 'train': 'train'}
# {'loss': '1.268', 'epoch': 773, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 774, 'train': 'train'}
# {'loss': '0.845', 'epoch': 774, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 775, 'train': 'train'}
# {'loss': '0.888', 'epoch': 775, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 776, 'train': 'train'}
# {'loss': '0.845', 'epoch': 776, 'train': 'eval'}
# {'loss': '0.056', 'epoch': 777, 'train': 'train'}
# {'loss': '0.764', 'epoch': 777, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 778, 'train': 'train'}
# {'loss': '0.650', 'epoch': 778, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 779, 'train': 'train'}
# {'loss': '0.933', 'epoch': 779, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 780, 'train': 'train'}
# {'loss': '0.678', 'epoch': 780, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 781, 'train': 'train'}
# {'loss': '0.896', 'epoch': 781, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 782, 'train': 'train'}
# {'loss': '0.695', 'epoch': 782, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 783, 'train': 'train'}
# {'loss': '0.639', 'epoch': 783, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 784, 'train': 'train'}
# {'loss': '0.693', 'epoch': 784, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 785, 'train': 'train'}
# {'loss': '0.920', 'epoch': 785, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 786, 'train': 'train'}
# {'loss': '1.052', 'epoch': 786, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 787, 'train': 'train'}
# {'loss': '0.776', 'epoch': 787, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 788, 'train': 'train'}
# {'loss': '0.870', 'epoch': 788, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 789, 'train': 'train'}
# {'loss': '0.748', 'epoch': 789, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 790, 'train': 'train'}
# {'loss': '1.032', 'epoch': 790, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 791, 'train': 'train'}
# {'loss': '1.089', 'epoch': 791, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 792, 'train': 'train'}
# {'loss': '0.861', 'epoch': 792, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 793, 'train': 'train'}
# {'loss': '0.894', 'epoch': 793, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 794, 'train': 'train'}
# {'loss': '1.085', 'epoch': 794, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 795, 'train': 'train'}
# {'loss': '1.295', 'epoch': 795, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 796, 'train': 'train'}
# {'loss': '0.984', 'epoch': 796, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 797, 'train': 'train'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 learn.fit(epochs)
#
# File ~/course22p2/miniai/learner.py:178, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     176     if lr is None: lr = self.lr
#     177     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 178     self._fit(train, valid)
#     179 finally:
#     180     for cb in cbs: self.cbs.remove(cb)
#
# File ~/course22p2/miniai/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/course22p2/miniai/learner.py:167, in Learner._fit(self, train, valid)
#     165 for self.epoch in self.epochs:
#     166     if train: self.one_epoch(True)
# --> 167     if valid: torch.no_grad()(self.one_epoch)(False)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/course22p2/miniai/learner.py:161, in Learner.one_epoch(self, training)
#     159 self.model.train(training)
#     160 self.dl = self.dls.train if training else self.dls.valid
# --> 161 self._one_epoch()
#
# File ~/course22p2/miniai/learner.py:130, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     128     o.callback(f'before_{self.nm}')
#     129     f(o, *args, **kwargs)
# --> 130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#     132 finally: o.callback(f'cleanup_{self.nm}')
#
# File ~/course22p2/miniai/learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File ~/course22p2/miniai/learner.py:69, in MetricsCB.after_epoch(self, learn)
#      67 log['epoch'] = learn.epoch
#      68 log['train'] = 'train' if learn.model.training else 'eval'
# ---> 69 self._log(log)
#
# Cell In[53], line 18, in WandBCB._log(self, d)
#      16 else:
#      17     wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
# ---> 18     wandb.log({'samples':self.sample_figure(learn)})
#      19 print(d)
#
# Cell In[53], line 24, in WandBCB.sample_figure(self, learn)
#      22 def sample_figure(self, learn):
#      23     with torch.no_grad():
# ---> 24         preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
#      25     s = to_cpu(vae.decode(preds[-1].cuda()*5))
#      26     s = s['sample'].clamp(0,1)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[52], line 12, in sample(f, model, sz, steps, eta, clamp, progress)
#      10 t = t[None].cuda()
#      11 abar_t = abar(t)
# ---> 12 noise = model((x_t, t))
#      13 abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
#      14 x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[50], line 39, in SimpleDiffusion.forward(self, inp)
#      37 x = self.conv_in(x)
#      38 saved = [x]
# ---> 39 for block in self.downs: x = block(x, emb)
#      40 saved += [p for o in self.downs for p in o.saved]
#      41 n,c,h,w = x.shape
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[45], line 11, in DownBlock.forward(self, x, t)
#       9 def forward(self, x, t):
#      10     self.saved = []
# ---> 11     for resnet in self.resnets: x = resnet(x, t)
#      12     x = self.down(x)
#      13     return x
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[44], line 7, in saved.<locals>._f(*args, **kwargs)
#       5 @wraps(m.forward)
#       6 def _f(*args, **kwargs):
# ----> 7     res = m_(*args, **kwargs)
#       8     blk.saved.append(res)
#       9     return res
#
# Cell In[43], line 21, in EmbResBlock.forward(self, x, t)
#      19 x = self.conv2(x)
#      20 x = x + self.idconv(inp)
# ---> 21 if self.attn: x = x + self.attn(x)
#      22 return x
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/nn/modules/module.py:1682, in Module.__getattr__(self, name)
#    1673         self._backward_pre_hooks = OrderedDict()
#    1675 # On the return type:
#    1676 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1677 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1680 # See full discussion on the problems with returning `Union` here
#    1681 # https://github.com/microsoft/pyright/issues/4213
# -> 1682 def __getattr__(self, name: str) -> Any:
#    1683     if '_parameters' in self.__dict__:
#    1684         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %% [markdown]
# cmodel = torch.load('models/data_aug2.pkl')
# del(cmodel[8])
# del(cmodel[7])
#
# @inplace
# def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]
#
# bs = 2048
# tds = dsd.with_transform(transformi)
# dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)
#
# dt = dls.train
# xb,yb = next(iter(dt))
#
# ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (64,4,8,8)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(0.9612), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)

# %%
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(1.), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)
