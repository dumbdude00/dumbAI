# %%
#| default_exp diffusion

# %% [markdown]
# # [fail] Diffusion unet

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
#| export
from miniai.imports import *

from einops import rearrange
from fastprogress import progress_bar
from diffusers import AutoencoderKL

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
class GPUCUDAMissing(BaseException):
    pass
    
try:
    if torch.cuda.is_available():
        print('# of GPUs available = ', torch.cuda.device_count())
    else:
        raise GPUCUDAMissing
except:
    print("ERROR: GPU is missing")
# Out:
# # of GPUs available =  1

# %%
xl,yl = 'image','label'
name = "zh-plus/tiny-imagenet"
bs = 1024
dsd = load_dataset(name)

# %%
dsd['train'] = dsd['train'].select(range(500))

# %%
dsd['valid'] = dsd['valid'].select(range(50))

# %%
class TinyHFDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hg_ds):
        self.ds = hg_ds
        # the 2 lines below must be done here because the execution of "ds['train']['image']" takes 18seconds
        # once it has executed, indexing it is very fast (5 milliseconds)
        self.image = hg_ds[xl]
        self.label = hg_ds[yl]
    def __len__(self): return self.ds.num_rows
    def __getitem__(self, i): return TF.to_tensor(self.image[i]), self.label[i]

# %%
tds = TinyHFDS(dsd['train'])

# %%
vds = TinyHFDS(dsd['valid'])

# %%
dl = DataLoader(tds, batch_size=bs, num_workers=0)
xb,yb = next(iter(dl))
show_images(xb[:16], imsize=2)

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").cuda().requires_grad_(False)

# %%
# %%time
lats = vae.encode(xb.cuda())
# Out:
# CPU times: user 320 ms, sys: 375 ms, total: 695 ms
# Wall time: 2.72 s

# %%
class LatsDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hfds):
        lbl = hfds[yl]
        self.label = lbl + lbl
        imgs = hfds[xl]
        list_tensor = [ TF.to_tensor(x) for i, x in enumerate(imgs+imgs)]
        batch = torch.stack(list_tensor)
        #batch.shape
        lats = vae.encode(batch.cuda())
        #lats.latent_dist.mean.shape
        self.lats = lats.latent_dist.mean
        
    def __len__(self): return len(self.lats)
    def __getitem__(self, i): return self.lats[i], self.label[i]

# %%
tlds = LatsDS(dsd['train'])
vlds = LatsDS(dsd['valid'])

# %% [markdown]
# ### Defs: TfmDS, tfmx, tfmy

# %%
class TfmDS:
    def __init__(self, ds, tfmx=fc.noop, tfmy=fc.noop): self.ds,self.tfmx,self.tfmy = ds,tfmx,tfmy
    def __len__(self): return len(self.ds)
    def __getitem__(self, i):
        x,y = self.ds[i]
        return self.tfmx(x),self.tfmy(y)

# %%
def tfmx(x):
    return x

# %%
def tfmy(y): 
    return y

# %% [markdown]
# ### Generate a batch and Decode batch

# %%
tfm_tds = TfmDS(tlds, tfmx, tfmy)
tfm_vds = TfmDS(vlds, tfmx, tfmy)

# %%
def collate_fn(b):
    b = default_collate(b)
    return b

# %%
#bs=512

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_fn))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb.shape, yb.shape, xb.min(), xb.max()
# Out:
# (torch.Size([1000, 4, 8, 8]),
#  torch.Size([1000]),
#  tensor(-20.1415, device='cuda:0'),
#  tensor(26.5186, device='cuda:0'))

# %%
show_images(((xb[:16,:3])/4).sigmoid() , imsize=2)

# %%
show_images(to_cpu(vae.decode(xb[:16]))['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# ### DDIM

# %%
#| export
def abar(t): return (t*math.pi/2).cos()**2
def inv_abar(x): return x.sqrt().acos()*2/math.pi

def noisify(x0):
    device = x0.device
    n = len(x0)
    t = torch.rand(n,).to(x0).clamp(0,0.999)
    ε = torch.randn(x0.shape, device=device)
    abar_t = abar(t).reshape(-1, 1, 1, 1).to(device)
    xt = abar_t.sqrt()*x0 + (1-abar_t).sqrt()*ε
    return (xt, t.to(device)), ε

def collate_ddpm(b): 
    b = default_collate(b)
    return noisify(b[0]*0.2) # jeremy scaled the lats by 0.2
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=0)

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_ddpm))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb[0].shape, xb[1].shape, yb.shape
# Out:
# (torch.Size([1000, 4, 8, 8]), torch.Size([1000]), torch.Size([1000, 4, 8, 8]))

# %%
xb[0].min(), xb[0].max()
# Out:
# (tensor(-4.1888, device='cuda:0'), tensor(5.0195, device='cuda:0'))

# %%
show_images((xb[0][:9,0]*5).clamp(0,1))

# %% [markdown]
# ## Train

# %% [markdown]
# Based on Diffusers

# %%
#| export
def timestep_embedding(tsteps, emb_dim, max_period= 10000):
    exponent = -math.log(max_period) * torch.linspace(0, 1, emb_dim//2, device=tsteps.device)
    emb = tsteps[:,None].float() * exponent.exp()[None,:]
    emb = torch.cat([emb.sin(), emb.cos()], dim=-1)
    return F.pad(emb, (0,1,0,0)) if emb_dim%2==1 else emb

# %%
#| export
def pre_conv(ni, nf, ks=3, stride=1, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2, bias=bias))
    return layers

# %%
#| export
def upsample(nf): return nn.Sequential(nn.Upsample(scale_factor=2.), nn.Conv2d(nf, nf, 3, padding=1))

# %%
#| export
def lin(ni, nf, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Linear(ni, nf, bias=bias))
    return layers

# %%
# This version is giving poor results - use the cell below instead
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans):
        super().__init__()
        self.attn = nn.MultiheadAttention(ni, ni//attn_chans, batch_first=True)
        self.norm = nn.BatchNorm2d(ni)

    def forward(self, x):
        n,c,h,w = x.shape
        x = self.norm(x).view(n, c, -1).transpose(1, 2)
        x = self.attn(x, x, x, need_weights=False)[0]
        return x.transpose(1,2).reshape(n,c,h,w)

# %%
#| export
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans, transpose=True):
        super().__init__()
        self.nheads = ni//attn_chans
        self.scale = math.sqrt(ni/self.nheads)
        self.norm = nn.LayerNorm(ni)
        self.qkv = nn.Linear(ni, ni*3)
        self.proj = nn.Linear(ni, ni)
        self.t = transpose
    
    def forward(self, x):
        n,c,s = x.shape
        if self.t: x = x.transpose(1, 2)
        x = self.norm(x)
        x = self.qkv(x)
        x = rearrange(x, 'n s (h d) -> (n h) s d', h=self.nheads)
        q,k,v = torch.chunk(x, 3, dim=-1)
        s = (q@k.transpose(1,2))/self.scale
        x = s.softmax(dim=-1)@v
        x = rearrange(x, '(n h) s d -> n s (h d)', h=self.nheads)
        x = self.proj(x)
        if self.t: x = x.transpose(1, 2)
        return x

# %%
#| export
class SelfAttention2D(SelfAttention):
    def forward(self, x):
        n,c,h,w = x.shape
        return super().forward(x.view(n, c, -1)).reshape(n,c,h,w)

# %%
#| export
class EmbResBlock(nn.Module):
    def __init__(self, n_emb, ni, nf=None, ks=3, act=nn.SiLU, norm=nn.BatchNorm2d, attn_chans=0):
        super().__init__()
        if nf is None: nf = ni
        self.emb_proj = nn.Linear(n_emb, nf*2)
        self.conv1 = pre_conv(ni, nf, ks, act=None, norm=norm)
        self.conv2 = pre_conv(nf, nf, ks, act=act, norm=norm)
        self.idconv = fc.noop if ni==nf else nn.Conv2d(ni, nf, 1)
        self.attn = False
        if attn_chans: self.attn = SelfAttention2D(nf, attn_chans)

    def forward(self, x, t):
        inp = x
        x = self.conv1(x)
        emb = self.emb_proj(F.silu(t))[:, :, None, None]
        scale,shift = torch.chunk(emb, 2, dim=1)
        x = x*(1+scale) + shift
        x = self.conv2(x)
        x = x + self.idconv(inp)
        if self.attn: x = x + self.attn(x)
        return x

# %%
#| export
def saved(m, blk):
    m_ = m.forward

    @wraps(m.forward)
    def _f(*args, **kwargs):
        res = m_(*args, **kwargs)
        blk.saved.append(res)
        return res

    m.forward = _f
    return m

# %%
#| export
class DownBlock(nn.Module):
    def __init__(self, n_emb, ni, nf, add_down=True, num_layers=1, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList([saved(EmbResBlock(n_emb, ni if i==0 else nf, nf, attn_chans=attn_chans), self)
                                      for i in range(num_layers)])
        self.down = saved(nn.Conv2d(nf, nf, 3, stride=2, padding=1), self) if add_down else nn.Identity()

    def forward(self, x, t):
        self.saved = []
        for resnet in self.resnets: x = resnet(x, t)
        x = self.down(x)
        return x

# %%
#| export
class UpBlock(nn.Module):
    def __init__(self, n_emb, ni, prev_nf, nf, add_up=True, num_layers=2, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList(
            [EmbResBlock(n_emb, (prev_nf if i==0 else nf)+(ni if (i==num_layers-1) else nf), nf, attn_chans=attn_chans)
            for i in range(num_layers)])
        self.up = upsample(nf) if add_up else nn.Identity()

    def forward(self, x, t, ups):
        for resnet in self.resnets: x = resnet(torch.cat([x, ups.pop()], dim=1), t)
        return self.up(x)

# %%
class LearnEmbSS(nn.Module):
    def __init__(self, sz, ni):
        super().__init__()
        self.scale = nn.Parameter(torch.zeros(sz, ni))
        self.shift = nn.Parameter(torch.zeros(sz, ni))

    def forward(self, x): return x*self.scale + self.shift

# %%
def _mlp(ni, nh):
    return nn.Sequential(nn.Linear(ni,nh), nn.GELU(), nn.LayerNorm(nh), nn.Linear(nh,ni))

# %%
class EmbTransformerBlk(nn.Module):
    def __init__(self, n_emb, ni, attn_chans=8):
        super().__init__()
        self.attn = SelfAttention(ni, attn_chans=attn_chans, transpose=False)
        self.mlp = _mlp(ni, ni*4)
        self.nrm1 = nn.LayerNorm(ni)
        self.nrm2 = nn.LayerNorm(ni)
        self.emb_proj = nn.Linear(n_emb, ni*2)

    def forward(self, x, t):
        emb = self.emb_proj(F.silu(t))[:, None]
        scale,shift = torch.chunk(emb, 2, dim=2)
        x = x + self.attn(self.nrm1(x))
        x = x*(1+scale) + shift
        return x + self.mlp(self.nrm2(x))

# %%
img_vec_len = 1
class SimpleDiffusion(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, nfs=(224,448,672,896), num_layers=1,
                 attn_chans=8, attn_start=1, n_mids=8):
        super().__init__()
        self.conv_in = nn.Conv2d(in_channels, nfs[0], kernel_size=3, padding=1)
        self.n_temb = nf = nfs[0]
        n_emb = nf*4
        self.emb_mlp = nn.Sequential(lin(self.n_temb, n_emb, norm=nn.BatchNorm1d),
                                     lin(n_emb, n_emb))
        self.downs = nn.ModuleList()
        n = len(nfs)
        for i in range(n):
            ni = nf
            nf = nfs[i]
            self.downs.append(DownBlock(n_emb, ni, nf, add_down=i!=n-1, num_layers=num_layers,
                                        attn_chans=0 if i<attn_start else attn_chans))

        self.le = LearnEmbSS(img_vec_len, nf)
        self.mids = nn.ModuleList([EmbTransformerBlk(n_emb, nf) for _ in range(n_mids)])

        rev_nfs = list(reversed(nfs))
        nf = rev_nfs[0]
        self.ups = nn.ModuleList()
        for i in range(n):
            prev_nf = nf
            nf = rev_nfs[i]
            ni = rev_nfs[min(i+1, len(nfs)-1)]
            self.ups.append(UpBlock(n_emb, ni, prev_nf, nf, add_up=i!=n-1, num_layers=num_layers+1,
                                    attn_chans=0 if i>=n-attn_start else attn_chans))
        self.conv_out = pre_conv(nfs[0], out_channels, act=nn.SiLU, norm=nn.BatchNorm2d, bias=False)

    def forward(self, inp):
        x,t = inp
        temb = timestep_embedding(t, self.n_temb)
        emb = self.emb_mlp(temb)
        x = self.conv_in(x)
        saved = [x]
        for block in self.downs: x = block(x, emb)
        saved += [p for o in self.downs for p in o.saved]
        n,c,h,w = x.shape
        x = self.le(x.reshape(n,c,-1).transpose(1,2))
        for block in self.mids: x = block(x, emb)
        x = x.transpose(1,2).reshape(n,c,h,w)
        for block in self.ups: x = block(x, emb, saved)
        return self.conv_out(x)

# %%
#| export
def ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp=True):
    sig = ((bbar_t1/bbar_t).sqrt() * (1-abar_t/abar_t1).sqrt()) * eta
    x_0_hat = ((x_t-(1-abar_t).sqrt()*noise) / abar_t.sqrt())
    if clamp: x_0_hat = x_0_hat.clamp(-1,1)
    if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
    x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
    x_t += sig * torch.randn(x_t.shape).to(x_t)
    return x_0_hat,x_t

# %%
#| export
@torch.no_grad()
def sample(f, model, sz, steps, eta=1., clamp=True, progress=False):
    model.eval()
    ts = torch.linspace(1-1/steps,0,steps)
    x_t = torch.randn(sz).cuda()
    preds = []
    tbe = progress_bar(ts) if progress else ts 
    for i,t in enumerate(tbe):
        t = t[None].cuda()
        abar_t = abar(t)
        noise = model((x_t, t))
        abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
        x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
        preds.append(x_0_hat.float().cpu())
    return preds

# %%
import wandb

class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project='ddpm_goldfish_64x64_clip', **metrics):
        fc.store_attr()
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d):
        #import pdb; pdb.set_trace()
        if learn.model.training: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
            wandb.log({'samples':self.sample_figure(learn)})
        print(d)

        
    def sample_figure(self, learn):
        with torch.no_grad():
            preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
        s = to_cpu(vae.decode(preds[-1].cuda()*5))
        s = s['sample'].clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16, imsize=3)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME'] = '09_diffusion-attn-cond_tin_goldfish_64x64_CLIP_i1.ipynb'
lr = 1e-4
epochs = 2000
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512), num_layers=2, attn_chans=0, attn_start=1, n_mids=10)'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
#model = EmbUNetModel(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2)
model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512,1024), num_layers=2, attn_chans=4, attn_start=1, n_mids=6)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# wandb: Currently logged in as: dumbdude (dumbdude-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_100836-rughz4d1</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/rughz4d1' target="_blank">divine-fire-4</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/rughz4d1' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/rughz4d1</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'loss': '1.094', 'epoch': 0, 'train': 'train'}
# {'loss': '1.002', 'epoch': 0, 'train': 'eval'}
# {'loss': '1.089', 'epoch': 1, 'train': 'train'}
# {'loss': '1.000', 'epoch': 1, 'train': 'eval'}
# {'loss': '1.086', 'epoch': 2, 'train': 'train'}
# {'loss': '1.013', 'epoch': 2, 'train': 'eval'}
# {'loss': '1.075', 'epoch': 3, 'train': 'train'}
# {'loss': '1.011', 'epoch': 3, 'train': 'eval'}
# {'loss': '1.069', 'epoch': 4, 'train': 'train'}
# {'loss': '0.994', 'epoch': 4, 'train': 'eval'}
# {'loss': '1.067', 'epoch': 5, 'train': 'train'}
# {'loss': '0.986', 'epoch': 5, 'train': 'eval'}
# {'loss': '1.055', 'epoch': 6, 'train': 'train'}
# {'loss': '1.009', 'epoch': 6, 'train': 'eval'}
# {'loss': '1.054', 'epoch': 7, 'train': 'train'}
# {'loss': '1.007', 'epoch': 7, 'train': 'eval'}
# {'loss': '1.045', 'epoch': 8, 'train': 'train'}
# {'loss': '0.998', 'epoch': 8, 'train': 'eval'}
# {'loss': '1.046', 'epoch': 9, 'train': 'train'}
# {'loss': '1.005', 'epoch': 9, 'train': 'eval'}
# {'loss': '1.045', 'epoch': 10, 'train': 'train'}
# {'loss': '1.000', 'epoch': 10, 'train': 'eval'}
# {'loss': '1.038', 'epoch': 11, 'train': 'train'}
# {'loss': '1.001', 'epoch': 11, 'train': 'eval'}
# {'loss': '1.027', 'epoch': 12, 'train': 'train'}
# {'loss': '0.993', 'epoch': 12, 'train': 'eval'}
# {'loss': '1.025', 'epoch': 13, 'train': 'train'}
# {'loss': '1.002', 'epoch': 13, 'train': 'eval'}
# {'loss': '1.024', 'epoch': 14, 'train': 'train'}
# {'loss': '0.992', 'epoch': 14, 'train': 'eval'}
# {'loss': '1.006', 'epoch': 15, 'train': 'train'}
# {'loss': '0.971', 'epoch': 15, 'train': 'eval'}
# {'loss': '1.013', 'epoch': 16, 'train': 'train'}
# {'loss': '0.998', 'epoch': 16, 'train': 'eval'}
# {'loss': '1.006', 'epoch': 17, 'train': 'train'}
# {'loss': '0.989', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.994', 'epoch': 18, 'train': 'train'}
# {'loss': '0.980', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.998', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.965', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.989', 'epoch': 20, 'train': 'train'}
# {'loss': '0.986', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.989', 'epoch': 21, 'train': 'train'}
# {'loss': '0.972', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.981', 'epoch': 22, 'train': 'train'}
# {'loss': '0.976', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.974', 'epoch': 23, 'train': 'train'}
# {'loss': '0.967', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.974', 'epoch': 24, 'train': 'train'}
# {'loss': '0.979', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.964', 'epoch': 25, 'train': 'train'}
# {'loss': '0.972', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.960', 'epoch': 26, 'train': 'train'}
# {'loss': '0.968', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.956', 'epoch': 27, 'train': 'train'}
# {'loss': '0.958', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.951', 'epoch': 28, 'train': 'train'}
# {'loss': '0.963', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.943', 'epoch': 29, 'train': 'train'}
# {'loss': '0.944', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.937', 'epoch': 30, 'train': 'train'}
# {'loss': '0.953', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.934', 'epoch': 31, 'train': 'train'}
# {'loss': '0.957', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.930', 'epoch': 32, 'train': 'train'}
# {'loss': '0.933', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.921', 'epoch': 33, 'train': 'train'}
# {'loss': '0.925', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.920', 'epoch': 34, 'train': 'train'}
# {'loss': '0.927', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.914', 'epoch': 35, 'train': 'train'}
# {'loss': '0.913', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.909', 'epoch': 36, 'train': 'train'}
# {'loss': '0.917', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.905', 'epoch': 37, 'train': 'train'}
# {'loss': '0.914', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.894', 'epoch': 38, 'train': 'train'}
# {'loss': '0.907', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.892', 'epoch': 39, 'train': 'train'}
# {'loss': '0.919', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.890', 'epoch': 40, 'train': 'train'}
# {'loss': '0.907', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.890', 'epoch': 41, 'train': 'train'}
# {'loss': '0.897', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.875', 'epoch': 42, 'train': 'train'}
# {'loss': '0.870', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.875', 'epoch': 43, 'train': 'train'}
# {'loss': '0.876', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.864', 'epoch': 44, 'train': 'train'}
# {'loss': '0.870', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.866', 'epoch': 45, 'train': 'train'}
# {'loss': '0.879', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.864', 'epoch': 46, 'train': 'train'}
# {'loss': '0.841', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.850', 'epoch': 47, 'train': 'train'}
# {'loss': '0.825', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.846', 'epoch': 48, 'train': 'train'}
# {'loss': '0.832', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.836', 'epoch': 49, 'train': 'train'}
# {'loss': '0.835', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.829', 'epoch': 50, 'train': 'train'}
# {'loss': '0.837', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.828', 'epoch': 51, 'train': 'train'}
# {'loss': '0.850', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.822', 'epoch': 52, 'train': 'train'}
# {'loss': '0.831', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.820', 'epoch': 53, 'train': 'train'}
# {'loss': '0.816', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.812', 'epoch': 54, 'train': 'train'}
# {'loss': '0.795', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.809', 'epoch': 55, 'train': 'train'}
# {'loss': '0.798', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.802', 'epoch': 56, 'train': 'train'}
# {'loss': '0.794', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.800', 'epoch': 57, 'train': 'train'}
# {'loss': '0.813', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.788', 'epoch': 58, 'train': 'train'}
# {'loss': '0.792', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.782', 'epoch': 59, 'train': 'train'}
# {'loss': '0.758', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.778', 'epoch': 60, 'train': 'train'}
# {'loss': '0.767', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.768', 'epoch': 61, 'train': 'train'}
# {'loss': '0.766', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.763', 'epoch': 62, 'train': 'train'}
# {'loss': '0.748', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.759', 'epoch': 63, 'train': 'train'}
# {'loss': '0.756', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.750', 'epoch': 64, 'train': 'train'}
# {'loss': '0.734', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.751', 'epoch': 65, 'train': 'train'}
# {'loss': '0.736', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.746', 'epoch': 66, 'train': 'train'}
# {'loss': '0.772', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.743', 'epoch': 67, 'train': 'train'}
# {'loss': '0.706', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.728', 'epoch': 70, 'train': 'train'}
# {'loss': '0.710', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.712', 'epoch': 71, 'train': 'train'}
# {'loss': '0.726', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.718', 'epoch': 72, 'train': 'train'}
# {'loss': '0.680', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.709', 'epoch': 73, 'train': 'train'}
# {'loss': '0.711', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.697', 'epoch': 74, 'train': 'train'}
# {'loss': '0.693', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.693', 'epoch': 75, 'train': 'train'}
# {'loss': '0.669', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.680', 'epoch': 76, 'train': 'train'}
# {'loss': '0.686', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.683', 'epoch': 77, 'train': 'train'}
# {'loss': '0.691', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.671', 'epoch': 78, 'train': 'train'}
# {'loss': '0.690', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.669', 'epoch': 79, 'train': 'train'}
# {'loss': '0.664', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.667', 'epoch': 80, 'train': 'train'}
# {'loss': '0.678', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.658', 'epoch': 81, 'train': 'train'}
# {'loss': '0.668', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.655', 'epoch': 82, 'train': 'train'}
# {'loss': '0.657', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.646', 'epoch': 83, 'train': 'train'}
# {'loss': '0.593', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.639', 'epoch': 84, 'train': 'train'}
# {'loss': '0.630', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.638', 'epoch': 85, 'train': 'train'}
# {'loss': '0.621', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.637', 'epoch': 86, 'train': 'train'}
# {'loss': '0.592', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.640', 'epoch': 87, 'train': 'train'}
# {'loss': '0.600', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.623', 'epoch': 88, 'train': 'train'}
# {'loss': '0.603', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.625', 'epoch': 89, 'train': 'train'}
# {'loss': '0.619', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.609', 'epoch': 90, 'train': 'train'}
# {'loss': '0.576', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.607', 'epoch': 91, 'train': 'train'}
# {'loss': '0.546', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.598', 'epoch': 92, 'train': 'train'}
# {'loss': '0.591', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.600', 'epoch': 93, 'train': 'train'}
# {'loss': '0.615', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.596', 'epoch': 94, 'train': 'train'}
# {'loss': '0.560', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.591', 'epoch': 95, 'train': 'train'}
# {'loss': '0.591', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.577', 'epoch': 96, 'train': 'train'}
# {'loss': '0.594', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.578', 'epoch': 97, 'train': 'train'}
# {'loss': '0.546', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.567', 'epoch': 98, 'train': 'train'}
# {'loss': '0.591', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.569', 'epoch': 99, 'train': 'train'}
# {'loss': '0.590', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.569', 'epoch': 100, 'train': 'train'}
# {'loss': '0.538', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.563', 'epoch': 101, 'train': 'train'}
# {'loss': '0.505', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.556', 'epoch': 102, 'train': 'train'}
# {'loss': '0.533', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.554', 'epoch': 103, 'train': 'train'}
# {'loss': '0.535', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.550', 'epoch': 104, 'train': 'train'}
# {'loss': '0.592', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.544', 'epoch': 105, 'train': 'train'}
# {'loss': '0.523', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.541', 'epoch': 106, 'train': 'train'}
# {'loss': '0.532', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.530', 'epoch': 107, 'train': 'train'}
# {'loss': '0.571', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.549', 'epoch': 108, 'train': 'train'}
# {'loss': '0.558', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.537', 'epoch': 109, 'train': 'train'}
# {'loss': '0.526', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.535', 'epoch': 110, 'train': 'train'}
# {'loss': '0.528', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.526', 'epoch': 111, 'train': 'train'}
# {'loss': '0.499', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.516', 'epoch': 112, 'train': 'train'}
# {'loss': '0.500', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.519', 'epoch': 113, 'train': 'train'}
# {'loss': '0.517', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.525', 'epoch': 114, 'train': 'train'}
# {'loss': '0.514', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.514', 'epoch': 115, 'train': 'train'}
# {'loss': '0.496', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.506', 'epoch': 116, 'train': 'train'}
# {'loss': '0.512', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.500', 'epoch': 117, 'train': 'train'}
# {'loss': '0.509', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.510', 'epoch': 118, 'train': 'train'}
# {'loss': '0.498', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.502', 'epoch': 119, 'train': 'train'}
# {'loss': '0.507', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.498', 'epoch': 120, 'train': 'train'}
# {'loss': '0.492', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.499', 'epoch': 121, 'train': 'train'}
# {'loss': '0.455', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.503', 'epoch': 122, 'train': 'train'}
# {'loss': '0.568', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.494', 'epoch': 123, 'train': 'train'}
# {'loss': '0.468', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.499', 'epoch': 124, 'train': 'train'}
# {'loss': '0.562', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.486', 'epoch': 125, 'train': 'train'}
# {'loss': '0.530', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.502', 'epoch': 126, 'train': 'train'}
# {'loss': '0.494', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.494', 'epoch': 127, 'train': 'train'}
# {'loss': '0.473', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.492', 'epoch': 128, 'train': 'train'}
# {'loss': '0.479', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.493', 'epoch': 129, 'train': 'train'}
# {'loss': '0.497', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 130, 'train': 'train'}
# {'loss': '0.484', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.479', 'epoch': 131, 'train': 'train'}
# {'loss': '0.506', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.484', 'epoch': 132, 'train': 'train'}
# {'loss': '0.483', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.489', 'epoch': 133, 'train': 'train'}
# {'loss': '0.537', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.478', 'epoch': 134, 'train': 'train'}
# {'loss': '0.485', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.486', 'epoch': 135, 'train': 'train'}
# {'loss': '0.487', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.467', 'epoch': 136, 'train': 'train'}
# {'loss': '0.555', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.473', 'epoch': 137, 'train': 'train'}
# {'loss': '0.502', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 138, 'train': 'train'}
# {'loss': '0.463', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.464', 'epoch': 139, 'train': 'train'}
# {'loss': '0.475', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 140, 'train': 'train'}
# {'loss': '0.493', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.472', 'epoch': 141, 'train': 'train'}
# {'loss': '0.490', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.472', 'epoch': 142, 'train': 'train'}
# {'loss': '0.461', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.452', 'epoch': 143, 'train': 'train'}
# {'loss': '0.563', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.473', 'epoch': 144, 'train': 'train'}
# {'loss': '0.517', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.468', 'epoch': 145, 'train': 'train'}
# {'loss': '0.502', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.465', 'epoch': 146, 'train': 'train'}
# {'loss': '0.452', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.450', 'epoch': 147, 'train': 'train'}
# {'loss': '0.484', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.455', 'epoch': 148, 'train': 'train'}
# {'loss': '0.472', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.464', 'epoch': 149, 'train': 'train'}
# {'loss': '0.511', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 150, 'train': 'train'}
# {'loss': '0.462', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.456', 'epoch': 151, 'train': 'train'}
# {'loss': '0.461', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.443', 'epoch': 152, 'train': 'train'}
# {'loss': '0.504', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.455', 'epoch': 153, 'train': 'train'}
# {'loss': '0.465', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.451', 'epoch': 154, 'train': 'train'}
# {'loss': '0.469', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.445', 'epoch': 155, 'train': 'train'}
# {'loss': '0.456', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.446', 'epoch': 156, 'train': 'train'}
# {'loss': '0.476', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 157, 'train': 'train'}
# {'loss': '0.489', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 158, 'train': 'train'}
# {'loss': '0.487', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.443', 'epoch': 159, 'train': 'train'}
# {'loss': '0.431', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 160, 'train': 'train'}
# {'loss': '0.505', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.442', 'epoch': 161, 'train': 'train'}
# {'loss': '0.464', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.438', 'epoch': 162, 'train': 'train'}
# {'loss': '0.509', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.433', 'epoch': 163, 'train': 'train'}
# {'loss': '0.548', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 164, 'train': 'train'}
# {'loss': '0.504', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.451', 'epoch': 165, 'train': 'train'}
# {'loss': '0.483', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.429', 'epoch': 166, 'train': 'train'}
# {'loss': '0.456', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.433', 'epoch': 167, 'train': 'train'}
# {'loss': '0.493', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.435', 'epoch': 168, 'train': 'train'}
# {'loss': '0.446', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 169, 'train': 'train'}
# {'loss': '0.473', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 170, 'train': 'train'}
# {'loss': '0.435', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.447', 'epoch': 171, 'train': 'train'}
# {'loss': '0.499', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.437', 'epoch': 172, 'train': 'train'}
# {'loss': '0.480', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.445', 'epoch': 173, 'train': 'train'}
# {'loss': '0.427', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.430', 'epoch': 174, 'train': 'train'}
# {'loss': '0.516', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.427', 'epoch': 175, 'train': 'train'}
# {'loss': '0.475', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.429', 'epoch': 176, 'train': 'train'}
# {'loss': '0.439', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.426', 'epoch': 177, 'train': 'train'}
# {'loss': '0.441', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 178, 'train': 'train'}
# {'loss': '0.443', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 179, 'train': 'train'}
# {'loss': '0.379', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.424', 'epoch': 180, 'train': 'train'}
# {'loss': '0.462', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.428', 'epoch': 181, 'train': 'train'}
# {'loss': '0.440', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.433', 'epoch': 182, 'train': 'train'}
# {'loss': '0.450', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 183, 'train': 'train'}
# {'loss': '0.426', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.423', 'epoch': 184, 'train': 'train'}
# {'loss': '0.451', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 185, 'train': 'train'}
# {'loss': '0.416', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 186, 'train': 'train'}
# {'loss': '0.426', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.433', 'epoch': 187, 'train': 'train'}
# {'loss': '0.409', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 188, 'train': 'train'}
# {'loss': '0.409', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.424', 'epoch': 189, 'train': 'train'}
# {'loss': '0.393', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 190, 'train': 'train'}
# {'loss': '0.376', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.415', 'epoch': 191, 'train': 'train'}
# {'loss': '0.414', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 192, 'train': 'train'}
# {'loss': '0.403', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 193, 'train': 'train'}
# {'loss': '0.441', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 194, 'train': 'train'}
# {'loss': '0.404', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 195, 'train': 'train'}
# {'loss': '0.421', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.421', 'epoch': 196, 'train': 'train'}
# {'loss': '0.392', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.412', 'epoch': 197, 'train': 'train'}
# {'loss': '0.454', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 198, 'train': 'train'}
# {'loss': '0.501', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.408', 'epoch': 199, 'train': 'train'}
# {'loss': '0.388', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.423', 'epoch': 200, 'train': 'train'}
# {'loss': '0.449', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.416', 'epoch': 201, 'train': 'train'}
# {'loss': '0.477', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 202, 'train': 'train'}
# {'loss': '0.445', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.415', 'epoch': 203, 'train': 'train'}
# {'loss': '0.435', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.412', 'epoch': 204, 'train': 'train'}
# {'loss': '0.434', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 205, 'train': 'train'}
# {'loss': '0.419', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.405', 'epoch': 206, 'train': 'train'}
# {'loss': '0.466', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 207, 'train': 'train'}
# {'loss': '0.470', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 208, 'train': 'train'}
# {'loss': '0.397', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.401', 'epoch': 209, 'train': 'train'}
# {'loss': '0.384', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 210, 'train': 'train'}
# {'loss': '0.432', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 211, 'train': 'train'}
# {'loss': '0.447', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 212, 'train': 'train'}
# {'loss': '0.381', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 213, 'train': 'train'}
# {'loss': '0.413', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 214, 'train': 'train'}
# {'loss': '0.421', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 215, 'train': 'train'}
# {'loss': '0.401', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 216, 'train': 'train'}
# {'loss': '0.403', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 217, 'train': 'train'}
# {'loss': '0.422', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 218, 'train': 'train'}
# {'loss': '0.372', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 219, 'train': 'train'}
# {'loss': '0.347', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 220, 'train': 'train'}
# {'loss': '0.384', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.393', 'epoch': 221, 'train': 'train'}
# {'loss': '0.380', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.391', 'epoch': 222, 'train': 'train'}
# {'loss': '0.404', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.391', 'epoch': 223, 'train': 'train'}
# {'loss': '0.375', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 224, 'train': 'train'}
# {'loss': '0.379', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.394', 'epoch': 225, 'train': 'train'}
# {'loss': '0.408', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 226, 'train': 'train'}
# {'loss': '0.408', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 227, 'train': 'train'}
# {'loss': '0.388', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.390', 'epoch': 228, 'train': 'train'}
# {'loss': '0.434', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.381', 'epoch': 229, 'train': 'train'}
# {'loss': '0.369', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 230, 'train': 'train'}
# {'loss': '0.454', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.401', 'epoch': 231, 'train': 'train'}
# {'loss': '0.402', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 232, 'train': 'train'}
# {'loss': '0.394', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 233, 'train': 'train'}
# {'loss': '0.402', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 234, 'train': 'train'}
# {'loss': '0.370', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 235, 'train': 'train'}
# {'loss': '0.426', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.391', 'epoch': 236, 'train': 'train'}
# {'loss': '0.422', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.394', 'epoch': 237, 'train': 'train'}
# {'loss': '0.413', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 238, 'train': 'train'}
# {'loss': '0.410', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 239, 'train': 'train'}
# {'loss': '0.416', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 240, 'train': 'train'}
# {'loss': '0.434', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 241, 'train': 'train'}
# {'loss': '0.384', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 242, 'train': 'train'}
# {'loss': '0.386', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 243, 'train': 'train'}
# {'loss': '0.455', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 244, 'train': 'train'}
# {'loss': '0.402', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 245, 'train': 'train'}
# {'loss': '0.466', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 246, 'train': 'train'}
# {'loss': '0.390', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 247, 'train': 'train'}
# {'loss': '0.484', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 248, 'train': 'train'}
# {'loss': '0.412', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 249, 'train': 'train'}
# {'loss': '0.427', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 250, 'train': 'train'}
# {'loss': '0.423', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.400', 'epoch': 251, 'train': 'train'}
# {'loss': '0.394', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.405', 'epoch': 252, 'train': 'train'}
# {'loss': '0.495', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 253, 'train': 'train'}
# {'loss': '0.434', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 254, 'train': 'train'}
# {'loss': '0.402', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 255, 'train': 'train'}
# {'loss': '0.341', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.390', 'epoch': 256, 'train': 'train'}
# {'loss': '0.381', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 257, 'train': 'train'}
# {'loss': '0.393', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 258, 'train': 'train'}
# {'loss': '0.390', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 259, 'train': 'train'}
# {'loss': '0.449', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 260, 'train': 'train'}
# {'loss': '0.449', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 261, 'train': 'train'}
# {'loss': '0.434', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 262, 'train': 'train'}
# {'loss': '0.408', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 263, 'train': 'train'}
# {'loss': '0.422', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 264, 'train': 'train'}
# {'loss': '0.425', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 265, 'train': 'train'}
# {'loss': '0.379', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 266, 'train': 'train'}
# {'loss': '0.400', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 267, 'train': 'train'}
# {'loss': '0.372', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 268, 'train': 'train'}
# {'loss': '0.419', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 269, 'train': 'train'}
# {'loss': '0.345', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 270, 'train': 'train'}
# {'loss': '0.389', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 271, 'train': 'train'}
# {'loss': '0.381', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 272, 'train': 'train'}
# {'loss': '0.413', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 273, 'train': 'train'}
# {'loss': '0.472', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 274, 'train': 'train'}
# {'loss': '0.397', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 275, 'train': 'train'}
# {'loss': '0.530', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 276, 'train': 'train'}
# {'loss': '0.388', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 277, 'train': 'train'}
# {'loss': '0.392', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 278, 'train': 'train'}
# {'loss': '0.412', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 279, 'train': 'train'}
# {'loss': '0.303', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 280, 'train': 'train'}
# {'loss': '0.376', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 281, 'train': 'train'}
# {'loss': '0.376', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 282, 'train': 'train'}
# {'loss': '0.385', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 283, 'train': 'train'}
# {'loss': '0.375', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 284, 'train': 'train'}
# {'loss': '0.416', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 285, 'train': 'train'}
# {'loss': '0.379', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 286, 'train': 'train'}
# {'loss': '0.401', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 287, 'train': 'train'}
# {'loss': '0.360', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 288, 'train': 'train'}
# {'loss': '0.334', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 289, 'train': 'train'}
# {'loss': '0.387', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 290, 'train': 'train'}
# {'loss': '0.418', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 291, 'train': 'train'}
# {'loss': '0.377', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 292, 'train': 'train'}
# {'loss': '0.337', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 293, 'train': 'train'}
# {'loss': '0.448', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 294, 'train': 'train'}
# {'loss': '0.429', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 295, 'train': 'train'}
# {'loss': '0.401', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 296, 'train': 'train'}
# {'loss': '0.392', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 297, 'train': 'train'}
# {'loss': '0.380', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 298, 'train': 'train'}
# {'loss': '0.382', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 299, 'train': 'train'}
# {'loss': '0.372', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 300, 'train': 'train'}
# {'loss': '0.422', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 301, 'train': 'train'}
# {'loss': '0.366', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 302, 'train': 'train'}
# {'loss': '0.334', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 303, 'train': 'train'}
# {'loss': '0.410', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 304, 'train': 'train'}
# {'loss': '0.449', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 305, 'train': 'train'}
# {'loss': '0.379', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 306, 'train': 'train'}
# {'loss': '0.390', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 307, 'train': 'train'}
# {'loss': '0.382', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 308, 'train': 'train'}
# {'loss': '0.408', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 309, 'train': 'train'}
# {'loss': '0.357', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 310, 'train': 'train'}
# {'loss': '0.410', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 311, 'train': 'train'}
# {'loss': '0.394', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 312, 'train': 'train'}
# {'loss': '0.609', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 313, 'train': 'train'}
# {'loss': '0.775', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 314, 'train': 'train'}
# {'loss': '0.775', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 315, 'train': 'train'}
# {'loss': '0.542', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 316, 'train': 'train'}
# {'loss': '0.407', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 317, 'train': 'train'}
# {'loss': '0.401', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 318, 'train': 'train'}
# {'loss': '0.389', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 319, 'train': 'train'}
# {'loss': '0.341', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 320, 'train': 'train'}
# {'loss': '0.452', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 321, 'train': 'train'}
# {'loss': '0.343', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 322, 'train': 'train'}
# {'loss': '0.347', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 323, 'train': 'train'}
# {'loss': '0.420', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 324, 'train': 'train'}
# {'loss': '0.360', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 325, 'train': 'train'}
# {'loss': '0.346', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 326, 'train': 'train'}
# {'loss': '0.480', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 327, 'train': 'train'}
# {'loss': '0.372', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 328, 'train': 'train'}
# {'loss': '0.367', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 329, 'train': 'train'}
# {'loss': '0.444', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 330, 'train': 'train'}
# {'loss': '0.443', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 331, 'train': 'train'}
# {'loss': '0.450', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 332, 'train': 'train'}
# {'loss': '0.463', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 333, 'train': 'train'}
# {'loss': '0.380', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 334, 'train': 'train'}
# {'loss': '0.570', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 335, 'train': 'train'}
# {'loss': '0.488', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 336, 'train': 'train'}
# {'loss': '0.428', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 337, 'train': 'train'}
# {'loss': '0.369', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 338, 'train': 'train'}
# {'loss': '0.353', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 339, 'train': 'train'}
# {'loss': '0.416', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 340, 'train': 'train'}
# {'loss': '0.303', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 341, 'train': 'train'}
# {'loss': '0.356', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 342, 'train': 'train'}
# {'loss': '0.397', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 343, 'train': 'train'}
# {'loss': '0.379', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 344, 'train': 'train'}
# {'loss': '0.410', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 345, 'train': 'train'}
# {'loss': '0.411', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 346, 'train': 'train'}
# {'loss': '0.379', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 347, 'train': 'train'}
# {'loss': '0.440', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 348, 'train': 'train'}
# {'loss': '0.393', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 349, 'train': 'train'}
# {'loss': '0.433', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 350, 'train': 'train'}
# {'loss': '0.361', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 351, 'train': 'train'}
# {'loss': '0.421', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 352, 'train': 'train'}
# {'loss': '0.404', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 353, 'train': 'train'}
# {'loss': '0.393', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 354, 'train': 'train'}
# {'loss': '0.382', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 355, 'train': 'train'}
# {'loss': '0.349', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 356, 'train': 'train'}
# {'loss': '0.366', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 357, 'train': 'train'}
# {'loss': '0.394', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 358, 'train': 'train'}
# {'loss': '0.390', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 359, 'train': 'train'}
# {'loss': '0.357', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 360, 'train': 'train'}
# {'loss': '0.416', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 361, 'train': 'train'}
# {'loss': '0.372', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 362, 'train': 'train'}
# {'loss': '0.304', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 363, 'train': 'train'}
# {'loss': '0.426', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 364, 'train': 'train'}
# {'loss': '0.377', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 365, 'train': 'train'}
# {'loss': '0.373', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 366, 'train': 'train'}
# {'loss': '0.402', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 367, 'train': 'train'}
# {'loss': '0.376', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 368, 'train': 'train'}
# {'loss': '0.354', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 369, 'train': 'train'}
# {'loss': '0.320', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 370, 'train': 'train'}
# {'loss': '0.331', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 371, 'train': 'train'}
# {'loss': '0.374', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 372, 'train': 'train'}
# {'loss': '0.379', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 373, 'train': 'train'}
# {'loss': '0.470', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 374, 'train': 'train'}
# {'loss': '0.396', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 375, 'train': 'train'}
# {'loss': '0.414', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 376, 'train': 'train'}
# {'loss': '0.410', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 377, 'train': 'train'}
# {'loss': '0.350', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 378, 'train': 'train'}
# {'loss': '0.350', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 379, 'train': 'train'}
# {'loss': '0.414', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 380, 'train': 'train'}
# {'loss': '0.348', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 381, 'train': 'train'}
# {'loss': '0.360', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 382, 'train': 'train'}
# {'loss': '0.415', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 383, 'train': 'train'}
# {'loss': '0.388', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 384, 'train': 'train'}
# {'loss': '0.476', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 385, 'train': 'train'}
# {'loss': '0.511', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 386, 'train': 'train'}
# {'loss': '0.501', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 387, 'train': 'train'}
# {'loss': '0.413', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 388, 'train': 'train'}
# {'loss': '0.458', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 389, 'train': 'train'}
# {'loss': '0.434', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 390, 'train': 'train'}
# {'loss': '0.413', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 391, 'train': 'train'}
# {'loss': '0.354', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 392, 'train': 'train'}
# {'loss': '0.389', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 393, 'train': 'train'}
# {'loss': '0.339', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 394, 'train': 'train'}
# {'loss': '0.377', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 395, 'train': 'train'}
# {'loss': '0.419', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 396, 'train': 'train'}
# {'loss': '0.303', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 397, 'train': 'train'}
# {'loss': '0.337', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 398, 'train': 'train'}
# {'loss': '0.355', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 399, 'train': 'train'}
# {'loss': '0.363', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 400, 'train': 'train'}
# {'loss': '0.478', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 401, 'train': 'train'}
# {'loss': '0.462', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 402, 'train': 'train'}
# {'loss': '0.533', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 403, 'train': 'train'}
# {'loss': '0.339', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 404, 'train': 'train'}
# {'loss': '0.412', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 405, 'train': 'train'}
# {'loss': '0.408', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 406, 'train': 'train'}
# {'loss': '0.351', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 407, 'train': 'train'}
# {'loss': '0.402', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 408, 'train': 'train'}
# {'loss': '0.355', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 409, 'train': 'train'}
# {'loss': '0.320', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 410, 'train': 'train'}
# {'loss': '0.397', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 411, 'train': 'train'}
# {'loss': '0.368', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 412, 'train': 'train'}
# {'loss': '0.401', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 413, 'train': 'train'}
# {'loss': '0.354', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 414, 'train': 'train'}
# {'loss': '0.364', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 415, 'train': 'train'}
# {'loss': '0.413', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 416, 'train': 'train'}
# {'loss': '0.396', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 417, 'train': 'train'}
# {'loss': '0.340', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 418, 'train': 'train'}
# {'loss': '0.393', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 419, 'train': 'train'}
# {'loss': '0.306', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 420, 'train': 'train'}
# {'loss': '0.370', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 421, 'train': 'train'}
# {'loss': '0.393', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 422, 'train': 'train'}
# {'loss': '0.386', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 423, 'train': 'train'}
# {'loss': '0.384', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 424, 'train': 'train'}
# {'loss': '0.386', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 425, 'train': 'train'}
# {'loss': '0.386', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 426, 'train': 'train'}
# {'loss': '0.327', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 427, 'train': 'train'}
# {'loss': '0.346', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 428, 'train': 'train'}
# {'loss': '0.374', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 429, 'train': 'train'}
# {'loss': '0.385', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 430, 'train': 'train'}
# {'loss': '0.456', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 431, 'train': 'train'}
# {'loss': '0.412', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 432, 'train': 'train'}
# {'loss': '0.331', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 433, 'train': 'train'}
# {'loss': '0.385', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 434, 'train': 'train'}
# {'loss': '0.419', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 435, 'train': 'train'}
# {'loss': '0.390', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 436, 'train': 'train'}
# {'loss': '0.363', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 437, 'train': 'train'}
# {'loss': '0.400', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 438, 'train': 'train'}
# {'loss': '0.365', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 439, 'train': 'train'}
# {'loss': '0.422', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 440, 'train': 'train'}
# {'loss': '0.356', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 441, 'train': 'train'}
# {'loss': '0.340', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 442, 'train': 'train'}
# {'loss': '0.425', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 443, 'train': 'train'}
# {'loss': '0.379', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 444, 'train': 'train'}
# {'loss': '0.363', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 445, 'train': 'train'}
# {'loss': '0.398', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 446, 'train': 'train'}
# {'loss': '0.309', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 447, 'train': 'train'}
# {'loss': '0.352', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 448, 'train': 'train'}
# {'loss': '0.369', 'epoch': 448, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 449, 'train': 'train'}
# {'loss': '0.399', 'epoch': 449, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 450, 'train': 'train'}
# {'loss': '0.438', 'epoch': 450, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 451, 'train': 'train'}
# {'loss': '0.365', 'epoch': 451, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 452, 'train': 'train'}
# {'loss': '0.381', 'epoch': 452, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 453, 'train': 'train'}
# {'loss': '0.378', 'epoch': 453, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 454, 'train': 'train'}
# {'loss': '0.336', 'epoch': 454, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 455, 'train': 'train'}
# {'loss': '0.386', 'epoch': 455, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 456, 'train': 'train'}
# {'loss': '0.390', 'epoch': 456, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 457, 'train': 'train'}
# {'loss': '0.363', 'epoch': 457, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 458, 'train': 'train'}
# {'loss': '0.429', 'epoch': 458, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 459, 'train': 'train'}
# {'loss': '0.428', 'epoch': 459, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 460, 'train': 'train'}
# {'loss': '0.361', 'epoch': 460, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 461, 'train': 'train'}
# {'loss': '0.468', 'epoch': 461, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 462, 'train': 'train'}
# {'loss': '0.401', 'epoch': 462, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 463, 'train': 'train'}
# {'loss': '0.382', 'epoch': 463, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 464, 'train': 'train'}
# {'loss': '0.441', 'epoch': 464, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 465, 'train': 'train'}
# {'loss': '0.402', 'epoch': 465, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 466, 'train': 'train'}
# {'loss': '0.386', 'epoch': 466, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 467, 'train': 'train'}
# {'loss': '0.375', 'epoch': 467, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 468, 'train': 'train'}
# {'loss': '0.341', 'epoch': 468, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 469, 'train': 'train'}
# {'loss': '0.413', 'epoch': 469, 'train': 'eval'}
# ...
# {'loss': '0.038', 'epoch': 1859, 'train': 'train'}
# {'loss': '2.760', 'epoch': 1859, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 1860, 'train': 'train'}
# {'loss': '2.295', 'epoch': 1860, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1861, 'train': 'train'}
# {'loss': '2.610', 'epoch': 1861, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1862, 'train': 'train'}
# {'loss': '1.947', 'epoch': 1862, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1863, 'train': 'train'}
# {'loss': '1.594', 'epoch': 1863, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1864, 'train': 'train'}
# {'loss': '2.536', 'epoch': 1864, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1865, 'train': 'train'}
# {'loss': '3.007', 'epoch': 1865, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1866, 'train': 'train'}
# {'loss': '1.907', 'epoch': 1866, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1867, 'train': 'train'}
# {'loss': '2.590', 'epoch': 1867, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1868, 'train': 'train'}
# {'loss': '1.972', 'epoch': 1868, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1869, 'train': 'train'}
# {'loss': '2.060', 'epoch': 1869, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1870, 'train': 'train'}
# {'loss': '1.629', 'epoch': 1870, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1871, 'train': 'train'}
# {'loss': '2.900', 'epoch': 1871, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1872, 'train': 'train'}
# {'loss': '2.738', 'epoch': 1872, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1873, 'train': 'train'}
# {'loss': '2.547', 'epoch': 1873, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1874, 'train': 'train'}
# {'loss': '1.754', 'epoch': 1874, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1875, 'train': 'train'}
# {'loss': '2.128', 'epoch': 1875, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1876, 'train': 'train'}
# {'loss': '1.822', 'epoch': 1876, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1877, 'train': 'train'}
# {'loss': '1.420', 'epoch': 1877, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1878, 'train': 'train'}
# {'loss': '2.708', 'epoch': 1878, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1879, 'train': 'train'}
# {'loss': '2.618', 'epoch': 1879, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1880, 'train': 'train'}
# {'loss': '1.817', 'epoch': 1880, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1881, 'train': 'train'}
# {'loss': '1.782', 'epoch': 1881, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1882, 'train': 'train'}
# {'loss': '3.830', 'epoch': 1882, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1883, 'train': 'train'}
# {'loss': '2.588', 'epoch': 1883, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1884, 'train': 'train'}
# {'loss': '2.202', 'epoch': 1884, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1885, 'train': 'train'}
# {'loss': '1.240', 'epoch': 1885, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1886, 'train': 'train'}
# {'loss': '2.905', 'epoch': 1886, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1887, 'train': 'train'}
# {'loss': '2.461', 'epoch': 1887, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1888, 'train': 'train'}
# {'loss': '2.544', 'epoch': 1888, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1889, 'train': 'train'}
# {'loss': '3.149', 'epoch': 1889, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1890, 'train': 'train'}
# {'loss': '2.141', 'epoch': 1890, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1891, 'train': 'train'}
# {'loss': '1.556', 'epoch': 1891, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1892, 'train': 'train'}
# {'loss': '2.895', 'epoch': 1892, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1893, 'train': 'train'}
# {'loss': '2.378', 'epoch': 1893, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1894, 'train': 'train'}
# {'loss': '2.659', 'epoch': 1894, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1895, 'train': 'train'}
# {'loss': '2.835', 'epoch': 1895, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1896, 'train': 'train'}
# {'loss': '2.067', 'epoch': 1896, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1897, 'train': 'train'}
# {'loss': '2.208', 'epoch': 1897, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1898, 'train': 'train'}
# {'loss': '1.823', 'epoch': 1898, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1899, 'train': 'train'}
# {'loss': '2.173', 'epoch': 1899, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1900, 'train': 'train'}
# {'loss': '2.728', 'epoch': 1900, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1901, 'train': 'train'}
# {'loss': '3.167', 'epoch': 1901, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1902, 'train': 'train'}
# {'loss': '2.563', 'epoch': 1902, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1903, 'train': 'train'}
# {'loss': '2.499', 'epoch': 1903, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1904, 'train': 'train'}
# {'loss': '2.884', 'epoch': 1904, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1905, 'train': 'train'}
# {'loss': '3.377', 'epoch': 1905, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1906, 'train': 'train'}
# {'loss': '1.663', 'epoch': 1906, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1907, 'train': 'train'}
# {'loss': '3.432', 'epoch': 1907, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1908, 'train': 'train'}
# {'loss': '2.321', 'epoch': 1908, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1909, 'train': 'train'}
# {'loss': '2.507', 'epoch': 1909, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1910, 'train': 'train'}
# {'loss': '2.455', 'epoch': 1910, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1911, 'train': 'train'}
# {'loss': '2.654', 'epoch': 1911, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1912, 'train': 'train'}
# {'loss': '2.178', 'epoch': 1912, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1913, 'train': 'train'}
# {'loss': '1.996', 'epoch': 1913, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1914, 'train': 'train'}
# {'loss': '2.217', 'epoch': 1914, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1915, 'train': 'train'}
# {'loss': '1.603', 'epoch': 1915, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1916, 'train': 'train'}
# {'loss': '3.479', 'epoch': 1916, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1917, 'train': 'train'}
# {'loss': '2.780', 'epoch': 1917, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1918, 'train': 'train'}
# {'loss': '1.553', 'epoch': 1918, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1919, 'train': 'train'}
# {'loss': '2.491', 'epoch': 1919, 'train': 'eval'}
# {'loss': '0.033', 'epoch': 1920, 'train': 'train'}
# {'loss': '2.056', 'epoch': 1920, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1921, 'train': 'train'}
# {'loss': '3.408', 'epoch': 1921, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1922, 'train': 'train'}
# {'loss': '2.378', 'epoch': 1922, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1923, 'train': 'train'}
# {'loss': '2.468', 'epoch': 1923, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1924, 'train': 'train'}
# {'loss': '2.342', 'epoch': 1924, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1925, 'train': 'train'}
# {'loss': '2.237', 'epoch': 1925, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1926, 'train': 'train'}
# {'loss': '3.392', 'epoch': 1926, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1927, 'train': 'train'}
# {'loss': '3.126', 'epoch': 1927, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1928, 'train': 'train'}
# {'loss': '2.687', 'epoch': 1928, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1929, 'train': 'train'}
# {'loss': '2.762', 'epoch': 1929, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1930, 'train': 'train'}
# {'loss': '2.505', 'epoch': 1930, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1931, 'train': 'train'}
# {'loss': '1.777', 'epoch': 1931, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1932, 'train': 'train'}
# {'loss': '2.525', 'epoch': 1932, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1933, 'train': 'train'}
# {'loss': '3.141', 'epoch': 1933, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1934, 'train': 'train'}
# {'loss': '2.983', 'epoch': 1934, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1935, 'train': 'train'}
# {'loss': '2.859', 'epoch': 1935, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1936, 'train': 'train'}
# {'loss': '2.435', 'epoch': 1936, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1937, 'train': 'train'}
# {'loss': '2.609', 'epoch': 1937, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1938, 'train': 'train'}
# {'loss': '2.044', 'epoch': 1938, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1939, 'train': 'train'}
# {'loss': '1.943', 'epoch': 1939, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1940, 'train': 'train'}
# {'loss': '2.444', 'epoch': 1940, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1941, 'train': 'train'}
# {'loss': '3.306', 'epoch': 1941, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1942, 'train': 'train'}
# {'loss': '2.533', 'epoch': 1942, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1943, 'train': 'train'}
# {'loss': '2.770', 'epoch': 1943, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1944, 'train': 'train'}
# {'loss': '4.088', 'epoch': 1944, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1945, 'train': 'train'}
# {'loss': '2.429', 'epoch': 1945, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1946, 'train': 'train'}
# {'loss': '2.501', 'epoch': 1946, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1947, 'train': 'train'}
# {'loss': '1.743', 'epoch': 1947, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1948, 'train': 'train'}
# {'loss': '3.080', 'epoch': 1948, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1949, 'train': 'train'}
# {'loss': '2.753', 'epoch': 1949, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1950, 'train': 'train'}
# {'loss': '2.755', 'epoch': 1950, 'train': 'eval'}
# {'loss': '0.032', 'epoch': 1951, 'train': 'train'}
# {'loss': '1.726', 'epoch': 1951, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1952, 'train': 'train'}
# {'loss': '2.028', 'epoch': 1952, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1953, 'train': 'train'}
# {'loss': '2.644', 'epoch': 1953, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1954, 'train': 'train'}
# {'loss': '2.574', 'epoch': 1954, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1955, 'train': 'train'}
# {'loss': '2.736', 'epoch': 1955, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1956, 'train': 'train'}
# {'loss': '2.966', 'epoch': 1956, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1957, 'train': 'train'}
# {'loss': '1.936', 'epoch': 1957, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1958, 'train': 'train'}
# {'loss': '1.589', 'epoch': 1958, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1959, 'train': 'train'}
# {'loss': '1.814', 'epoch': 1959, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1960, 'train': 'train'}
# {'loss': '2.024', 'epoch': 1960, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1961, 'train': 'train'}
# {'loss': '2.915', 'epoch': 1961, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1962, 'train': 'train'}
# {'loss': '1.739', 'epoch': 1962, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1963, 'train': 'train'}
# {'loss': '1.771', 'epoch': 1963, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1964, 'train': 'train'}
# {'loss': '2.383', 'epoch': 1964, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1965, 'train': 'train'}
# {'loss': '2.624', 'epoch': 1965, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1966, 'train': 'train'}
# {'loss': '1.830', 'epoch': 1966, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1967, 'train': 'train'}
# {'loss': '2.898', 'epoch': 1967, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1968, 'train': 'train'}
# {'loss': '2.353', 'epoch': 1968, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1969, 'train': 'train'}
# {'loss': '2.080', 'epoch': 1969, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1970, 'train': 'train'}
# {'loss': '2.921', 'epoch': 1970, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1971, 'train': 'train'}
# {'loss': '2.209', 'epoch': 1971, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1972, 'train': 'train'}
# {'loss': '1.894', 'epoch': 1972, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1973, 'train': 'train'}
# {'loss': '1.963', 'epoch': 1973, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1974, 'train': 'train'}
# {'loss': '1.944', 'epoch': 1974, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1975, 'train': 'train'}
# {'loss': '2.287', 'epoch': 1975, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1976, 'train': 'train'}
# {'loss': '3.059', 'epoch': 1976, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1977, 'train': 'train'}
# {'loss': '2.309', 'epoch': 1977, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1978, 'train': 'train'}
# {'loss': '2.040', 'epoch': 1978, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1979, 'train': 'train'}
# {'loss': '2.505', 'epoch': 1979, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1980, 'train': 'train'}
# {'loss': '2.247', 'epoch': 1980, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1981, 'train': 'train'}
# {'loss': '3.197', 'epoch': 1981, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1982, 'train': 'train'}
# {'loss': '3.054', 'epoch': 1982, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1983, 'train': 'train'}
# {'loss': '2.267', 'epoch': 1983, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1984, 'train': 'train'}
# {'loss': '1.881', 'epoch': 1984, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1985, 'train': 'train'}
# {'loss': '2.833', 'epoch': 1985, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1986, 'train': 'train'}
# {'loss': '3.106', 'epoch': 1986, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1987, 'train': 'train'}
# {'loss': '2.479', 'epoch': 1987, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1988, 'train': 'train'}
# {'loss': '2.607', 'epoch': 1988, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1989, 'train': 'train'}
# {'loss': '2.838', 'epoch': 1989, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1990, 'train': 'train'}
# {'loss': '2.674', 'epoch': 1990, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1991, 'train': 'train'}
# {'loss': '2.965', 'epoch': 1991, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1992, 'train': 'train'}
# {'loss': '2.845', 'epoch': 1992, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1993, 'train': 'train'}
# {'loss': '2.574', 'epoch': 1993, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1994, 'train': 'train'}
# {'loss': '3.795', 'epoch': 1994, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1995, 'train': 'train'}
# {'loss': '2.106', 'epoch': 1995, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1996, 'train': 'train'}
# {'loss': '2.187', 'epoch': 1996, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1997, 'train': 'train'}
# {'loss': '2.448', 'epoch': 1997, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1998, 'train': 'train'}
# {'loss': '1.395', 'epoch': 1998, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1999, 'train': 'train'}
# {'loss': '2.182', 'epoch': 1999, 'train': 'eval'}
# VBox(children=(Label(value='1060.745 MB of 1066.343 MB uploaded\r'), FloatProgress(value=0.9947506957326001, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▃▂▁▁▁▁▁▁▁▁▁▁▂▂▃▂▁▃▂▂▂▃▃▃▃▃▃▄▄▃▅▄▆▃█▅▅▆▇▆</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃▂▁▁▁▁▁▁▁▁▁▁▂▂▃▂▁▃▂▂▂▃▃▃▃▃▃▄▄▃▅▄▆▃█▅▅▆▇▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>2.18169</td></tr><tr><td>train_loss</td><td>0.038</td></tr><tr><td>val_loss</td><td>2.182</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">divine-fire-4</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/rughz4d1' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/rughz4d1</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a><br/>Synced 6 W&B file(s), 2000 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_100836-rughz4d1/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# lr = 0.5e-4
# epochs = 1500
# opt_func = partial(optim.AdamW, eps=1e-5)
# tmax = epochs * len(dls.train)
# sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
# #wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
# cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
# learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %% [markdown]
# learn.fit(epochs)

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %% [markdown]
# cmodel = torch.load('models/data_aug2.pkl')
# del(cmodel[8])
# del(cmodel[7])
#
# @inplace
# def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]
#
# bs = 2048
# tds = dsd.with_transform(transformi)
# dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)
#
# dt = dls.train
# xb,yb = next(iter(dt))
#
# ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (64,4,8,8)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(1.), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)

# %%
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(1.), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)
