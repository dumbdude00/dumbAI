# %%
#| default_exp diffusion

# %% [markdown]
# # [fail] Diffusion unet

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
#| export
from miniai.imports import *

from einops import rearrange
from fastprogress import progress_bar
from diffusers import AutoencoderKL

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
class GPUCUDAMissing(BaseException):
    pass
    
try:
    if torch.cuda.is_available():
        print('# of GPUs available = ', torch.cuda.device_count())
    else:
        raise GPUCUDAMissing
except:
    print("ERROR: GPU is missing")
# Out:
# # of GPUs available =  1

# %%
xl,yl = 'image','label'
name = "zh-plus/tiny-imagenet"
bs = 50
dsd = load_dataset(name)

# %%
dsd['train'] = dsd['train'].select(range(500))

# %%
dsd['valid'] = dsd['valid'].select(range(50))

# %%
class TinyHFDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hg_ds):
        self.ds = hg_ds
        # the 2 lines below must be done here because the execution of "ds['train']['image']" takes 18seconds
        # once it has executed, indexing it is very fast (5 milliseconds)
        self.image = hg_ds[xl]
        self.label = hg_ds[yl]
    def __len__(self): return self.ds.num_rows
    def __getitem__(self, i): return TF.to_tensor(self.image[i]), self.label[i]

# %%
tds = TinyHFDS(dsd['train'])

# %%
vds = TinyHFDS(dsd['valid'])

# %%
dl = DataLoader(tds, batch_size=bs, num_workers=0)
xb,yb = next(iter(dl))
show_images(xb[:16], imsize=2)

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").cuda().requires_grad_(False)

# %%
# %%time
lats = vae.encode(xb.cuda())
# Out:
# CPU times: user 613 ms, sys: 428 ms, total: 1.04 s
# Wall time: 3.1 s

# %%
class LatsDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hfds):
        lbl = hfds[yl]
        self.label = lbl + lbl
        imgs = hfds[xl]
        list_tensor = [ TF.to_tensor(x) for i, x in enumerate(imgs+imgs)]
        batch = torch.stack(list_tensor)
        #batch.shape
        lats = vae.encode(batch.cuda())
        #lats.latent_dist.mean.shape
        self.lats = lats.latent_dist.mean
        
    def __len__(self): return len(self.lats)
    def __getitem__(self, i): return self.lats[i], self.label[i]

# %%
tlds = LatsDS(dsd['train'])
vlds = LatsDS(dsd['valid'])

# %% [markdown]
# ### Defs: TfmDS, tfmx, tfmy

# %%
class TfmDS:
    def __init__(self, ds, tfmx=fc.noop, tfmy=fc.noop): self.ds,self.tfmx,self.tfmy = ds,tfmx,tfmy
    def __len__(self): return len(self.ds)
    def __getitem__(self, i):
        x,y = self.ds[i]
        return self.tfmx(x),self.tfmy(y)

# %%
def tfmx(x):
    return x

# %%
def tfmy(y): 
    return y

# %% [markdown]
# ### Generate a batch and Decode batch

# %%
tfm_tds = TfmDS(tlds, tfmx, tfmy)
tfm_vds = TfmDS(vlds, tfmx, tfmy)

# %%
def collate_fn(b):
    b = default_collate(b)
    return b

# %%
#bs=512

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_fn))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb.shape, yb.shape, xb.min(), xb.max()
# Out:
# (torch.Size([50, 4, 8, 8]),
#  torch.Size([50]),
#  tensor(-16.4384, device='cuda:0'),
#  tensor(21.9615, device='cuda:0'))

# %%
show_images(((xb[:16,:3])/4).sigmoid() , imsize=2)

# %%
show_images(to_cpu(vae.decode(xb[:16]))['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# ### DDIM

# %%
#| export
def abar(t): return (t*math.pi/2).cos()**2
def inv_abar(x): return x.sqrt().acos()*2/math.pi

def noisify(x0):
    device = x0.device
    n = len(x0)
    t = torch.rand(n,).to(x0).clamp(0,0.999)
    ε = torch.randn(x0.shape, device=device)
    abar_t = abar(t).reshape(-1, 1, 1, 1).to(device)
    xt = abar_t.sqrt()*x0 + (1-abar_t).sqrt()*ε
    return (xt, t.to(device)), ε

def collate_ddpm(b): 
    b = default_collate(b)
    return noisify(b[0]*0.2) # jeremy scaled the lats by 0.2
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=0)

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_ddpm))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb[0].shape, xb[1].shape, yb.shape
# Out:
# (torch.Size([50, 4, 8, 8]), torch.Size([50]), torch.Size([50, 4, 8, 8]))

# %%
xb[0].min(), xb[0].max()
# Out:
# (tensor(-3.9343, device='cuda:0'), tensor(4.0962, device='cuda:0'))

# %%
show_images((xb[0][:9,0]*5).clamp(0,1))

# %% [markdown]
# ## Train

# %% [markdown]
# Based on Diffusers

# %%
#| export
def timestep_embedding(tsteps, emb_dim, max_period= 10000):
    exponent = -math.log(max_period) * torch.linspace(0, 1, emb_dim//2, device=tsteps.device)
    emb = tsteps[:,None].float() * exponent.exp()[None,:]
    emb = torch.cat([emb.sin(), emb.cos()], dim=-1)
    return F.pad(emb, (0,1,0,0)) if emb_dim%2==1 else emb

# %%
#| export
def pre_conv(ni, nf, ks=3, stride=1, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2, bias=bias))
    return layers

# %%
#| export
def upsample(nf): return nn.Sequential(nn.Upsample(scale_factor=2.), nn.Conv2d(nf, nf, 3, padding=1))

# %%
#| export
def lin(ni, nf, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Linear(ni, nf, bias=bias))
    return layers

# %%
# This version is giving poor results - use the cell below instead
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans):
        super().__init__()
        self.attn = nn.MultiheadAttention(ni, ni//attn_chans, batch_first=True)
        self.norm = nn.BatchNorm2d(ni)

    def forward(self, x):
        n,c,h,w = x.shape
        x = self.norm(x).view(n, c, -1).transpose(1, 2)
        x = self.attn(x, x, x, need_weights=False)[0]
        return x.transpose(1,2).reshape(n,c,h,w)

# %%
#| export
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans, transpose=True):
        super().__init__()
        self.nheads = ni//attn_chans
        self.scale = math.sqrt(ni/self.nheads)
        self.norm = nn.LayerNorm(ni)
        self.qkv = nn.Linear(ni, ni*3)
        self.proj = nn.Linear(ni, ni)
        self.t = transpose
    
    def forward(self, x):
        n,c,s = x.shape
        if self.t: x = x.transpose(1, 2)
        x = self.norm(x)
        x = self.qkv(x)
        x = rearrange(x, 'n s (h d) -> (n h) s d', h=self.nheads)
        q,k,v = torch.chunk(x, 3, dim=-1)
        s = (q@k.transpose(1,2))/self.scale
        x = s.softmax(dim=-1)@v
        x = rearrange(x, '(n h) s d -> n s (h d)', h=self.nheads)
        x = self.proj(x)
        if self.t: x = x.transpose(1, 2)
        return x

# %%
#| export
class SelfAttention2D(SelfAttention):
    def forward(self, x):
        n,c,h,w = x.shape
        return super().forward(x.view(n, c, -1)).reshape(n,c,h,w)

# %%
#| export
class EmbResBlock(nn.Module):
    def __init__(self, n_emb, ni, nf=None, ks=3, act=nn.SiLU, norm=nn.BatchNorm2d, attn_chans=0):
        super().__init__()
        if nf is None: nf = ni
        self.emb_proj = nn.Linear(n_emb, nf*2)
        self.conv1 = pre_conv(ni, nf, ks, act=None, norm=norm)
        self.conv2 = pre_conv(nf, nf, ks, act=act, norm=norm)
        self.idconv = fc.noop if ni==nf else nn.Conv2d(ni, nf, 1)
        self.attn = False
        if attn_chans: self.attn = SelfAttention2D(nf, attn_chans)

    def forward(self, x, t):
        inp = x
        x = self.conv1(x)
        emb = self.emb_proj(F.silu(t))[:, :, None, None]
        scale,shift = torch.chunk(emb, 2, dim=1)
        x = x*(1+scale) + shift
        x = self.conv2(x)
        x = x + self.idconv(inp)
        if self.attn: x = x + self.attn(x)
        return x

# %%
#| export
def saved(m, blk):
    m_ = m.forward

    @wraps(m.forward)
    def _f(*args, **kwargs):
        res = m_(*args, **kwargs)
        blk.saved.append(res)
        return res

    m.forward = _f
    return m

# %%
#| export
class DownBlock(nn.Module):
    def __init__(self, n_emb, ni, nf, add_down=True, num_layers=1, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList([saved(EmbResBlock(n_emb, ni if i==0 else nf, nf, attn_chans=attn_chans), self)
                                      for i in range(num_layers)])
        self.down = saved(nn.Conv2d(nf, nf, 3, stride=2, padding=1), self) if add_down else nn.Identity()

    def forward(self, x, t):
        self.saved = []
        for resnet in self.resnets: x = resnet(x, t)
        x = self.down(x)
        return x

# %%
#| export
class UpBlock(nn.Module):
    def __init__(self, n_emb, ni, prev_nf, nf, add_up=True, num_layers=2, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList(
            [EmbResBlock(n_emb, (prev_nf if i==0 else nf)+(ni if (i==num_layers-1) else nf), nf, attn_chans=attn_chans)
            for i in range(num_layers)])
        self.up = upsample(nf) if add_up else nn.Identity()

    def forward(self, x, t, ups):
        for resnet in self.resnets: x = resnet(torch.cat([x, ups.pop()], dim=1), t)
        return self.up(x)

# %%
class LearnEmbSS(nn.Module):
    def __init__(self, sz, ni):
        super().__init__()
        self.scale = nn.Parameter(torch.zeros(sz, ni))
        self.shift = nn.Parameter(torch.zeros(sz, ni))

    def forward(self, x): return x*self.scale + self.shift

# %%
def _mlp(ni, nh):
    return nn.Sequential(nn.Linear(ni,nh), nn.GELU(), nn.LayerNorm(nh), nn.Linear(nh,ni))

# %%
class EmbTransformerBlk(nn.Module):
    def __init__(self, n_emb, ni, attn_chans=8):
        super().__init__()
        self.attn = SelfAttention(ni, attn_chans=attn_chans, transpose=False)
        self.mlp = _mlp(ni, ni*4)
        self.nrm1 = nn.LayerNorm(ni)
        self.nrm2 = nn.LayerNorm(ni)
        self.emb_proj = nn.Linear(n_emb, ni*2)

    def forward(self, x, t):
        emb = self.emb_proj(F.silu(t))[:, None]
        scale,shift = torch.chunk(emb, 2, dim=2)
        x = x + self.attn(self.nrm1(x))
        x = x*(1+scale) + shift
        return x + self.mlp(self.nrm2(x))

# %%
img_vec_len = 1
class SimpleDiffusion(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, nfs=(224,448,672,896), num_layers=1,
                 attn_chans=8, attn_start=1, n_mids=8):
        super().__init__()
        self.conv_in = nn.Conv2d(in_channels, nfs[0], kernel_size=3, padding=1)
        self.n_temb = nf = nfs[0]
        n_emb = nf*4
        self.emb_mlp = nn.Sequential(lin(self.n_temb, n_emb, norm=nn.BatchNorm1d),
                                     lin(n_emb, n_emb))
        self.downs = nn.ModuleList()
        n = len(nfs)
        for i in range(n):
            ni = nf
            nf = nfs[i]
            self.downs.append(DownBlock(n_emb, ni, nf, add_down=i!=n-1, num_layers=num_layers,
                                        attn_chans=0 if i<attn_start else attn_chans))

        self.le = LearnEmbSS(img_vec_len, nf)
        self.mids = nn.ModuleList([EmbTransformerBlk(n_emb, nf) for _ in range(n_mids)])

        rev_nfs = list(reversed(nfs))
        nf = rev_nfs[0]
        self.ups = nn.ModuleList()
        for i in range(n):
            prev_nf = nf
            nf = rev_nfs[i]
            ni = rev_nfs[min(i+1, len(nfs)-1)]
            self.ups.append(UpBlock(n_emb, ni, prev_nf, nf, add_up=i!=n-1, num_layers=num_layers+1,
                                    attn_chans=0 if i>=n-attn_start else attn_chans))
        self.conv_out = pre_conv(nfs[0], out_channels, act=nn.SiLU, norm=nn.BatchNorm2d, bias=False)

    def forward(self, inp):
        x,t = inp
        temb = timestep_embedding(t, self.n_temb)
        emb = self.emb_mlp(temb)
        x = self.conv_in(x)
        saved = [x]
        for block in self.downs: x = block(x, emb)
        saved += [p for o in self.downs for p in o.saved]
        n,c,h,w = x.shape
        x = self.le(x.reshape(n,c,-1).transpose(1,2))
        for block in self.mids: x = block(x, emb)
        x = x.transpose(1,2).reshape(n,c,h,w)
        for block in self.ups: x = block(x, emb, saved)
        return self.conv_out(x)

# %%
#| export
def ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp=True):
    sig = ((bbar_t1/bbar_t).sqrt() * (1-abar_t/abar_t1).sqrt()) * eta
    x_0_hat = ((x_t-(1-abar_t).sqrt()*noise) / abar_t.sqrt())
    if clamp: x_0_hat = x_0_hat.clamp(-1,1)
    if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
    x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
    x_t += sig * torch.randn(x_t.shape).to(x_t)
    return x_0_hat,x_t

# %%
#| export
@torch.no_grad()
def sample(f, model, sz, steps, eta=1., clamp=True, progress=False):
    model.eval()
    ts = torch.linspace(1-1/steps,0,steps)
    x_t = torch.randn(sz).cuda()
    preds = []
    tbe = progress_bar(ts) if progress else ts 
    for i,t in enumerate(tbe):
        t = t[None].cuda()
        abar_t = abar(t)
        noise = model((x_t, t))
        abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
        x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
        preds.append(x_0_hat.float().cpu())
    return preds

# %%
import wandb

class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project='ddpm_goldfish_64x64_clip', **metrics):
        fc.store_attr()
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d):
        #import pdb; pdb.set_trace()
        if learn.model.training: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
            wandb.log({'samples':self.sample_figure(learn)})
        print(d)

        
    def sample_figure(self, learn):
        with torch.no_grad():
            preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
        s = to_cpu(vae.decode(preds[-1].cuda()*5))
        s = s['sample'].clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16, imsize=3)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME'] = '09_diffusion-attn-cond_tin_goldfish_64x64_CLIP_i5.ipynb'
lr = 1e-4
epochs = 2000
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'smaller bs'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
#model = EmbUNetModel(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2)
model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512,1024), num_layers=2, attn_chans=4, attn_start=0, n_mids=1)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# wandb: Currently logged in as: dumbdude (dumbdude-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_155052-hwhit4sd</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/hwhit4sd' target="_blank">effortless-smoke-10</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/hwhit4sd' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/hwhit4sd</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='99' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.95% [99/2000 08:17&lt;2:39:13]
#     </div>
#
#
#
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00 0.395]
#     </div>
# {'loss': '0.978', 'epoch': 0, 'train': 'train'}
# {'loss': '0.960', 'epoch': 0, 'train': 'eval'}
# {'loss': '0.907', 'epoch': 1, 'train': 'train'}
# {'loss': '0.884', 'epoch': 1, 'train': 'eval'}
# {'loss': '0.847', 'epoch': 2, 'train': 'train'}
# {'loss': '0.827', 'epoch': 2, 'train': 'eval'}
# {'loss': '0.791', 'epoch': 3, 'train': 'train'}
# {'loss': '0.755', 'epoch': 3, 'train': 'eval'}
# {'loss': '0.727', 'epoch': 4, 'train': 'train'}
# {'loss': '0.733', 'epoch': 4, 'train': 'eval'}
# {'loss': '0.667', 'epoch': 5, 'train': 'train'}
# {'loss': '0.648', 'epoch': 5, 'train': 'eval'}
# {'loss': '0.630', 'epoch': 6, 'train': 'train'}
# {'loss': '0.640', 'epoch': 6, 'train': 'eval'}
# {'loss': '0.599', 'epoch': 7, 'train': 'train'}
# {'loss': '0.573', 'epoch': 7, 'train': 'eval'}
# {'loss': '0.561', 'epoch': 8, 'train': 'train'}
# {'loss': '0.560', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.548', 'epoch': 9, 'train': 'train'}
# {'loss': '0.519', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.524', 'epoch': 10, 'train': 'train'}
# {'loss': '0.526', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.513', 'epoch': 11, 'train': 'train'}
# {'loss': '0.475', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.499', 'epoch': 12, 'train': 'train'}
# {'loss': '0.510', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.480', 'epoch': 13, 'train': 'train'}
# {'loss': '0.485', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.467', 'epoch': 14, 'train': 'train'}
# {'loss': '0.441', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.481', 'epoch': 15, 'train': 'train'}
# {'loss': '0.472', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.472', 'epoch': 16, 'train': 'train'}
# {'loss': '0.473', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 17, 'train': 'train'}
# {'loss': '0.435', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.464', 'epoch': 18, 'train': 'train'}
# {'loss': '0.505', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.462', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.457', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.450', 'epoch': 20, 'train': 'train'}
# {'loss': '0.508', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 21, 'train': 'train'}
# {'loss': '0.480', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.446', 'epoch': 22, 'train': 'train'}
# {'loss': '0.433', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.448', 'epoch': 23, 'train': 'train'}
# {'loss': '0.458', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.439', 'epoch': 24, 'train': 'train'}
# {'loss': '0.483', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.433', 'epoch': 25, 'train': 'train'}
# {'loss': '0.478', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.424', 'epoch': 26, 'train': 'train'}
# {'loss': '0.419', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 27, 'train': 'train'}
# {'loss': '0.423', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.427', 'epoch': 28, 'train': 'train'}
# {'loss': '0.473', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.420', 'epoch': 29, 'train': 'train'}
# {'loss': '0.470', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.428', 'epoch': 30, 'train': 'train'}
# {'loss': '0.411', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.421', 'epoch': 31, 'train': 'train'}
# {'loss': '0.426', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 32, 'train': 'train'}
# {'loss': '0.437', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.416', 'epoch': 33, 'train': 'train'}
# {'loss': '0.354', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 34, 'train': 'train'}
# {'loss': '0.443', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 35, 'train': 'train'}
# {'loss': '0.437', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 36, 'train': 'train'}
# {'loss': '0.421', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 37, 'train': 'train'}
# {'loss': '0.386', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 38, 'train': 'train'}
# {'loss': '0.392', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 39, 'train': 'train'}
# {'loss': '0.435', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 40, 'train': 'train'}
# {'loss': '0.414', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 41, 'train': 'train'}
# {'loss': '0.415', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.400', 'epoch': 42, 'train': 'train'}
# {'loss': '0.449', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.400', 'epoch': 43, 'train': 'train'}
# {'loss': '0.381', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.419', 'epoch': 44, 'train': 'train'}
# {'loss': '0.397', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 45, 'train': 'train'}
# {'loss': '0.377', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 46, 'train': 'train'}
# {'loss': '0.386', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 47, 'train': 'train'}
# {'loss': '0.397', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.391', 'epoch': 48, 'train': 'train'}
# {'loss': '0.404', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 49, 'train': 'train'}
# {'loss': '0.380', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 50, 'train': 'train'}
# {'loss': '0.357', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 51, 'train': 'train'}
# {'loss': '0.373', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.384', 'epoch': 52, 'train': 'train'}
# {'loss': '0.382', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 53, 'train': 'train'}
# {'loss': '0.341', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 54, 'train': 'train'}
# {'loss': '0.378', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 55, 'train': 'train'}
# {'loss': '0.391', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 56, 'train': 'train'}
# {'loss': '0.380', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 57, 'train': 'train'}
# {'loss': '0.421', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 58, 'train': 'train'}
# {'loss': '0.418', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 59, 'train': 'train'}
# {'loss': '0.432', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 60, 'train': 'train'}
# {'loss': '0.356', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 61, 'train': 'train'}
# {'loss': '0.372', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.389', 'epoch': 62, 'train': 'train'}
# {'loss': '0.398', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 63, 'train': 'train'}
# {'loss': '0.358', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 64, 'train': 'train'}
# {'loss': '0.353', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 65, 'train': 'train'}
# {'loss': '0.377', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 66, 'train': 'train'}
# {'loss': '0.408', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 67, 'train': 'train'}
# {'loss': '0.385', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 68, 'train': 'train'}
# {'loss': '0.381', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 69, 'train': 'train'}
# {'loss': '0.432', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 70, 'train': 'train'}
# {'loss': '0.414', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 71, 'train': 'train'}
# {'loss': '0.358', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 72, 'train': 'train'}
# {'loss': '0.346', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 73, 'train': 'train'}
# {'loss': '0.439', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 74, 'train': 'train'}
# {'loss': '0.381', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 75, 'train': 'train'}
# {'loss': '0.492', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.387', 'epoch': 76, 'train': 'train'}
# {'loss': '0.409', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.381', 'epoch': 77, 'train': 'train'}
# {'loss': '0.395', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 78, 'train': 'train'}
# {'loss': '0.360', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 79, 'train': 'train'}
# {'loss': '0.346', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 80, 'train': 'train'}
# {'loss': '0.366', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 81, 'train': 'train'}
# {'loss': '0.359', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 82, 'train': 'train'}
# {'loss': '0.400', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 83, 'train': 'train'}
# {'loss': '0.342', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 84, 'train': 'train'}
# {'loss': '0.384', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 85, 'train': 'train'}
# {'loss': '0.382', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 86, 'train': 'train'}
# {'loss': '0.444', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 87, 'train': 'train'}
# {'loss': '0.402', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 88, 'train': 'train'}
# {'loss': '0.372', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 89, 'train': 'train'}
# {'loss': '0.389', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 90, 'train': 'train'}
# {'loss': '0.419', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 91, 'train': 'train'}
# {'loss': '0.407', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 92, 'train': 'train'}
# {'loss': '0.338', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 93, 'train': 'train'}
# {'loss': '0.313', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 94, 'train': 'train'}
# {'loss': '0.392', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.379', 'epoch': 95, 'train': 'train'}
# {'loss': '0.330', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 96, 'train': 'train'}
# {'loss': '0.363', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 97, 'train': 'train'}
# {'loss': '0.387', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 98, 'train': 'train'}
# {'loss': '0.373', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 99, 'train': 'train'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 learn.fit(epochs)
#
# File ~/course22p2/miniai/learner.py:178, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     176     if lr is None: lr = self.lr
#     177     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 178     self._fit(train, valid)
#     179 finally:
#     180     for cb in cbs: self.cbs.remove(cb)
#
# File ~/course22p2/miniai/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/course22p2/miniai/learner.py:167, in Learner._fit(self, train, valid)
#     165 for self.epoch in self.epochs:
#     166     if train: self.one_epoch(True)
# --> 167     if valid: torch.no_grad()(self.one_epoch)(False)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/course22p2/miniai/learner.py:161, in Learner.one_epoch(self, training)
#     159 self.model.train(training)
#     160 self.dl = self.dls.train if training else self.dls.valid
# --> 161 self._one_epoch()
#
# File ~/course22p2/miniai/learner.py:130, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     128     o.callback(f'before_{self.nm}')
#     129     f(o, *args, **kwargs)
# --> 130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#     132 finally: o.callback(f'cleanup_{self.nm}')
#
# File ~/course22p2/miniai/learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File ~/course22p2/miniai/learner.py:69, in MetricsCB.after_epoch(self, learn)
#      67 log['epoch'] = learn.epoch
#      68 log['train'] = 'train' if learn.model.training else 'eval'
# ---> 69 self._log(log)
#
# Cell In[53], line 18, in WandBCB._log(self, d)
#      16 else:
#      17     wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
# ---> 18     wandb.log({'samples':self.sample_figure(learn)})
#      19 print(d)
#
# Cell In[53], line 24, in WandBCB.sample_figure(self, learn)
#      22 def sample_figure(self, learn):
#      23     with torch.no_grad():
# ---> 24         preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
#      25     s = to_cpu(vae.decode(preds[-1].cuda()*5))
#      26     s = s['sample'].clamp(0,1)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[52], line 14, in sample(f, model, sz, steps, eta, clamp, progress)
#      12     noise = model((x_t, t))
#      13     abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
# ---> 14     x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
#      15     preds.append(x_0_hat.float().cpu())
#      16 return preds
#
# Cell In[51], line 7, in ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp)
#       5 if clamp: x_0_hat = x_0_hat.clamp(-1,1)
#       6 if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
# ----> 7 x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
#       8 x_t += sig * torch.randn(x_t.shape).to(x_t)
#       9 return x_0_hat,x_t
#
# KeyboardInterrupt:

# %%
lr = 0.1e-4
epochs = 1700
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
#wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# Finishing last run (ID:hwhit4sd) before initializing another...
# VBox(children=(Label(value='56.221 MB of 56.221 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>██▅▄▃▃▄▃▃▃▄▃▃▃▂▂▄▂▂▂▃▂▂▂▂▂▁▂▃▁▂▃▁▂▁▂▂▃▂▁</td></tr><tr><td>train_loss</td><td>█▇▅▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▅▄▃▃▃▂▃▂▃▂▂▁▂▂▂▂▂▂▁▁▂▂▁▁▂▂▁▂▂▂▁▁▂▂▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.39517</td></tr><tr><td>train_loss</td><td>0.36</td></tr><tr><td>val_loss</td><td>0.395</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">effortless-smoke-10</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/hwhit4sd' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/hwhit4sd</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a><br/>Synced 6 W&B file(s), 99 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_155052-hwhit4sd/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# Successfully finished last run (ID:hwhit4sd). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113903671503066, max=1.0…
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_155943-8dxknfi2</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/8dxknfi2' target="_blank">laced-waterfall-11</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/8dxknfi2' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/8dxknfi2</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'loss': '0.375', 'epoch': 0, 'train': 'train'}
# {'loss': '0.386', 'epoch': 0, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 1, 'train': 'train'}
# {'loss': '0.405', 'epoch': 1, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 2, 'train': 'train'}
# {'loss': '0.428', 'epoch': 2, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 3, 'train': 'train'}
# {'loss': '0.376', 'epoch': 3, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 4, 'train': 'train'}
# {'loss': '0.401', 'epoch': 4, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 5, 'train': 'train'}
# {'loss': '0.395', 'epoch': 5, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 6, 'train': 'train'}
# {'loss': '0.375', 'epoch': 6, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 7, 'train': 'train'}
# {'loss': '0.389', 'epoch': 7, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 8, 'train': 'train'}
# {'loss': '0.328', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 9, 'train': 'train'}
# {'loss': '0.416', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 10, 'train': 'train'}
# {'loss': '0.337', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 11, 'train': 'train'}
# {'loss': '0.394', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 12, 'train': 'train'}
# {'loss': '0.400', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 13, 'train': 'train'}
# {'loss': '0.361', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 14, 'train': 'train'}
# {'loss': '0.324', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 15, 'train': 'train'}
# {'loss': '0.376', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 16, 'train': 'train'}
# {'loss': '0.383', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 17, 'train': 'train'}
# {'loss': '0.357', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 18, 'train': 'train'}
# {'loss': '0.341', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.353', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 20, 'train': 'train'}
# {'loss': '0.381', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 21, 'train': 'train'}
# {'loss': '0.334', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 22, 'train': 'train'}
# {'loss': '0.371', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 23, 'train': 'train'}
# {'loss': '0.356', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 24, 'train': 'train'}
# {'loss': '0.393', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 25, 'train': 'train'}
# {'loss': '0.373', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 26, 'train': 'train'}
# {'loss': '0.327', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 27, 'train': 'train'}
# {'loss': '0.383', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 28, 'train': 'train'}
# {'loss': '0.411', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 29, 'train': 'train'}
# {'loss': '0.393', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 30, 'train': 'train'}
# {'loss': '0.410', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 31, 'train': 'train'}
# {'loss': '0.325', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 32, 'train': 'train'}
# {'loss': '0.305', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 33, 'train': 'train'}
# {'loss': '0.382', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 34, 'train': 'train'}
# {'loss': '0.334', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 35, 'train': 'train'}
# {'loss': '0.451', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 36, 'train': 'train'}
# {'loss': '0.403', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 37, 'train': 'train'}
# {'loss': '0.341', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 38, 'train': 'train'}
# {'loss': '0.376', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 39, 'train': 'train'}
# {'loss': '0.376', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 40, 'train': 'train'}
# {'loss': '0.353', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 41, 'train': 'train'}
# {'loss': '0.387', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 42, 'train': 'train'}
# {'loss': '0.346', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 43, 'train': 'train'}
# {'loss': '0.355', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 44, 'train': 'train'}
# {'loss': '0.345', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 45, 'train': 'train'}
# {'loss': '0.390', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 46, 'train': 'train'}
# {'loss': '0.352', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 47, 'train': 'train'}
# {'loss': '0.361', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 48, 'train': 'train'}
# {'loss': '0.366', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 49, 'train': 'train'}
# {'loss': '0.401', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 50, 'train': 'train'}
# {'loss': '0.312', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 51, 'train': 'train'}
# {'loss': '0.396', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 52, 'train': 'train'}
# {'loss': '0.355', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 53, 'train': 'train'}
# {'loss': '0.341', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 54, 'train': 'train'}
# {'loss': '0.328', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 55, 'train': 'train'}
# {'loss': '0.356', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 56, 'train': 'train'}
# {'loss': '0.349', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 57, 'train': 'train'}
# {'loss': '0.395', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 58, 'train': 'train'}
# {'loss': '0.384', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 59, 'train': 'train'}
# {'loss': '0.414', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 60, 'train': 'train'}
# {'loss': '0.318', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 61, 'train': 'train'}
# {'loss': '0.360', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 62, 'train': 'train'}
# {'loss': '0.396', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 63, 'train': 'train'}
# {'loss': '0.368', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 64, 'train': 'train'}
# {'loss': '0.345', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 65, 'train': 'train'}
# {'loss': '0.347', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 66, 'train': 'train'}
# {'loss': '0.367', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 67, 'train': 'train'}
# {'loss': '0.371', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 68, 'train': 'train'}
# {'loss': '0.387', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 69, 'train': 'train'}
# {'loss': '0.392', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 70, 'train': 'train'}
# {'loss': '0.369', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 71, 'train': 'train'}
# {'loss': '0.404', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 72, 'train': 'train'}
# {'loss': '0.385', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 73, 'train': 'train'}
# {'loss': '0.385', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 74, 'train': 'train'}
# {'loss': '0.365', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 75, 'train': 'train'}
# {'loss': '0.363', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 76, 'train': 'train'}
# {'loss': '0.377', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 77, 'train': 'train'}
# {'loss': '0.392', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 78, 'train': 'train'}
# {'loss': '0.366', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 79, 'train': 'train'}
# {'loss': '0.343', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 80, 'train': 'train'}
# {'loss': '0.405', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 81, 'train': 'train'}
# {'loss': '0.377', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 82, 'train': 'train'}
# {'loss': '0.396', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 83, 'train': 'train'}
# {'loss': '0.346', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 84, 'train': 'train'}
# {'loss': '0.387', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 85, 'train': 'train'}
# {'loss': '0.428', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 86, 'train': 'train'}
# {'loss': '0.347', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 87, 'train': 'train'}
# {'loss': '0.458', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 88, 'train': 'train'}
# {'loss': '0.403', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 89, 'train': 'train'}
# {'loss': '0.392', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 90, 'train': 'train'}
# {'loss': '0.341', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 91, 'train': 'train'}
# {'loss': '0.391', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 92, 'train': 'train'}
# {'loss': '0.380', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 93, 'train': 'train'}
# {'loss': '0.384', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 94, 'train': 'train'}
# {'loss': '0.346', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 95, 'train': 'train'}
# {'loss': '0.393', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 96, 'train': 'train'}
# {'loss': '0.321', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 97, 'train': 'train'}
# {'loss': '0.418', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 98, 'train': 'train'}
# {'loss': '0.455', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 99, 'train': 'train'}
# {'loss': '0.332', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 100, 'train': 'train'}
# {'loss': '0.354', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 101, 'train': 'train'}
# {'loss': '0.396', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 102, 'train': 'train'}
# {'loss': '0.314', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 103, 'train': 'train'}
# {'loss': '0.331', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 104, 'train': 'train'}
# {'loss': '0.315', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 105, 'train': 'train'}
# {'loss': '0.391', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 106, 'train': 'train'}
# {'loss': '0.364', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 107, 'train': 'train'}
# {'loss': '0.305', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 108, 'train': 'train'}
# {'loss': '0.404', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 109, 'train': 'train'}
# {'loss': '0.347', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 110, 'train': 'train'}
# {'loss': '0.361', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 111, 'train': 'train'}
# {'loss': '0.310', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 112, 'train': 'train'}
# {'loss': '0.404', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 113, 'train': 'train'}
# {'loss': '0.357', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 114, 'train': 'train'}
# {'loss': '0.350', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 115, 'train': 'train'}
# {'loss': '0.345', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 116, 'train': 'train'}
# {'loss': '0.349', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 117, 'train': 'train'}
# {'loss': '0.377', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 118, 'train': 'train'}
# {'loss': '0.382', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 119, 'train': 'train'}
# {'loss': '0.365', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 120, 'train': 'train'}
# {'loss': '0.356', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 121, 'train': 'train'}
# {'loss': '0.346', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 122, 'train': 'train'}
# {'loss': '0.393', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 123, 'train': 'train'}
# {'loss': '0.425', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 124, 'train': 'train'}
# {'loss': '0.346', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 125, 'train': 'train'}
# {'loss': '0.417', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 126, 'train': 'train'}
# {'loss': '0.346', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 127, 'train': 'train'}
# {'loss': '0.353', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 128, 'train': 'train'}
# {'loss': '0.398', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 129, 'train': 'train'}
# {'loss': '0.359', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 130, 'train': 'train'}
# {'loss': '0.388', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 131, 'train': 'train'}
# {'loss': '0.371', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 132, 'train': 'train'}
# {'loss': '0.322', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 133, 'train': 'train'}
# {'loss': '0.408', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 134, 'train': 'train'}
# {'loss': '0.319', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 135, 'train': 'train'}
# {'loss': '0.392', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 136, 'train': 'train'}
# {'loss': '0.378', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 137, 'train': 'train'}
# {'loss': '0.379', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 138, 'train': 'train'}
# {'loss': '0.386', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 139, 'train': 'train'}
# {'loss': '0.349', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 140, 'train': 'train'}
# {'loss': '0.344', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 141, 'train': 'train'}
# {'loss': '0.332', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 142, 'train': 'train'}
# {'loss': '0.348', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 143, 'train': 'train'}
# {'loss': '0.369', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 144, 'train': 'train'}
# {'loss': '0.393', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 145, 'train': 'train'}
# {'loss': '0.433', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 146, 'train': 'train'}
# {'loss': '0.333', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 147, 'train': 'train'}
# {'loss': '0.364', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 148, 'train': 'train'}
# {'loss': '0.369', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 149, 'train': 'train'}
# {'loss': '0.372', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 150, 'train': 'train'}
# {'loss': '0.325', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 151, 'train': 'train'}
# {'loss': '0.365', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 152, 'train': 'train'}
# {'loss': '0.371', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 153, 'train': 'train'}
# {'loss': '0.352', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 154, 'train': 'train'}
# {'loss': '0.356', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 155, 'train': 'train'}
# {'loss': '0.352', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 156, 'train': 'train'}
# {'loss': '0.378', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 157, 'train': 'train'}
# {'loss': '0.340', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 158, 'train': 'train'}
# {'loss': '0.417', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 159, 'train': 'train'}
# {'loss': '0.393', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 160, 'train': 'train'}
# {'loss': '0.333', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 161, 'train': 'train'}
# {'loss': '0.448', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 162, 'train': 'train'}
# {'loss': '0.393', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 163, 'train': 'train'}
# {'loss': '0.401', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 164, 'train': 'train'}
# {'loss': '0.369', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 165, 'train': 'train'}
# {'loss': '0.362', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 166, 'train': 'train'}
# {'loss': '0.419', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 167, 'train': 'train'}
# {'loss': '0.369', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 168, 'train': 'train'}
# {'loss': '0.359', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 169, 'train': 'train'}
# {'loss': '0.312', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 170, 'train': 'train'}
# {'loss': '0.315', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 171, 'train': 'train'}
# {'loss': '0.386', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 172, 'train': 'train'}
# {'loss': '0.411', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 173, 'train': 'train'}
# {'loss': '0.353', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 174, 'train': 'train'}
# {'loss': '0.340', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 175, 'train': 'train'}
# {'loss': '0.315', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 176, 'train': 'train'}
# {'loss': '0.400', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 177, 'train': 'train'}
# {'loss': '0.376', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 178, 'train': 'train'}
# {'loss': '0.389', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 179, 'train': 'train'}
# {'loss': '0.414', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 180, 'train': 'train'}
# {'loss': '0.330', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 181, 'train': 'train'}
# {'loss': '0.349', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 182, 'train': 'train'}
# {'loss': '0.364', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 183, 'train': 'train'}
# {'loss': '0.370', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 184, 'train': 'train'}
# {'loss': '0.399', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 185, 'train': 'train'}
# {'loss': '0.399', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 186, 'train': 'train'}
# {'loss': '0.351', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 187, 'train': 'train'}
# {'loss': '0.422', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 188, 'train': 'train'}
# {'loss': '0.323', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 189, 'train': 'train'}
# {'loss': '0.378', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 190, 'train': 'train'}
# {'loss': '0.323', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.371', 'epoch': 191, 'train': 'train'}
# {'loss': '0.302', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 192, 'train': 'train'}
# {'loss': '0.365', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 193, 'train': 'train'}
# {'loss': '0.324', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 194, 'train': 'train'}
# {'loss': '0.346', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 195, 'train': 'train'}
# {'loss': '0.357', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 196, 'train': 'train'}
# {'loss': '0.372', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 197, 'train': 'train'}
# {'loss': '0.300', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 198, 'train': 'train'}
# {'loss': '0.367', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 199, 'train': 'train'}
# {'loss': '0.376', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 200, 'train': 'train'}
# {'loss': '0.348', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 201, 'train': 'train'}
# {'loss': '0.367', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 202, 'train': 'train'}
# {'loss': '0.424', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 203, 'train': 'train'}
# {'loss': '0.362', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 204, 'train': 'train'}
# {'loss': '0.345', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 205, 'train': 'train'}
# {'loss': '0.369', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 206, 'train': 'train'}
# {'loss': '0.401', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 207, 'train': 'train'}
# {'loss': '0.394', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 208, 'train': 'train'}
# {'loss': '0.364', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 209, 'train': 'train'}
# {'loss': '0.387', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 210, 'train': 'train'}
# {'loss': '0.363', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 211, 'train': 'train'}
# {'loss': '0.366', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 212, 'train': 'train'}
# {'loss': '0.376', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 213, 'train': 'train'}
# {'loss': '0.405', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 214, 'train': 'train'}
# {'loss': '0.312', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 215, 'train': 'train'}
# {'loss': '0.363', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 216, 'train': 'train'}
# {'loss': '0.416', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 217, 'train': 'train'}
# {'loss': '0.357', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 218, 'train': 'train'}
# {'loss': '0.374', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.364', 'epoch': 219, 'train': 'train'}
# {'loss': '0.363', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 220, 'train': 'train'}
# {'loss': '0.347', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 221, 'train': 'train'}
# {'loss': '0.395', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 222, 'train': 'train'}
# {'loss': '0.319', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 223, 'train': 'train'}
# {'loss': '0.387', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 224, 'train': 'train'}
# {'loss': '0.423', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 225, 'train': 'train'}
# {'loss': '0.346', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 226, 'train': 'train'}
# {'loss': '0.417', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 227, 'train': 'train'}
# {'loss': '0.337', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 228, 'train': 'train'}
# {'loss': '0.377', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 229, 'train': 'train'}
# {'loss': '0.381', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 230, 'train': 'train'}
# {'loss': '0.382', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 231, 'train': 'train'}
# {'loss': '0.406', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 232, 'train': 'train'}
# {'loss': '0.408', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 233, 'train': 'train'}
# {'loss': '0.417', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 234, 'train': 'train'}
# {'loss': '0.362', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 235, 'train': 'train'}
# {'loss': '0.400', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 236, 'train': 'train'}
# {'loss': '0.402', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 237, 'train': 'train'}
# {'loss': '0.368', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 238, 'train': 'train'}
# {'loss': '0.378', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 239, 'train': 'train'}
# {'loss': '0.393', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 240, 'train': 'train'}
# {'loss': '0.405', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 241, 'train': 'train'}
# {'loss': '0.385', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 242, 'train': 'train'}
# {'loss': '0.325', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 243, 'train': 'train'}
# {'loss': '0.382', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 244, 'train': 'train'}
# {'loss': '0.397', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 245, 'train': 'train'}
# {'loss': '0.299', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 246, 'train': 'train'}
# {'loss': '0.300', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 247, 'train': 'train'}
# {'loss': '0.344', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 248, 'train': 'train'}
# {'loss': '0.407', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 249, 'train': 'train'}
# {'loss': '0.342', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 250, 'train': 'train'}
# {'loss': '0.374', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 251, 'train': 'train'}
# {'loss': '0.374', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 252, 'train': 'train'}
# {'loss': '0.370', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 253, 'train': 'train'}
# {'loss': '0.383', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 254, 'train': 'train'}
# {'loss': '0.375', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 255, 'train': 'train'}
# {'loss': '0.397', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 256, 'train': 'train'}
# {'loss': '0.381', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 257, 'train': 'train'}
# {'loss': '0.354', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 258, 'train': 'train'}
# {'loss': '0.392', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 259, 'train': 'train'}
# {'loss': '0.333', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 260, 'train': 'train'}
# {'loss': '0.351', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 261, 'train': 'train'}
# {'loss': '0.396', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 262, 'train': 'train'}
# {'loss': '0.344', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 263, 'train': 'train'}
# {'loss': '0.368', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 264, 'train': 'train'}
# {'loss': '0.387', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 265, 'train': 'train'}
# {'loss': '0.362', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 266, 'train': 'train'}
# {'loss': '0.452', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 267, 'train': 'train'}
# {'loss': '0.343', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 268, 'train': 'train'}
# {'loss': '0.418', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 269, 'train': 'train'}
# {'loss': '0.328', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 270, 'train': 'train'}
# {'loss': '0.386', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 271, 'train': 'train'}
# {'loss': '0.462', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 272, 'train': 'train'}
# {'loss': '0.394', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 273, 'train': 'train'}
# {'loss': '0.359', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 274, 'train': 'train'}
# {'loss': '0.363', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 275, 'train': 'train'}
# {'loss': '0.338', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 276, 'train': 'train'}
# {'loss': '0.403', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 277, 'train': 'train'}
# {'loss': '0.349', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 278, 'train': 'train'}
# {'loss': '0.432', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 279, 'train': 'train'}
# {'loss': '0.419', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 280, 'train': 'train'}
# {'loss': '0.293', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 281, 'train': 'train'}
# {'loss': '0.366', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 282, 'train': 'train'}
# {'loss': '0.381', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 283, 'train': 'train'}
# {'loss': '0.320', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 284, 'train': 'train'}
# {'loss': '0.376', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.315', 'epoch': 285, 'train': 'train'}
# {'loss': '0.363', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 286, 'train': 'train'}
# {'loss': '0.353', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 287, 'train': 'train'}
# {'loss': '0.376', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 288, 'train': 'train'}
# {'loss': '0.371', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 289, 'train': 'train'}
# {'loss': '0.326', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 290, 'train': 'train'}
# {'loss': '0.380', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 291, 'train': 'train'}
# {'loss': '0.371', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 292, 'train': 'train'}
# {'loss': '0.439', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 293, 'train': 'train'}
# {'loss': '0.334', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 294, 'train': 'train'}
# {'loss': '0.358', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.321', 'epoch': 295, 'train': 'train'}
# {'loss': '0.464', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 296, 'train': 'train'}
# {'loss': '0.361', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 297, 'train': 'train'}
# {'loss': '0.428', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 298, 'train': 'train'}
# {'loss': '0.350', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 299, 'train': 'train'}
# {'loss': '0.439', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 300, 'train': 'train'}
# {'loss': '0.388', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 301, 'train': 'train'}
# {'loss': '0.337', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.322', 'epoch': 302, 'train': 'train'}
# {'loss': '0.332', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 303, 'train': 'train'}
# {'loss': '0.310', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 304, 'train': 'train'}
# {'loss': '0.378', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 305, 'train': 'train'}
# {'loss': '0.364', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 306, 'train': 'train'}
# {'loss': '0.365', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 307, 'train': 'train'}
# {'loss': '0.411', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 308, 'train': 'train'}
# {'loss': '0.361', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 309, 'train': 'train'}
# {'loss': '0.336', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 310, 'train': 'train'}
# {'loss': '0.402', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 311, 'train': 'train'}
# {'loss': '0.301', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 312, 'train': 'train'}
# {'loss': '0.397', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 313, 'train': 'train'}
# {'loss': '0.359', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.322', 'epoch': 314, 'train': 'train'}
# {'loss': '0.399', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 315, 'train': 'train'}
# {'loss': '0.372', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 316, 'train': 'train'}
# {'loss': '0.386', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 317, 'train': 'train'}
# {'loss': '0.417', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 318, 'train': 'train'}
# {'loss': '0.340', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 319, 'train': 'train'}
# {'loss': '0.348', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 320, 'train': 'train'}
# {'loss': '0.367', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 321, 'train': 'train'}
# {'loss': '0.333', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 322, 'train': 'train'}
# {'loss': '0.328', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 323, 'train': 'train'}
# {'loss': '0.373', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 324, 'train': 'train'}
# {'loss': '0.344', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 325, 'train': 'train'}
# {'loss': '0.311', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 326, 'train': 'train'}
# {'loss': '0.373', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 327, 'train': 'train'}
# {'loss': '0.383', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 328, 'train': 'train'}
# {'loss': '0.426', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 329, 'train': 'train'}
# {'loss': '0.430', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 330, 'train': 'train'}
# {'loss': '0.345', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.322', 'epoch': 331, 'train': 'train'}
# {'loss': '0.415', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 332, 'train': 'train'}
# {'loss': '0.364', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 333, 'train': 'train'}
# {'loss': '0.275', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 334, 'train': 'train'}
# {'loss': '0.475', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 335, 'train': 'train'}
# {'loss': '0.385', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 336, 'train': 'train'}
# {'loss': '0.375', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 337, 'train': 'train'}
# {'loss': '0.350', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 338, 'train': 'train'}
# {'loss': '0.332', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.314', 'epoch': 339, 'train': 'train'}
# {'loss': '0.418', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 340, 'train': 'train'}
# {'loss': '0.402', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.319', 'epoch': 341, 'train': 'train'}
# {'loss': '0.327', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 342, 'train': 'train'}
# {'loss': '0.358', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 343, 'train': 'train'}
# {'loss': '0.381', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 344, 'train': 'train'}
# {'loss': '0.387', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 345, 'train': 'train'}
# {'loss': '0.451', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 346, 'train': 'train'}
# {'loss': '0.417', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 347, 'train': 'train'}
# {'loss': '0.396', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 348, 'train': 'train'}
# {'loss': '0.420', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 349, 'train': 'train'}
# {'loss': '0.423', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 350, 'train': 'train'}
# {'loss': '0.416', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 351, 'train': 'train'}
# {'loss': '0.401', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 352, 'train': 'train'}
# {'loss': '0.396', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 353, 'train': 'train'}
# {'loss': '0.437', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 354, 'train': 'train'}
# {'loss': '0.415', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 355, 'train': 'train'}
# {'loss': '0.413', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 356, 'train': 'train'}
# {'loss': '0.399', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.314', 'epoch': 357, 'train': 'train'}
# {'loss': '0.331', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.314', 'epoch': 358, 'train': 'train'}
# {'loss': '0.349', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 359, 'train': 'train'}
# {'loss': '0.374', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 360, 'train': 'train'}
# {'loss': '0.363', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 361, 'train': 'train'}
# {'loss': '0.376', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.322', 'epoch': 362, 'train': 'train'}
# {'loss': '0.414', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 363, 'train': 'train'}
# {'loss': '0.365', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.315', 'epoch': 364, 'train': 'train'}
# {'loss': '0.383', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 365, 'train': 'train'}
# {'loss': '0.417', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 366, 'train': 'train'}
# {'loss': '0.404', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 367, 'train': 'train'}
# {'loss': '0.388', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.319', 'epoch': 368, 'train': 'train'}
# {'loss': '0.371', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 369, 'train': 'train'}
# {'loss': '0.401', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.314', 'epoch': 370, 'train': 'train'}
# {'loss': '0.417', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 371, 'train': 'train'}
# {'loss': '0.427', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 372, 'train': 'train'}
# {'loss': '0.439', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.322', 'epoch': 373, 'train': 'train'}
# {'loss': '0.410', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 374, 'train': 'train'}
# {'loss': '0.385', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 375, 'train': 'train'}
# {'loss': '0.392', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 376, 'train': 'train'}
# {'loss': '0.409', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 377, 'train': 'train'}
# {'loss': '0.505', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 378, 'train': 'train'}
# {'loss': '0.398', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.310', 'epoch': 379, 'train': 'train'}
# {'loss': '0.378', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 380, 'train': 'train'}
# {'loss': '0.337', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 381, 'train': 'train'}
# {'loss': '0.396', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 382, 'train': 'train'}
# {'loss': '0.345', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 383, 'train': 'train'}
# {'loss': '0.377', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.302', 'epoch': 384, 'train': 'train'}
# {'loss': '0.431', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 385, 'train': 'train'}
# {'loss': '0.441', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 386, 'train': 'train'}
# {'loss': '0.413', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 387, 'train': 'train'}
# {'loss': '0.378', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 388, 'train': 'train'}
# {'loss': '0.451', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.303', 'epoch': 389, 'train': 'train'}
# {'loss': '0.365', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.310', 'epoch': 390, 'train': 'train'}
# {'loss': '0.386', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.311', 'epoch': 391, 'train': 'train'}
# {'loss': '0.382', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.321', 'epoch': 392, 'train': 'train'}
# {'loss': '0.448', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 393, 'train': 'train'}
# {'loss': '0.420', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.307', 'epoch': 394, 'train': 'train'}
# {'loss': '0.441', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 395, 'train': 'train'}
# {'loss': '0.367', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 396, 'train': 'train'}
# {'loss': '0.495', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.318', 'epoch': 397, 'train': 'train'}
# {'loss': '0.432', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.311', 'epoch': 398, 'train': 'train'}
# {'loss': '0.416', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.309', 'epoch': 399, 'train': 'train'}
# {'loss': '0.384', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.298', 'epoch': 400, 'train': 'train'}
# {'loss': '0.409', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.305', 'epoch': 401, 'train': 'train'}
# {'loss': '0.389', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 402, 'train': 'train'}
# {'loss': '0.412', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.289', 'epoch': 403, 'train': 'train'}
# {'loss': '0.392', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 404, 'train': 'train'}
# {'loss': '0.443', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.283', 'epoch': 405, 'train': 'train'}
# {'loss': '0.423', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 406, 'train': 'train'}
# {'loss': '0.384', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 407, 'train': 'train'}
# {'loss': '0.425', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.289', 'epoch': 408, 'train': 'train'}
# {'loss': '0.434', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 409, 'train': 'train'}
# {'loss': '0.417', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.316', 'epoch': 410, 'train': 'train'}
# {'loss': '0.435', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 411, 'train': 'train'}
# {'loss': '0.452', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.297', 'epoch': 412, 'train': 'train'}
# {'loss': '0.466', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 413, 'train': 'train'}
# {'loss': '0.404', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.310', 'epoch': 414, 'train': 'train'}
# {'loss': '0.432', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 415, 'train': 'train'}
# {'loss': '0.381', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.300', 'epoch': 416, 'train': 'train'}
# {'loss': '0.421', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 417, 'train': 'train'}
# {'loss': '0.424', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.297', 'epoch': 418, 'train': 'train'}
# {'loss': '0.447', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.289', 'epoch': 419, 'train': 'train'}
# {'loss': '0.403', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.304', 'epoch': 420, 'train': 'train'}
# {'loss': '0.433', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.302', 'epoch': 421, 'train': 'train'}
# {'loss': '0.452', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.299', 'epoch': 422, 'train': 'train'}
# {'loss': '0.516', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 423, 'train': 'train'}
# {'loss': '0.408', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.280', 'epoch': 424, 'train': 'train'}
# {'loss': '0.445', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.291', 'epoch': 425, 'train': 'train'}
# {'loss': '0.418', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.290', 'epoch': 426, 'train': 'train'}
# {'loss': '0.501', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.288', 'epoch': 427, 'train': 'train'}
# {'loss': '0.394', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.300', 'epoch': 428, 'train': 'train'}
# {'loss': '0.453', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.294', 'epoch': 429, 'train': 'train'}
# {'loss': '0.441', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.288', 'epoch': 430, 'train': 'train'}
# {'loss': '0.515', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.296', 'epoch': 431, 'train': 'train'}
# {'loss': '0.463', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.290', 'epoch': 432, 'train': 'train'}
# {'loss': '0.377', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.298', 'epoch': 433, 'train': 'train'}
# {'loss': '0.426', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.297', 'epoch': 434, 'train': 'train'}
# {'loss': '0.482', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.292', 'epoch': 435, 'train': 'train'}
# {'loss': '0.400', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.291', 'epoch': 436, 'train': 'train'}
# {'loss': '0.375', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.286', 'epoch': 437, 'train': 'train'}
# {'loss': '0.524', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.303', 'epoch': 438, 'train': 'train'}
# {'loss': '0.459', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.277', 'epoch': 439, 'train': 'train'}
# {'loss': '0.452', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.287', 'epoch': 440, 'train': 'train'}
# {'loss': '0.527', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.292', 'epoch': 441, 'train': 'train'}
# {'loss': '0.431', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.297', 'epoch': 442, 'train': 'train'}
# {'loss': '0.383', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.271', 'epoch': 443, 'train': 'train'}
# {'loss': '0.404', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.293', 'epoch': 444, 'train': 'train'}
# {'loss': '0.392', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.302', 'epoch': 445, 'train': 'train'}
# {'loss': '0.385', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.282', 'epoch': 446, 'train': 'train'}
# {'loss': '0.431', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.276', 'epoch': 447, 'train': 'train'}
# {'loss': '0.453', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.284', 'epoch': 448, 'train': 'train'}
# {'loss': '0.456', 'epoch': 448, 'train': 'eval'}
# ...
# {'loss': '0.064', 'epoch': 1559, 'train': 'train'}
# {'loss': '0.986', 'epoch': 1559, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1560, 'train': 'train'}
# {'loss': '1.121', 'epoch': 1560, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1561, 'train': 'train'}
# {'loss': '0.769', 'epoch': 1561, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1562, 'train': 'train'}
# {'loss': '0.821', 'epoch': 1562, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 1563, 'train': 'train'}
# {'loss': '0.728', 'epoch': 1563, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1564, 'train': 'train'}
# {'loss': '0.820', 'epoch': 1564, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1565, 'train': 'train'}
# {'loss': '0.970', 'epoch': 1565, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1566, 'train': 'train'}
# {'loss': '0.821', 'epoch': 1566, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1567, 'train': 'train'}
# {'loss': '0.897', 'epoch': 1567, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 1568, 'train': 'train'}
# {'loss': '0.880', 'epoch': 1568, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1569, 'train': 'train'}
# {'loss': '1.021', 'epoch': 1569, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1570, 'train': 'train'}
# {'loss': '0.944', 'epoch': 1570, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1571, 'train': 'train'}
# {'loss': '1.258', 'epoch': 1571, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 1572, 'train': 'train'}
# {'loss': '0.909', 'epoch': 1572, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 1573, 'train': 'train'}
# {'loss': '0.846', 'epoch': 1573, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1574, 'train': 'train'}
# {'loss': '0.756', 'epoch': 1574, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1575, 'train': 'train'}
# {'loss': '0.810', 'epoch': 1575, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1576, 'train': 'train'}
# {'loss': '0.847', 'epoch': 1576, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1577, 'train': 'train'}
# {'loss': '1.181', 'epoch': 1577, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1578, 'train': 'train'}
# {'loss': '0.937', 'epoch': 1578, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 1579, 'train': 'train'}
# {'loss': '1.281', 'epoch': 1579, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1580, 'train': 'train'}
# {'loss': '0.903', 'epoch': 1580, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 1581, 'train': 'train'}
# {'loss': '0.896', 'epoch': 1581, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1582, 'train': 'train'}
# {'loss': '0.696', 'epoch': 1582, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1583, 'train': 'train'}
# {'loss': '0.624', 'epoch': 1583, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1584, 'train': 'train'}
# {'loss': '0.834', 'epoch': 1584, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1585, 'train': 'train'}
# {'loss': '0.803', 'epoch': 1585, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1586, 'train': 'train'}
# {'loss': '0.828', 'epoch': 1586, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1587, 'train': 'train'}
# {'loss': '0.962', 'epoch': 1587, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1588, 'train': 'train'}
# {'loss': '0.558', 'epoch': 1588, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1589, 'train': 'train'}
# {'loss': '1.006', 'epoch': 1589, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1590, 'train': 'train'}
# {'loss': '1.051', 'epoch': 1590, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 1591, 'train': 'train'}
# {'loss': '0.926', 'epoch': 1591, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 1592, 'train': 'train'}
# {'loss': '0.807', 'epoch': 1592, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1593, 'train': 'train'}
# {'loss': '0.907', 'epoch': 1593, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1594, 'train': 'train'}
# {'loss': '0.904', 'epoch': 1594, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1595, 'train': 'train'}
# {'loss': '0.819', 'epoch': 1595, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1596, 'train': 'train'}
# {'loss': '0.792', 'epoch': 1596, 'train': 'eval'}
# {'loss': '0.072', 'epoch': 1597, 'train': 'train'}
# {'loss': '1.286', 'epoch': 1597, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1598, 'train': 'train'}
# {'loss': '0.986', 'epoch': 1598, 'train': 'eval'}
# {'loss': '0.075', 'epoch': 1599, 'train': 'train'}
# {'loss': '0.858', 'epoch': 1599, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 1600, 'train': 'train'}
# {'loss': '0.691', 'epoch': 1600, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1601, 'train': 'train'}
# {'loss': '1.031', 'epoch': 1601, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1602, 'train': 'train'}
# {'loss': '0.845', 'epoch': 1602, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1603, 'train': 'train'}
# {'loss': '0.970', 'epoch': 1603, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1604, 'train': 'train'}
# {'loss': '0.986', 'epoch': 1604, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1605, 'train': 'train'}
# {'loss': '1.017', 'epoch': 1605, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1606, 'train': 'train'}
# {'loss': '0.662', 'epoch': 1606, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1607, 'train': 'train'}
# {'loss': '1.151', 'epoch': 1607, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1608, 'train': 'train'}
# {'loss': '0.846', 'epoch': 1608, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1609, 'train': 'train'}
# {'loss': '0.983', 'epoch': 1609, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1610, 'train': 'train'}
# {'loss': '0.998', 'epoch': 1610, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1611, 'train': 'train'}
# {'loss': '0.812', 'epoch': 1611, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1612, 'train': 'train'}
# {'loss': '0.861', 'epoch': 1612, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1613, 'train': 'train'}
# {'loss': '1.030', 'epoch': 1613, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1614, 'train': 'train'}
# {'loss': '1.018', 'epoch': 1614, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1615, 'train': 'train'}
# {'loss': '1.044', 'epoch': 1615, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 1616, 'train': 'train'}
# {'loss': '1.146', 'epoch': 1616, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1617, 'train': 'train'}
# {'loss': '0.992', 'epoch': 1617, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1618, 'train': 'train'}
# {'loss': '0.911', 'epoch': 1618, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1619, 'train': 'train'}
# {'loss': '0.942', 'epoch': 1619, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1620, 'train': 'train'}
# {'loss': '0.841', 'epoch': 1620, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1621, 'train': 'train'}
# {'loss': '0.947', 'epoch': 1621, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1622, 'train': 'train'}
# {'loss': '1.014', 'epoch': 1622, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1623, 'train': 'train'}
# {'loss': '1.039', 'epoch': 1623, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1624, 'train': 'train'}
# {'loss': '0.821', 'epoch': 1624, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 1625, 'train': 'train'}
# {'loss': '1.041', 'epoch': 1625, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1626, 'train': 'train'}
# {'loss': '0.975', 'epoch': 1626, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1627, 'train': 'train'}
# {'loss': '0.843', 'epoch': 1627, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1628, 'train': 'train'}
# {'loss': '0.830', 'epoch': 1628, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1629, 'train': 'train'}
# {'loss': '0.816', 'epoch': 1629, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 1630, 'train': 'train'}
# {'loss': '0.864', 'epoch': 1630, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1631, 'train': 'train'}
# {'loss': '0.857', 'epoch': 1631, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1632, 'train': 'train'}
# {'loss': '1.011', 'epoch': 1632, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1633, 'train': 'train'}
# {'loss': '0.942', 'epoch': 1633, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1634, 'train': 'train'}
# {'loss': '0.976', 'epoch': 1634, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1635, 'train': 'train'}
# {'loss': '0.905', 'epoch': 1635, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1636, 'train': 'train'}
# {'loss': '0.986', 'epoch': 1636, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 1637, 'train': 'train'}
# {'loss': '1.032', 'epoch': 1637, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1638, 'train': 'train'}
# {'loss': '1.081', 'epoch': 1638, 'train': 'eval'}
# {'loss': '0.074', 'epoch': 1639, 'train': 'train'}
# {'loss': '0.908', 'epoch': 1639, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1640, 'train': 'train'}
# {'loss': '0.887', 'epoch': 1640, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1641, 'train': 'train'}
# {'loss': '1.141', 'epoch': 1641, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1642, 'train': 'train'}
# {'loss': '0.889', 'epoch': 1642, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1643, 'train': 'train'}
# {'loss': '0.901', 'epoch': 1643, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1644, 'train': 'train'}
# {'loss': '0.952', 'epoch': 1644, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1645, 'train': 'train'}
# {'loss': '0.812', 'epoch': 1645, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1646, 'train': 'train'}
# {'loss': '1.021', 'epoch': 1646, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1647, 'train': 'train'}
# {'loss': '0.951', 'epoch': 1647, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1648, 'train': 'train'}
# {'loss': '1.100', 'epoch': 1648, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1649, 'train': 'train'}
# {'loss': '0.852', 'epoch': 1649, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1650, 'train': 'train'}
# {'loss': '1.002', 'epoch': 1650, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1651, 'train': 'train'}
# {'loss': '1.112', 'epoch': 1651, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1652, 'train': 'train'}
# {'loss': '0.907', 'epoch': 1652, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1653, 'train': 'train'}
# {'loss': '0.894', 'epoch': 1653, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1654, 'train': 'train'}
# {'loss': '1.058', 'epoch': 1654, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1655, 'train': 'train'}
# {'loss': '0.882', 'epoch': 1655, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1656, 'train': 'train'}
# {'loss': '1.060', 'epoch': 1656, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1657, 'train': 'train'}
# {'loss': '0.827', 'epoch': 1657, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1658, 'train': 'train'}
# {'loss': '0.858', 'epoch': 1658, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 1659, 'train': 'train'}
# {'loss': '1.084', 'epoch': 1659, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1660, 'train': 'train'}
# {'loss': '0.821', 'epoch': 1660, 'train': 'eval'}
# {'loss': '0.060', 'epoch': 1661, 'train': 'train'}
# {'loss': '0.867', 'epoch': 1661, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1662, 'train': 'train'}
# {'loss': '0.796', 'epoch': 1662, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1663, 'train': 'train'}
# {'loss': '0.813', 'epoch': 1663, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1664, 'train': 'train'}
# {'loss': '1.255', 'epoch': 1664, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1665, 'train': 'train'}
# {'loss': '1.139', 'epoch': 1665, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1666, 'train': 'train'}
# {'loss': '0.979', 'epoch': 1666, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1667, 'train': 'train'}
# {'loss': '0.977', 'epoch': 1667, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1668, 'train': 'train'}
# {'loss': '0.955', 'epoch': 1668, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1669, 'train': 'train'}
# {'loss': '1.382', 'epoch': 1669, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1670, 'train': 'train'}
# {'loss': '0.946', 'epoch': 1670, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1671, 'train': 'train'}
# {'loss': '0.959', 'epoch': 1671, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1672, 'train': 'train'}
# {'loss': '1.023', 'epoch': 1672, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1673, 'train': 'train'}
# {'loss': '0.853', 'epoch': 1673, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1674, 'train': 'train'}
# {'loss': '0.748', 'epoch': 1674, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1675, 'train': 'train'}
# {'loss': '0.991', 'epoch': 1675, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1676, 'train': 'train'}
# {'loss': '0.891', 'epoch': 1676, 'train': 'eval'}
# {'loss': '0.062', 'epoch': 1677, 'train': 'train'}
# {'loss': '0.803', 'epoch': 1677, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1678, 'train': 'train'}
# {'loss': '0.894', 'epoch': 1678, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1679, 'train': 'train'}
# {'loss': '0.922', 'epoch': 1679, 'train': 'eval'}
# {'loss': '0.066', 'epoch': 1680, 'train': 'train'}
# {'loss': '0.746', 'epoch': 1680, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1681, 'train': 'train'}
# {'loss': '1.065', 'epoch': 1681, 'train': 'eval'}
# {'loss': '0.069', 'epoch': 1682, 'train': 'train'}
# {'loss': '0.882', 'epoch': 1682, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1683, 'train': 'train'}
# {'loss': '0.776', 'epoch': 1683, 'train': 'eval'}
# {'loss': '0.068', 'epoch': 1684, 'train': 'train'}
# {'loss': '1.052', 'epoch': 1684, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1685, 'train': 'train'}
# {'loss': '0.929', 'epoch': 1685, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1686, 'train': 'train'}
# {'loss': '0.937', 'epoch': 1686, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 1687, 'train': 'train'}
# {'loss': '0.948', 'epoch': 1687, 'train': 'eval'}
# {'loss': '0.063', 'epoch': 1688, 'train': 'train'}
# {'loss': '0.841', 'epoch': 1688, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1689, 'train': 'train'}
# {'loss': '0.948', 'epoch': 1689, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1690, 'train': 'train'}
# {'loss': '1.154', 'epoch': 1690, 'train': 'eval'}
# {'loss': '0.065', 'epoch': 1691, 'train': 'train'}
# {'loss': '0.899', 'epoch': 1691, 'train': 'eval'}
# {'loss': '0.067', 'epoch': 1692, 'train': 'train'}
# {'loss': '1.350', 'epoch': 1692, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1693, 'train': 'train'}
# {'loss': '1.115', 'epoch': 1693, 'train': 'eval'}
# {'loss': '0.064', 'epoch': 1694, 'train': 'train'}
# {'loss': '0.958', 'epoch': 1694, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1695, 'train': 'train'}
# {'loss': '0.868', 'epoch': 1695, 'train': 'eval'}
# {'loss': '0.070', 'epoch': 1696, 'train': 'train'}
# {'loss': '1.069', 'epoch': 1696, 'train': 'eval'}
# {'loss': '0.061', 'epoch': 1697, 'train': 'train'}
# {'loss': '0.873', 'epoch': 1697, 'train': 'eval'}
# {'loss': '0.071', 'epoch': 1698, 'train': 'train'}
# {'loss': '0.933', 'epoch': 1698, 'train': 'eval'}
# {'loss': '0.057', 'epoch': 1699, 'train': 'train'}
# {'loss': '0.822', 'epoch': 1699, 'train': 'eval'}
# VBox(children=(Label(value='938.501 MB of 938.501 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▃▃▃▃▃▃▃▃▃▃▄▃▅▂▂▂▂▂▂▂▂▁▂▁▇▁▁▁▁▁▁▁▁▁▁▁█▁▁▁</td></tr><tr><td>train_loss</td><td>▇██▇█▇▇▇▇▇▆▆▅▅▄▄▃▃▃▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▂▁▁▂▂▁▂▂▂▂▃▄▄▄▄▅▅▆▅▆▄▆▅▆█▄▆▄▄▄▄▆▇▆▆▅▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>0.82172</td></tr><tr><td>train_loss</td><td>0.057</td></tr><tr><td>val_loss</td><td>0.822</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">laced-waterfall-11</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/8dxknfi2' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/8dxknfi2</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a><br/>Synced 6 W&B file(s), 1700 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_155943-8dxknfi2/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %% [markdown]
# cmodel = torch.load('models/data_aug2.pkl')
# del(cmodel[8])
# del(cmodel[7])
#
# @inplace
# def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]
#
# bs = 2048
# tds = dsd.with_transform(transformi)
# dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)
#
# dt = dls.train
# xb,yb = next(iter(dt))
#
# ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (64,4,8,8)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(1.), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)

# %%
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape
# Out:
# (tensor(0.), tensor(1.), torch.Size([64, 3, 64, 64]))

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)
