# %%
#| default_exp diffusion

# %% [markdown]
# # [fail] Diffusion unet

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
#| export
from miniai.imports import *

from einops import rearrange
from fastprogress import progress_bar
from diffusers import AutoencoderKL

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

import logging
logging.disable(logging.WARNING)

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
class GPUCUDAMissing(BaseException):
    pass
    
try:
    if torch.cuda.is_available():
        print('# of GPUs available = ', torch.cuda.device_count())
    else:
        raise GPUCUDAMissing
except:
    print("ERROR: GPU is missing")
# Out:
# # of GPUs available =  1

# %%
xl,yl = 'image','label'
name = "zh-plus/tiny-imagenet"
bs = 1024
dsd = load_dataset(name)

# %%
dsd['train'] = dsd['train'].select(range(500))

# %%
dsd['valid'] = dsd['valid'].select(range(50))

# %%
class TinyHFDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hg_ds):
        self.ds = hg_ds
        # the 2 lines below must be done here because the execution of "ds['train']['image']" takes 18seconds
        # once it has executed, indexing it is very fast (5 milliseconds)
        self.image = hg_ds[xl]
        self.label = hg_ds[yl]
    def __len__(self): return self.ds.num_rows
    def __getitem__(self, i): return TF.to_tensor(self.image[i]), self.label[i]

# %%
tds = TinyHFDS(dsd['train'])

# %%
vds = TinyHFDS(dsd['valid'])

# %%
dl = DataLoader(tds, batch_size=bs, num_workers=0)
xb,yb = next(iter(dl))
show_images(xb[:16], imsize=2)

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").cuda().requires_grad_(False)

# %%
# %%time
lats = vae.encode(xb.cuda())
# Out:
# CPU times: user 555 ms, sys: 409 ms, total: 964 ms
# Wall time: 3.64 s

# %%
class LatsDS:
    # this is specific for Hugging Face's dsd which can be very slow to index
    def __init__(self, hfds):
        lbl = hfds[yl]
        self.label = lbl + lbl
        imgs = hfds[xl]
        list_tensor = [ TF.to_tensor(x) for i, x in enumerate(imgs+imgs)]
        batch = torch.stack(list_tensor)
        #batch.shape
        lats = vae.encode(batch.cuda())
        #lats.latent_dist.mean.shape
        self.lats = lats.latent_dist.mean
        
    def __len__(self): return len(self.lats)
    def __getitem__(self, i): return self.lats[i], self.label[i]

# %%
tlds = LatsDS(dsd['train'])
vlds = LatsDS(dsd['valid'])

# %% [markdown]
# ### Defs: TfmDS, tfmx, tfmy

# %%
class TfmDS:
    def __init__(self, ds, tfmx=fc.noop, tfmy=fc.noop): self.ds,self.tfmx,self.tfmy = ds,tfmx,tfmy
    def __len__(self): return len(self.ds)
    def __getitem__(self, i):
        x,y = self.ds[i]
        return self.tfmx(x),self.tfmy(y)

# %%
def tfmx(x):
    return x

# %%
def tfmy(y): 
    return y

# %% [markdown]
# ### Generate a batch and Decode batch

# %%
tfm_tds = TfmDS(tlds, tfmx, tfmy)
tfm_vds = TfmDS(vlds, tfmx, tfmy)

# %%
def collate_fn(b):
    b = default_collate(b)
    return b

# %%
#bs=512

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_fn))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb.shape, yb.shape, xb.min(), xb.max()
# Out:
# (torch.Size([1000, 4, 8, 8]),
#  torch.Size([1000]),
#  tensor(-20.1415, device='cuda:0'),
#  tensor(26.5186, device='cuda:0'))

# %%
show_images(((xb[:16,:3])/4).sigmoid() , imsize=2)

# %%
show_images(to_cpu(vae.decode(xb[:16]))['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# ### DDIM

# %%
#| export
def abar(t): return (t*math.pi/2).cos()**2
def inv_abar(x): return x.sqrt().acos()*2/math.pi

def noisify(x0):
    device = x0.device
    n = len(x0)
    t = torch.rand(n,).to(x0).clamp(0,0.999)
    ε = torch.randn(x0.shape, device=device)
    abar_t = abar(t).reshape(-1, 1, 1, 1).to(device)
    xt = abar_t.sqrt()*x0 + (1-abar_t).sqrt()*ε
    return (xt, t.to(device)), ε

def collate_ddpm(b): 
    b = default_collate(b)
    return noisify(b[0]*0.2) # jeremy scaled the lats by 0.2
def dl_ddpm(ds): return DataLoader(ds, batch_size=bs, collate_fn=collate_ddpm, num_workers=0)

# %%
dls = DataLoaders(*get_dls(tfm_tds, tfm_vds, bs=bs, num_workers=0, collate_fn=collate_ddpm))

# %%
dt = dls.train

# %%
xb, yb = next(iter(dt))

# %%
xb[0].shape, xb[1].shape, yb.shape
# Out:
# (torch.Size([1000, 4, 8, 8]), torch.Size([1000]), torch.Size([1000, 4, 8, 8]))

# %%
xb[0].min(), xb[0].max()
# Out:
# (tensor(-4.1888, device='cuda:0'), tensor(5.0209, device='cuda:0'))

# %%
show_images((xb[0][:9,0]*5).clamp(0,1))

# %% [markdown]
# ## Train

# %% [markdown]
# Based on Diffusers

# %%
#| export
def timestep_embedding(tsteps, emb_dim, max_period= 10000):
    exponent = -math.log(max_period) * torch.linspace(0, 1, emb_dim//2, device=tsteps.device)
    emb = tsteps[:,None].float() * exponent.exp()[None,:]
    emb = torch.cat([emb.sin(), emb.cos()], dim=-1)
    return F.pad(emb, (0,1,0,0)) if emb_dim%2==1 else emb

# %%
#| export
def pre_conv(ni, nf, ks=3, stride=1, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Conv2d(ni, nf, stride=stride, kernel_size=ks, padding=ks//2, bias=bias))
    return layers

# %%
#| export
def upsample(nf): return nn.Sequential(nn.Upsample(scale_factor=2.), nn.Conv2d(nf, nf, 3, padding=1))

# %%
#| export
def lin(ni, nf, act=nn.SiLU, norm=None, bias=True):
    layers = nn.Sequential()
    if norm: layers.append(norm(ni))
    if act : layers.append(act())
    layers.append(nn.Linear(ni, nf, bias=bias))
    return layers

# %%
# This version is giving poor results - use the cell below instead
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans):
        super().__init__()
        self.attn = nn.MultiheadAttention(ni, ni//attn_chans, batch_first=True)
        self.norm = nn.BatchNorm2d(ni)

    def forward(self, x):
        n,c,h,w = x.shape
        x = self.norm(x).view(n, c, -1).transpose(1, 2)
        x = self.attn(x, x, x, need_weights=False)[0]
        return x.transpose(1,2).reshape(n,c,h,w)

# %%
#| export
class SelfAttention(nn.Module):
    def __init__(self, ni, attn_chans, transpose=True):
        super().__init__()
        self.nheads = ni//attn_chans
        self.scale = math.sqrt(ni/self.nheads)
        self.norm = nn.LayerNorm(ni)
        self.qkv = nn.Linear(ni, ni*3)
        self.proj = nn.Linear(ni, ni)
        self.t = transpose
    
    def forward(self, x):
        n,c,s = x.shape
        if self.t: x = x.transpose(1, 2)
        x = self.norm(x)
        x = self.qkv(x)
        x = rearrange(x, 'n s (h d) -> (n h) s d', h=self.nheads)
        q,k,v = torch.chunk(x, 3, dim=-1)
        s = (q@k.transpose(1,2))/self.scale
        x = s.softmax(dim=-1)@v
        x = rearrange(x, '(n h) s d -> n s (h d)', h=self.nheads)
        x = self.proj(x)
        if self.t: x = x.transpose(1, 2)
        return x

# %%
#| export
class SelfAttention2D(SelfAttention):
    def forward(self, x):
        n,c,h,w = x.shape
        return super().forward(x.view(n, c, -1)).reshape(n,c,h,w)

# %%
#| export
class EmbResBlock(nn.Module):
    def __init__(self, n_emb, ni, nf=None, ks=3, act=nn.SiLU, norm=nn.BatchNorm2d, attn_chans=0):
        super().__init__()
        if nf is None: nf = ni
        self.emb_proj = nn.Linear(n_emb, nf*2)
        self.conv1 = pre_conv(ni, nf, ks, act=None, norm=norm)
        self.conv2 = pre_conv(nf, nf, ks, act=act, norm=norm)
        self.idconv = fc.noop if ni==nf else nn.Conv2d(ni, nf, 1)
        self.attn = False
        if attn_chans: self.attn = SelfAttention2D(nf, attn_chans)

    def forward(self, x, t):
        inp = x
        x = self.conv1(x)
        emb = self.emb_proj(F.silu(t))[:, :, None, None]
        scale,shift = torch.chunk(emb, 2, dim=1)
        x = x*(1+scale) + shift
        x = self.conv2(x)
        x = x + self.idconv(inp)
        if self.attn: x = x + self.attn(x)
        return x

# %%
#| export
def saved(m, blk):
    m_ = m.forward

    @wraps(m.forward)
    def _f(*args, **kwargs):
        res = m_(*args, **kwargs)
        blk.saved.append(res)
        return res

    m.forward = _f
    return m

# %%
#| export
class DownBlock(nn.Module):
    def __init__(self, n_emb, ni, nf, add_down=True, num_layers=1, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList([saved(EmbResBlock(n_emb, ni if i==0 else nf, nf, attn_chans=attn_chans), self)
                                      for i in range(num_layers)])
        self.down = saved(nn.Conv2d(nf, nf, 3, stride=2, padding=1), self) if add_down else nn.Identity()

    def forward(self, x, t):
        self.saved = []
        for resnet in self.resnets: x = resnet(x, t)
        x = self.down(x)
        return x

# %%
#| export
class UpBlock(nn.Module):
    def __init__(self, n_emb, ni, prev_nf, nf, add_up=True, num_layers=2, attn_chans=0):
        super().__init__()
        self.resnets = nn.ModuleList(
            [EmbResBlock(n_emb, (prev_nf if i==0 else nf)+(ni if (i==num_layers-1) else nf), nf, attn_chans=attn_chans)
            for i in range(num_layers)])
        self.up = upsample(nf) if add_up else nn.Identity()

    def forward(self, x, t, ups):
        for resnet in self.resnets: x = resnet(torch.cat([x, ups.pop()], dim=1), t)
        return self.up(x)

# %%
class LearnEmbSS(nn.Module):
    def __init__(self, sz, ni):
        super().__init__()
        self.scale = nn.Parameter(torch.zeros(sz, ni))
        self.shift = nn.Parameter(torch.zeros(sz, ni))

    def forward(self, x): return x*self.scale + self.shift

# %%
def _mlp(ni, nh):
    return nn.Sequential(nn.Linear(ni,nh), nn.GELU(), nn.LayerNorm(nh), nn.Linear(nh,ni))

# %%
class EmbTransformerBlk(nn.Module):
    def __init__(self, n_emb, ni, attn_chans=8):
        super().__init__()
        self.attn = SelfAttention(ni, attn_chans=attn_chans, transpose=False)
        self.mlp = _mlp(ni, ni*4)
        self.nrm1 = nn.LayerNorm(ni)
        self.nrm2 = nn.LayerNorm(ni)
        self.emb_proj = nn.Linear(n_emb, ni*2)

    def forward(self, x, t):
        emb = self.emb_proj(F.silu(t))[:, None]
        scale,shift = torch.chunk(emb, 2, dim=2)
        x = x + self.attn(self.nrm1(x))
        x = x*(1+scale) + shift
        return x + self.mlp(self.nrm2(x))

# %%
img_vec_len = 4
class SimpleDiffusion(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, nfs=(224,448,672,896), num_layers=1,
                 attn_chans=8, attn_start=1, n_mids=8):
        super().__init__()
        self.conv_in = nn.Conv2d(in_channels, nfs[0], kernel_size=3, padding=1)
        self.n_temb = nf = nfs[0]
        n_emb = nf*4
        self.emb_mlp = nn.Sequential(lin(self.n_temb, n_emb, norm=nn.BatchNorm1d),
                                     lin(n_emb, n_emb))
        self.downs = nn.ModuleList()
        n = len(nfs)
        for i in range(n):
            ni = nf
            nf = nfs[i]
            self.downs.append(DownBlock(n_emb, ni, nf, add_down=i!=n-1, num_layers=num_layers,
                                        attn_chans=0 if i<attn_start else attn_chans))

        self.le = LearnEmbSS(img_vec_len, nf)
        self.mids = nn.ModuleList([EmbTransformerBlk(n_emb, nf) for _ in range(n_mids)])

        rev_nfs = list(reversed(nfs))
        nf = rev_nfs[0]
        self.ups = nn.ModuleList()
        for i in range(n):
            prev_nf = nf
            nf = rev_nfs[i]
            ni = rev_nfs[min(i+1, len(nfs)-1)]
            self.ups.append(UpBlock(n_emb, ni, prev_nf, nf, add_up=i!=n-1, num_layers=num_layers+1,
                                    attn_chans=0 if i>=n-attn_start else attn_chans))
        self.conv_out = pre_conv(nfs[0], out_channels, act=nn.SiLU, norm=nn.BatchNorm2d, bias=False)

    def forward(self, inp):
        x,t = inp
        temb = timestep_embedding(t, self.n_temb)
        emb = self.emb_mlp(temb)
        x = self.conv_in(x)
        saved = [x]
        for block in self.downs: x = block(x, emb)
        saved += [p for o in self.downs for p in o.saved]
        n,c,h,w = x.shape
        x = self.le(x.reshape(n,c,-1).transpose(1,2))
        for block in self.mids: x = block(x, emb)
        x = x.transpose(1,2).reshape(n,c,h,w)
        for block in self.ups: x = block(x, emb, saved)
        return self.conv_out(x)

# %%
#| export
def ddim_step(x_t, noise, abar_t, abar_t1, bbar_t, bbar_t1, eta, sig, clamp=True):
    sig = ((bbar_t1/bbar_t).sqrt() * (1-abar_t/abar_t1).sqrt()) * eta
    x_0_hat = ((x_t-(1-abar_t).sqrt()*noise) / abar_t.sqrt())
    if clamp: x_0_hat = x_0_hat.clamp(-1,1)
    if bbar_t1<=sig**2+0.01: sig=0.  # set to zero if very small or NaN
    x_t = abar_t1.sqrt()*x_0_hat + (bbar_t1-sig**2).sqrt()*noise
    x_t += sig * torch.randn(x_t.shape).to(x_t)
    return x_0_hat,x_t

# %%
#| export
@torch.no_grad()
def sample(f, model, sz, steps, eta=1., clamp=True, progress=False):
    model.eval()
    ts = torch.linspace(1-1/steps,0,steps)
    x_t = torch.randn(sz).cuda()
    preds = []
    tbe = progress_bar(ts) if progress else ts 
    for i,t in enumerate(tbe):
        t = t[None].cuda()
        abar_t = abar(t)
        noise = model((x_t, t))
        abar_t1 = abar(t-1/steps) if t>=1/steps else torch.tensor(1)
        x_0_hat,x_t = f(x_t, noise, abar_t, abar_t1, 1-abar_t, 1-abar_t1, eta, 1-((i+1)/100), clamp=clamp)
        preds.append(x_0_hat.float().cpu())
    return preds

# %%
import wandb

class WandBCB(MetricsCB):
    order=100
    def __init__(self, config, *ms, project='ddpm_goldfish_64x64_clip', **metrics):
        fc.store_attr()
        super().__init__(*ms, **metrics)
        
    def before_fit(self, learn): wandb.init(project=self.project, config=self.config)
    def after_fit(self, learn): wandb.finish()

    def _log(self, d):
        #import pdb; pdb.set_trace()
        if learn.model.training: 
            wandb.log({'train_'+m:float(d[m]) for m in self.all_metrics})
        else: 
            wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
            wandb.log({'samples':self.sample_figure(learn)})
        print(d)

        
    def sample_figure(self, learn):
        with torch.no_grad():
            preds = sample(ddim_step, model, (16, 4, 8, 8), steps=100, eta=1.)
        s = to_cpu(vae.decode(preds[-1].cuda()*5))
        s = s['sample'].clamp(0,1)
        plt.clf()
        fig, axs = get_grid(16, imsize=3)
        for im,ax in zip(s[:16], axs.flat): show_image(im, ax=ax)
        return fig

    def after_batch(self, learn):
        super().after_batch(learn) 
        wandb.log({'loss':learn.loss})

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
import os
os.environ['WANDB_NOTEBOOK_NAME'] = '09_diffusion-attn-cond_tin_goldfish_64x64_CLIP_i1.ipynb'
lr = 1e-4
epochs = 1500
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512), num_layers=2, attn_chans=0, attn_start=1, n_mids=10)'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
#model = EmbUNetModel(in_channels=3, out_channels=3, nfs=(32,64,128,256,512), num_layers=2)
model = SimpleDiffusion(in_channels=4, out_channels=4, nfs=(128,256,512), num_layers=2, attn_chans=0, attn_start=1, n_mids=10)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# wandb: Currently logged in as: dumbdude (dumbdude-none). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_084921-39d9jmw4</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/39d9jmw4' target="_blank">fiery-silence-2</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/39d9jmw4' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/39d9jmw4</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'loss': '1.061', 'epoch': 0, 'train': 'train'}
# {'loss': '0.991', 'epoch': 0, 'train': 'eval'}
# {'loss': '1.057', 'epoch': 1, 'train': 'train'}
# {'loss': '0.990', 'epoch': 1, 'train': 'eval'}
# {'loss': '1.053', 'epoch': 2, 'train': 'train'}
# {'loss': '1.001', 'epoch': 2, 'train': 'eval'}
# {'loss': '1.048', 'epoch': 3, 'train': 'train'}
# {'loss': '1.000', 'epoch': 3, 'train': 'eval'}
# {'loss': '1.042', 'epoch': 4, 'train': 'train'}
# {'loss': '0.984', 'epoch': 4, 'train': 'eval'}
# {'loss': '1.037', 'epoch': 5, 'train': 'train'}
# {'loss': '0.976', 'epoch': 5, 'train': 'eval'}
# {'loss': '1.029', 'epoch': 6, 'train': 'train'}
# {'loss': '0.996', 'epoch': 6, 'train': 'eval'}
# {'loss': '1.031', 'epoch': 7, 'train': 'train'}
# {'loss': '0.998', 'epoch': 7, 'train': 'eval'}
# {'loss': '1.025', 'epoch': 8, 'train': 'train'}
# {'loss': '0.983', 'epoch': 8, 'train': 'eval'}
# {'loss': '1.023', 'epoch': 9, 'train': 'train'}
# {'loss': '0.992', 'epoch': 9, 'train': 'eval'}
# {'loss': '1.017', 'epoch': 10, 'train': 'train'}
# {'loss': '0.986', 'epoch': 10, 'train': 'eval'}
# {'loss': '1.008', 'epoch': 11, 'train': 'train'}
# {'loss': '0.988', 'epoch': 11, 'train': 'eval'}
# {'loss': '1.001', 'epoch': 12, 'train': 'train'}
# {'loss': '0.977', 'epoch': 12, 'train': 'eval'}
# {'loss': '1.000', 'epoch': 13, 'train': 'train'}
# {'loss': '0.989', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.993', 'epoch': 14, 'train': 'train'}
# {'loss': '0.984', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.986', 'epoch': 15, 'train': 'train'}
# {'loss': '0.957', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.986', 'epoch': 16, 'train': 'train'}
# {'loss': '0.979', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.984', 'epoch': 17, 'train': 'train'}
# {'loss': '0.973', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.973', 'epoch': 18, 'train': 'train'}
# {'loss': '0.966', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.965', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '0.950', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.965', 'epoch': 20, 'train': 'train'}
# {'loss': '0.969', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.962', 'epoch': 21, 'train': 'train'}
# {'loss': '0.965', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.954', 'epoch': 22, 'train': 'train'}
# {'loss': '0.958', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.949', 'epoch': 23, 'train': 'train'}
# {'loss': '0.950', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.945', 'epoch': 24, 'train': 'train'}
# {'loss': '0.962', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.941', 'epoch': 25, 'train': 'train'}
# {'loss': '0.949', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.936', 'epoch': 26, 'train': 'train'}
# {'loss': '0.948', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.929', 'epoch': 27, 'train': 'train'}
# {'loss': '0.952', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.925', 'epoch': 28, 'train': 'train'}
# {'loss': '0.932', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.923', 'epoch': 29, 'train': 'train'}
# {'loss': '0.921', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.913', 'epoch': 30, 'train': 'train'}
# {'loss': '0.933', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.908', 'epoch': 31, 'train': 'train'}
# {'loss': '0.927', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.912', 'epoch': 32, 'train': 'train'}
# {'loss': '0.915', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.891', 'epoch': 33, 'train': 'train'}
# {'loss': '0.901', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.891', 'epoch': 34, 'train': 'train'}
# {'loss': '0.903', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.885', 'epoch': 35, 'train': 'train'}
# {'loss': '0.906', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.882', 'epoch': 36, 'train': 'train'}
# {'loss': '0.907', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.873', 'epoch': 37, 'train': 'train'}
# {'loss': '0.884', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.872', 'epoch': 38, 'train': 'train'}
# {'loss': '0.892', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.861', 'epoch': 39, 'train': 'train'}
# {'loss': '0.886', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.859', 'epoch': 40, 'train': 'train'}
# {'loss': '0.870', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.859', 'epoch': 41, 'train': 'train'}
# {'loss': '0.884', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.845', 'epoch': 42, 'train': 'train'}
# {'loss': '0.857', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.848', 'epoch': 43, 'train': 'train'}
# {'loss': '0.852', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.834', 'epoch': 44, 'train': 'train'}
# {'loss': '0.839', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.830', 'epoch': 45, 'train': 'train'}
# {'loss': '0.853', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.831', 'epoch': 46, 'train': 'train'}
# {'loss': '0.840', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.809', 'epoch': 47, 'train': 'train'}
# {'loss': '0.825', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.807', 'epoch': 48, 'train': 'train'}
# {'loss': '0.801', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.803', 'epoch': 49, 'train': 'train'}
# {'loss': '0.819', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.799', 'epoch': 50, 'train': 'train'}
# {'loss': '0.828', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.797', 'epoch': 51, 'train': 'train'}
# {'loss': '0.808', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.789', 'epoch': 52, 'train': 'train'}
# {'loss': '0.767', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.783', 'epoch': 53, 'train': 'train'}
# {'loss': '0.778', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.773', 'epoch': 54, 'train': 'train'}
# {'loss': '0.791', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.779', 'epoch': 55, 'train': 'train'}
# {'loss': '0.760', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.759', 'epoch': 56, 'train': 'train'}
# {'loss': '0.771', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.753', 'epoch': 57, 'train': 'train'}
# {'loss': '0.763', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.748', 'epoch': 58, 'train': 'train'}
# {'loss': '0.744', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.741', 'epoch': 59, 'train': 'train'}
# {'loss': '0.716', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.741', 'epoch': 60, 'train': 'train'}
# {'loss': '0.732', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.728', 'epoch': 61, 'train': 'train'}
# {'loss': '0.712', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.721', 'epoch': 62, 'train': 'train'}
# {'loss': '0.707', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.717', 'epoch': 63, 'train': 'train'}
# {'loss': '0.697', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.706', 'epoch': 64, 'train': 'train'}
# {'loss': '0.705', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.697', 'epoch': 65, 'train': 'train'}
# {'loss': '0.716', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.693', 'epoch': 66, 'train': 'train'}
# {'loss': '0.666', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.690', 'epoch': 67, 'train': 'train'}
# {'loss': '0.690', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.688', 'epoch': 68, 'train': 'train'}
# {'loss': '0.666', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.679', 'epoch': 69, 'train': 'train'}
# {'loss': '0.650', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.673', 'epoch': 70, 'train': 'train'}
# {'loss': '0.658', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.664', 'epoch': 71, 'train': 'train'}
# {'loss': '0.627', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.659', 'epoch': 72, 'train': 'train'}
# {'loss': '0.642', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.658', 'epoch': 73, 'train': 'train'}
# {'loss': '0.624', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.650', 'epoch': 74, 'train': 'train'}
# {'loss': '0.648', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.651', 'epoch': 75, 'train': 'train'}
# {'loss': '0.598', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.643', 'epoch': 76, 'train': 'train'}
# {'loss': '0.642', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.635', 'epoch': 77, 'train': 'train'}
# {'loss': '0.586', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.621', 'epoch': 78, 'train': 'train'}
# {'loss': '0.650', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.612', 'epoch': 79, 'train': 'train'}
# {'loss': '0.613', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.605', 'epoch': 80, 'train': 'train'}
# {'loss': '0.587', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.606', 'epoch': 81, 'train': 'train'}
# {'loss': '0.584', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.592', 'epoch': 82, 'train': 'train'}
# {'loss': '0.604', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.604', 'epoch': 83, 'train': 'train'}
# {'loss': '0.609', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.591', 'epoch': 84, 'train': 'train'}
# {'loss': '0.581', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.583', 'epoch': 85, 'train': 'train'}
# {'loss': '0.601', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.581', 'epoch': 86, 'train': 'train'}
# {'loss': '0.594', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.567', 'epoch': 87, 'train': 'train'}
# {'loss': '0.567', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.560', 'epoch': 88, 'train': 'train'}
# {'loss': '0.540', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.559', 'epoch': 89, 'train': 'train'}
# {'loss': '0.532', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.560', 'epoch': 90, 'train': 'train'}
# {'loss': '0.559', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.561', 'epoch': 91, 'train': 'train'}
# {'loss': '0.526', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.555', 'epoch': 92, 'train': 'train'}
# {'loss': '0.594', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.553', 'epoch': 93, 'train': 'train'}
# {'loss': '0.605', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.552', 'epoch': 94, 'train': 'train'}
# {'loss': '0.599', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.532', 'epoch': 95, 'train': 'train'}
# {'loss': '0.592', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.540', 'epoch': 96, 'train': 'train'}
# {'loss': '0.586', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.533', 'epoch': 97, 'train': 'train'}
# {'loss': '0.607', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.529', 'epoch': 98, 'train': 'train'}
# {'loss': '0.627', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.536', 'epoch': 99, 'train': 'train'}
# {'loss': '0.653', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.528', 'epoch': 100, 'train': 'train'}
# {'loss': '0.622', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.511', 'epoch': 101, 'train': 'train'}
# {'loss': '0.590', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.511', 'epoch': 102, 'train': 'train'}
# {'loss': '0.591', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.508', 'epoch': 103, 'train': 'train'}
# {'loss': '0.624', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.507', 'epoch': 104, 'train': 'train'}
# {'loss': '0.602', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.475', 'epoch': 105, 'train': 'train'}
# {'loss': '0.637', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.500', 'epoch': 106, 'train': 'train'}
# {'loss': '0.598', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.503', 'epoch': 107, 'train': 'train'}
# {'loss': '0.648', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.506', 'epoch': 108, 'train': 'train'}
# {'loss': '0.650', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.491', 'epoch': 109, 'train': 'train'}
# {'loss': '0.602', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.491', 'epoch': 110, 'train': 'train'}
# {'loss': '0.643', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.499', 'epoch': 111, 'train': 'train'}
# {'loss': '0.674', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.482', 'epoch': 112, 'train': 'train'}
# {'loss': '0.706', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.469', 'epoch': 113, 'train': 'train'}
# {'loss': '0.693', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.494', 'epoch': 114, 'train': 'train'}
# {'loss': '0.637', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.488', 'epoch': 115, 'train': 'train'}
# {'loss': '0.700', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.477', 'epoch': 116, 'train': 'train'}
# {'loss': '0.723', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.471', 'epoch': 117, 'train': 'train'}
# {'loss': '0.727', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.500', 'epoch': 118, 'train': 'train'}
# {'loss': '0.792', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.467', 'epoch': 119, 'train': 'train'}
# {'loss': '0.802', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.477', 'epoch': 120, 'train': 'train'}
# {'loss': '0.739', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.473', 'epoch': 121, 'train': 'train'}
# {'loss': '0.692', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.477', 'epoch': 122, 'train': 'train'}
# {'loss': '0.754', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.463', 'epoch': 123, 'train': 'train'}
# {'loss': '0.768', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 124, 'train': 'train'}
# {'loss': '0.829', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.460', 'epoch': 125, 'train': 'train'}
# {'loss': '0.810', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.465', 'epoch': 126, 'train': 'train'}
# {'loss': '0.768', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.443', 'epoch': 127, 'train': 'train'}
# {'loss': '0.769', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.475', 'epoch': 128, 'train': 'train'}
# {'loss': '0.805', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.474', 'epoch': 129, 'train': 'train'}
# {'loss': '0.778', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.457', 'epoch': 130, 'train': 'train'}
# {'loss': '0.786', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.463', 'epoch': 131, 'train': 'train'}
# {'loss': '0.711', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.449', 'epoch': 132, 'train': 'train'}
# {'loss': '0.701', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.457', 'epoch': 133, 'train': 'train'}
# {'loss': '0.665', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.463', 'epoch': 134, 'train': 'train'}
# {'loss': '0.637', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.443', 'epoch': 135, 'train': 'train'}
# {'loss': '0.609', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.441', 'epoch': 136, 'train': 'train'}
# {'loss': '0.644', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.469', 'epoch': 137, 'train': 'train'}
# {'loss': '0.580', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.447', 'epoch': 138, 'train': 'train'}
# {'loss': '0.570', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.444', 'epoch': 139, 'train': 'train'}
# {'loss': '0.527', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.452', 'epoch': 140, 'train': 'train'}
# {'loss': '0.490', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.445', 'epoch': 141, 'train': 'train'}
# {'loss': '0.502', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.443', 'epoch': 142, 'train': 'train'}
# {'loss': '0.521', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.440', 'epoch': 143, 'train': 'train'}
# {'loss': '0.477', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.432', 'epoch': 144, 'train': 'train'}
# {'loss': '0.466', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.446', 'epoch': 145, 'train': 'train'}
# {'loss': '0.487', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.436', 'epoch': 146, 'train': 'train'}
# {'loss': '0.459', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.447', 'epoch': 147, 'train': 'train'}
# {'loss': '0.492', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 148, 'train': 'train'}
# {'loss': '0.514', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.442', 'epoch': 149, 'train': 'train'}
# {'loss': '0.459', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.453', 'epoch': 150, 'train': 'train'}
# {'loss': '0.462', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.421', 'epoch': 151, 'train': 'train'}
# {'loss': '0.450', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.438', 'epoch': 152, 'train': 'train'}
# {'loss': '0.429', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.435', 'epoch': 153, 'train': 'train'}
# {'loss': '0.417', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.431', 'epoch': 154, 'train': 'train'}
# {'loss': '0.405', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.438', 'epoch': 155, 'train': 'train'}
# {'loss': '0.440', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.430', 'epoch': 156, 'train': 'train'}
# {'loss': '0.438', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.407', 'epoch': 157, 'train': 'train'}
# {'loss': '0.459', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.424', 'epoch': 158, 'train': 'train'}
# {'loss': '0.405', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.422', 'epoch': 159, 'train': 'train'}
# {'loss': '0.452', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.415', 'epoch': 160, 'train': 'train'}
# {'loss': '0.431', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.439', 'epoch': 161, 'train': 'train'}
# {'loss': '0.489', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.417', 'epoch': 162, 'train': 'train'}
# {'loss': '0.437', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 163, 'train': 'train'}
# {'loss': '0.380', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.431', 'epoch': 164, 'train': 'train'}
# {'loss': '0.452', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.436', 'epoch': 165, 'train': 'train'}
# {'loss': '0.416', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.420', 'epoch': 166, 'train': 'train'}
# {'loss': '0.449', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.427', 'epoch': 167, 'train': 'train'}
# {'loss': '0.419', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 168, 'train': 'train'}
# {'loss': '0.465', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.420', 'epoch': 169, 'train': 'train'}
# {'loss': '0.456', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.415', 'epoch': 170, 'train': 'train'}
# {'loss': '0.378', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 171, 'train': 'train'}
# {'loss': '0.462', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 172, 'train': 'train'}
# {'loss': '0.412', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.405', 'epoch': 173, 'train': 'train'}
# {'loss': '0.477', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.426', 'epoch': 174, 'train': 'train'}
# {'loss': '0.516', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.411', 'epoch': 175, 'train': 'train'}
# {'loss': '0.410', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.408', 'epoch': 176, 'train': 'train'}
# {'loss': '0.432', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.415', 'epoch': 177, 'train': 'train'}
# {'loss': '0.505', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 178, 'train': 'train'}
# {'loss': '0.502', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.403', 'epoch': 179, 'train': 'train'}
# {'loss': '0.540', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.410', 'epoch': 180, 'train': 'train'}
# {'loss': '0.595', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 181, 'train': 'train'}
# {'loss': '0.566', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.416', 'epoch': 182, 'train': 'train'}
# {'loss': '0.513', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 183, 'train': 'train'}
# {'loss': '0.570', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 184, 'train': 'train'}
# {'loss': '0.548', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.408', 'epoch': 185, 'train': 'train'}
# {'loss': '0.517', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 186, 'train': 'train'}
# {'loss': '0.518', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.406', 'epoch': 187, 'train': 'train'}
# {'loss': '0.556', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.404', 'epoch': 188, 'train': 'train'}
# {'loss': '0.599', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.397', 'epoch': 189, 'train': 'train'}
# {'loss': '0.491', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.389', 'epoch': 190, 'train': 'train'}
# {'loss': '0.529', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 191, 'train': 'train'}
# {'loss': '0.553', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.390', 'epoch': 192, 'train': 'train'}
# {'loss': '0.553', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.378', 'epoch': 193, 'train': 'train'}
# {'loss': '0.543', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.414', 'epoch': 194, 'train': 'train'}
# {'loss': '0.547', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.394', 'epoch': 195, 'train': 'train'}
# {'loss': '0.547', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 196, 'train': 'train'}
# {'loss': '0.496', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.399', 'epoch': 197, 'train': 'train'}
# {'loss': '0.476', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.395', 'epoch': 198, 'train': 'train'}
# {'loss': '0.451', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 199, 'train': 'train'}
# {'loss': '0.431', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.376', 'epoch': 200, 'train': 'train'}
# {'loss': '0.417', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 201, 'train': 'train'}
# {'loss': '0.376', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 202, 'train': 'train'}
# {'loss': '0.389', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.368', 'epoch': 203, 'train': 'train'}
# {'loss': '0.445', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.396', 'epoch': 204, 'train': 'train'}
# {'loss': '0.388', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.394', 'epoch': 205, 'train': 'train'}
# {'loss': '0.472', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 206, 'train': 'train'}
# {'loss': '0.399', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 207, 'train': 'train'}
# {'loss': '0.441', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.387', 'epoch': 208, 'train': 'train'}
# {'loss': '0.376', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 209, 'train': 'train'}
# {'loss': '0.440', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 210, 'train': 'train'}
# {'loss': '0.390', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 211, 'train': 'train'}
# {'loss': '0.441', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 212, 'train': 'train'}
# {'loss': '0.410', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 213, 'train': 'train'}
# {'loss': '0.425', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.385', 'epoch': 214, 'train': 'train'}
# {'loss': '0.397', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 215, 'train': 'train'}
# {'loss': '0.379', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 216, 'train': 'train'}
# {'loss': '0.456', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.387', 'epoch': 217, 'train': 'train'}
# {'loss': '0.436', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.402', 'epoch': 218, 'train': 'train'}
# {'loss': '0.397', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 219, 'train': 'train'}
# {'loss': '0.398', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.390', 'epoch': 220, 'train': 'train'}
# {'loss': '0.411', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.398', 'epoch': 221, 'train': 'train'}
# {'loss': '0.443', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.387', 'epoch': 222, 'train': 'train'}
# {'loss': '0.472', 'epoch': 222, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 223, 'train': 'train'}
# {'loss': '0.427', 'epoch': 223, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 224, 'train': 'train'}
# {'loss': '0.391', 'epoch': 224, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 225, 'train': 'train'}
# {'loss': '0.454', 'epoch': 225, 'train': 'eval'}
# {'loss': '0.392', 'epoch': 226, 'train': 'train'}
# {'loss': '0.405', 'epoch': 226, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 227, 'train': 'train'}
# {'loss': '0.425', 'epoch': 227, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 228, 'train': 'train'}
# {'loss': '0.426', 'epoch': 228, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 229, 'train': 'train'}
# {'loss': '0.404', 'epoch': 229, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 230, 'train': 'train'}
# {'loss': '0.393', 'epoch': 230, 'train': 'eval'}
# {'loss': '0.389', 'epoch': 231, 'train': 'train'}
# {'loss': '0.440', 'epoch': 231, 'train': 'eval'}
# {'loss': '0.382', 'epoch': 232, 'train': 'train'}
# {'loss': '0.375', 'epoch': 232, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 233, 'train': 'train'}
# {'loss': '0.410', 'epoch': 233, 'train': 'eval'}
# {'loss': '0.373', 'epoch': 234, 'train': 'train'}
# {'loss': '0.383', 'epoch': 234, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 235, 'train': 'train'}
# {'loss': '0.366', 'epoch': 235, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 236, 'train': 'train'}
# {'loss': '0.394', 'epoch': 236, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 237, 'train': 'train'}
# {'loss': '0.411', 'epoch': 237, 'train': 'eval'}
# {'loss': '0.377', 'epoch': 238, 'train': 'train'}
# {'loss': '0.413', 'epoch': 238, 'train': 'eval'}
# {'loss': '0.388', 'epoch': 239, 'train': 'train'}
# {'loss': '0.372', 'epoch': 239, 'train': 'eval'}
# {'loss': '0.386', 'epoch': 240, 'train': 'train'}
# {'loss': '0.393', 'epoch': 240, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 241, 'train': 'train'}
# {'loss': '0.369', 'epoch': 241, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 242, 'train': 'train'}
# {'loss': '0.318', 'epoch': 242, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 243, 'train': 'train'}
# {'loss': '0.441', 'epoch': 243, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 244, 'train': 'train'}
# {'loss': '0.424', 'epoch': 244, 'train': 'eval'}
# {'loss': '0.374', 'epoch': 245, 'train': 'train'}
# {'loss': '0.376', 'epoch': 245, 'train': 'eval'}
# {'loss': '0.380', 'epoch': 246, 'train': 'train'}
# {'loss': '0.393', 'epoch': 246, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 247, 'train': 'train'}
# {'loss': '0.318', 'epoch': 247, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 248, 'train': 'train'}
# {'loss': '0.350', 'epoch': 248, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 249, 'train': 'train'}
# {'loss': '0.419', 'epoch': 249, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 250, 'train': 'train'}
# {'loss': '0.471', 'epoch': 250, 'train': 'eval'}
# {'loss': '0.349', 'epoch': 251, 'train': 'train'}
# {'loss': '0.451', 'epoch': 251, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 252, 'train': 'train'}
# {'loss': '0.423', 'epoch': 252, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 253, 'train': 'train'}
# {'loss': '0.550', 'epoch': 253, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 254, 'train': 'train'}
# {'loss': '0.543', 'epoch': 254, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 255, 'train': 'train'}
# {'loss': '0.446', 'epoch': 255, 'train': 'eval'}
# {'loss': '0.370', 'epoch': 256, 'train': 'train'}
# {'loss': '0.452', 'epoch': 256, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 257, 'train': 'train'}
# {'loss': '0.543', 'epoch': 257, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 258, 'train': 'train'}
# {'loss': '0.603', 'epoch': 258, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 259, 'train': 'train'}
# {'loss': '0.721', 'epoch': 259, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 260, 'train': 'train'}
# {'loss': '0.671', 'epoch': 260, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 261, 'train': 'train'}
# {'loss': '0.583', 'epoch': 261, 'train': 'eval'}
# {'loss': '0.383', 'epoch': 262, 'train': 'train'}
# {'loss': '0.622', 'epoch': 262, 'train': 'eval'}
# {'loss': '0.387', 'epoch': 263, 'train': 'train'}
# {'loss': '0.702', 'epoch': 263, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 264, 'train': 'train'}
# {'loss': '0.597', 'epoch': 264, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 265, 'train': 'train'}
# {'loss': '0.441', 'epoch': 265, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 266, 'train': 'train'}
# {'loss': '0.480', 'epoch': 266, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 267, 'train': 'train'}
# {'loss': '0.356', 'epoch': 267, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 268, 'train': 'train'}
# {'loss': '0.381', 'epoch': 268, 'train': 'eval'}
# {'loss': '0.372', 'epoch': 269, 'train': 'train'}
# {'loss': '0.403', 'epoch': 269, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 270, 'train': 'train'}
# {'loss': '0.393', 'epoch': 270, 'train': 'eval'}
# {'loss': '0.350', 'epoch': 271, 'train': 'train'}
# {'loss': '0.396', 'epoch': 271, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 272, 'train': 'train'}
# {'loss': '0.336', 'epoch': 272, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 273, 'train': 'train'}
# {'loss': '0.447', 'epoch': 273, 'train': 'eval'}
# {'loss': '0.355', 'epoch': 274, 'train': 'train'}
# {'loss': '0.415', 'epoch': 274, 'train': 'eval'}
# {'loss': '0.375', 'epoch': 275, 'train': 'train'}
# {'loss': '0.440', 'epoch': 275, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 276, 'train': 'train'}
# {'loss': '0.411', 'epoch': 276, 'train': 'eval'}
# {'loss': '0.359', 'epoch': 277, 'train': 'train'}
# {'loss': '0.363', 'epoch': 277, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 278, 'train': 'train'}
# {'loss': '0.379', 'epoch': 278, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 279, 'train': 'train'}
# {'loss': '0.400', 'epoch': 279, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 280, 'train': 'train'}
# {'loss': '0.441', 'epoch': 280, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 281, 'train': 'train'}
# {'loss': '0.420', 'epoch': 281, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 282, 'train': 'train'}
# {'loss': '0.400', 'epoch': 282, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 283, 'train': 'train'}
# {'loss': '0.365', 'epoch': 283, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 284, 'train': 'train'}
# {'loss': '0.392', 'epoch': 284, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 285, 'train': 'train'}
# {'loss': '0.356', 'epoch': 285, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 286, 'train': 'train'}
# {'loss': '0.485', 'epoch': 286, 'train': 'eval'}
# {'loss': '0.365', 'epoch': 287, 'train': 'train'}
# {'loss': '0.447', 'epoch': 287, 'train': 'eval'}
# {'loss': '0.361', 'epoch': 288, 'train': 'train'}
# {'loss': '0.353', 'epoch': 288, 'train': 'eval'}
# {'loss': '0.369', 'epoch': 289, 'train': 'train'}
# {'loss': '0.416', 'epoch': 289, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 290, 'train': 'train'}
# {'loss': '0.397', 'epoch': 290, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 291, 'train': 'train'}
# {'loss': '0.329', 'epoch': 291, 'train': 'eval'}
# {'loss': '0.363', 'epoch': 292, 'train': 'train'}
# {'loss': '0.363', 'epoch': 292, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 293, 'train': 'train'}
# {'loss': '0.375', 'epoch': 293, 'train': 'eval'}
# {'loss': '0.362', 'epoch': 294, 'train': 'train'}
# {'loss': '0.384', 'epoch': 294, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 295, 'train': 'train'}
# {'loss': '0.433', 'epoch': 295, 'train': 'eval'}
# {'loss': '0.347', 'epoch': 296, 'train': 'train'}
# {'loss': '0.410', 'epoch': 296, 'train': 'eval'}
# {'loss': '0.357', 'epoch': 297, 'train': 'train'}
# {'loss': '0.367', 'epoch': 297, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 298, 'train': 'train'}
# {'loss': '0.327', 'epoch': 298, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 299, 'train': 'train'}
# {'loss': '0.407', 'epoch': 299, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 300, 'train': 'train'}
# {'loss': '0.473', 'epoch': 300, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 301, 'train': 'train'}
# {'loss': '0.691', 'epoch': 301, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 302, 'train': 'train'}
# {'loss': '0.781', 'epoch': 302, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 303, 'train': 'train'}
# {'loss': '0.910', 'epoch': 303, 'train': 'eval'}
# {'loss': '0.358', 'epoch': 304, 'train': 'train'}
# {'loss': '0.918', 'epoch': 304, 'train': 'eval'}
# {'loss': '0.367', 'epoch': 305, 'train': 'train'}
# {'loss': '0.716', 'epoch': 305, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 306, 'train': 'train'}
# {'loss': '0.457', 'epoch': 306, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 307, 'train': 'train'}
# {'loss': '0.528', 'epoch': 307, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 308, 'train': 'train'}
# {'loss': '0.608', 'epoch': 308, 'train': 'eval'}
# {'loss': '0.360', 'epoch': 309, 'train': 'train'}
# {'loss': '0.363', 'epoch': 309, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 310, 'train': 'train'}
# {'loss': '0.361', 'epoch': 310, 'train': 'eval'}
# {'loss': '0.332', 'epoch': 311, 'train': 'train'}
# {'loss': '0.408', 'epoch': 311, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 312, 'train': 'train'}
# {'loss': '0.363', 'epoch': 312, 'train': 'eval'}
# {'loss': '0.352', 'epoch': 313, 'train': 'train'}
# {'loss': '0.348', 'epoch': 313, 'train': 'eval'}
# {'loss': '0.330', 'epoch': 314, 'train': 'train'}
# {'loss': '0.476', 'epoch': 314, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 315, 'train': 'train'}
# {'loss': '0.404', 'epoch': 315, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 316, 'train': 'train'}
# {'loss': '0.378', 'epoch': 316, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 317, 'train': 'train'}
# {'loss': '0.354', 'epoch': 317, 'train': 'eval'}
# {'loss': '0.366', 'epoch': 318, 'train': 'train'}
# {'loss': '0.356', 'epoch': 318, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 319, 'train': 'train'}
# {'loss': '0.374', 'epoch': 319, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 320, 'train': 'train'}
# {'loss': '0.383', 'epoch': 320, 'train': 'eval'}
# {'loss': '0.341', 'epoch': 321, 'train': 'train'}
# {'loss': '0.389', 'epoch': 321, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 322, 'train': 'train'}
# {'loss': '0.417', 'epoch': 322, 'train': 'eval'}
# {'loss': '0.356', 'epoch': 323, 'train': 'train'}
# {'loss': '0.415', 'epoch': 323, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 324, 'train': 'train'}
# {'loss': '0.415', 'epoch': 324, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 325, 'train': 'train'}
# {'loss': '0.344', 'epoch': 325, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 326, 'train': 'train'}
# {'loss': '0.340', 'epoch': 326, 'train': 'eval'}
# {'loss': '0.351', 'epoch': 327, 'train': 'train'}
# {'loss': '0.387', 'epoch': 327, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 328, 'train': 'train'}
# {'loss': '0.371', 'epoch': 328, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 329, 'train': 'train'}
# {'loss': '0.409', 'epoch': 329, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 330, 'train': 'train'}
# {'loss': '0.423', 'epoch': 330, 'train': 'eval'}
# {'loss': '0.336', 'epoch': 331, 'train': 'train'}
# {'loss': '0.462', 'epoch': 331, 'train': 'eval'}
# {'loss': '0.353', 'epoch': 332, 'train': 'train'}
# {'loss': '0.485', 'epoch': 332, 'train': 'eval'}
# {'loss': '0.338', 'epoch': 333, 'train': 'train'}
# {'loss': '0.392', 'epoch': 333, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 334, 'train': 'train'}
# {'loss': '0.375', 'epoch': 334, 'train': 'eval'}
# {'loss': '0.345', 'epoch': 335, 'train': 'train'}
# {'loss': '0.420', 'epoch': 335, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 336, 'train': 'train'}
# {'loss': '0.400', 'epoch': 336, 'train': 'eval'}
# {'loss': '0.344', 'epoch': 337, 'train': 'train'}
# {'loss': '0.409', 'epoch': 337, 'train': 'eval'}
# {'loss': '0.342', 'epoch': 338, 'train': 'train'}
# {'loss': '0.365', 'epoch': 338, 'train': 'eval'}
# {'loss': '0.348', 'epoch': 339, 'train': 'train'}
# {'loss': '0.393', 'epoch': 339, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 340, 'train': 'train'}
# {'loss': '0.408', 'epoch': 340, 'train': 'eval'}
# {'loss': '0.343', 'epoch': 341, 'train': 'train'}
# {'loss': '0.434', 'epoch': 341, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 342, 'train': 'train'}
# {'loss': '0.386', 'epoch': 342, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 343, 'train': 'train'}
# {'loss': '0.429', 'epoch': 343, 'train': 'eval'}
# {'loss': '0.354', 'epoch': 344, 'train': 'train'}
# {'loss': '0.380', 'epoch': 344, 'train': 'eval'}
# {'loss': '0.346', 'epoch': 345, 'train': 'train'}
# {'loss': '0.879', 'epoch': 345, 'train': 'eval'}
# {'loss': '0.325', 'epoch': 346, 'train': 'train'}
# {'loss': '0.989', 'epoch': 346, 'train': 'eval'}
# {'loss': '0.339', 'epoch': 347, 'train': 'train'}
# {'loss': '0.998', 'epoch': 347, 'train': 'eval'}
# {'loss': '0.337', 'epoch': 348, 'train': 'train'}
# {'loss': '0.932', 'epoch': 348, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 349, 'train': 'train'}
# {'loss': '0.464', 'epoch': 349, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 350, 'train': 'train'}
# {'loss': '0.396', 'epoch': 350, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 351, 'train': 'train'}
# {'loss': '0.465', 'epoch': 351, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 352, 'train': 'train'}
# {'loss': '0.504', 'epoch': 352, 'train': 'eval'}
# {'loss': '0.310', 'epoch': 353, 'train': 'train'}
# {'loss': '0.420', 'epoch': 353, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 354, 'train': 'train'}
# {'loss': '0.447', 'epoch': 354, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 355, 'train': 'train'}
# {'loss': '0.504', 'epoch': 355, 'train': 'eval'}
# {'loss': '0.340', 'epoch': 356, 'train': 'train'}
# {'loss': '0.389', 'epoch': 356, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 357, 'train': 'train'}
# {'loss': '0.402', 'epoch': 357, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 358, 'train': 'train'}
# {'loss': '0.445', 'epoch': 358, 'train': 'eval'}
# {'loss': '0.331', 'epoch': 359, 'train': 'train'}
# {'loss': '0.405', 'epoch': 359, 'train': 'eval'}
# {'loss': '0.333', 'epoch': 360, 'train': 'train'}
# {'loss': '0.444', 'epoch': 360, 'train': 'eval'}
# {'loss': '0.326', 'epoch': 361, 'train': 'train'}
# {'loss': '0.466', 'epoch': 361, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 362, 'train': 'train'}
# {'loss': '0.442', 'epoch': 362, 'train': 'eval'}
# {'loss': '0.319', 'epoch': 363, 'train': 'train'}
# {'loss': '0.430', 'epoch': 363, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 364, 'train': 'train'}
# {'loss': '0.418', 'epoch': 364, 'train': 'eval'}
# {'loss': '0.328', 'epoch': 365, 'train': 'train'}
# {'loss': '0.382', 'epoch': 365, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 366, 'train': 'train'}
# {'loss': '0.579', 'epoch': 366, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 367, 'train': 'train'}
# {'loss': '0.608', 'epoch': 367, 'train': 'eval'}
# {'loss': '0.329', 'epoch': 368, 'train': 'train'}
# {'loss': '0.451', 'epoch': 368, 'train': 'eval'}
# {'loss': '0.324', 'epoch': 369, 'train': 'train'}
# {'loss': '0.431', 'epoch': 369, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 370, 'train': 'train'}
# {'loss': '0.455', 'epoch': 370, 'train': 'eval'}
# {'loss': '0.313', 'epoch': 371, 'train': 'train'}
# {'loss': '0.394', 'epoch': 371, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 372, 'train': 'train'}
# {'loss': '0.428', 'epoch': 372, 'train': 'eval'}
# {'loss': '0.335', 'epoch': 373, 'train': 'train'}
# {'loss': '0.410', 'epoch': 373, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 374, 'train': 'train'}
# {'loss': '0.464', 'epoch': 374, 'train': 'eval'}
# {'loss': '0.323', 'epoch': 375, 'train': 'train'}
# {'loss': '0.413', 'epoch': 375, 'train': 'eval'}
# {'loss': '0.321', 'epoch': 376, 'train': 'train'}
# {'loss': '0.826', 'epoch': 376, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 377, 'train': 'train'}
# {'loss': '0.810', 'epoch': 377, 'train': 'eval'}
# {'loss': '0.305', 'epoch': 378, 'train': 'train'}
# {'loss': '0.825', 'epoch': 378, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 379, 'train': 'train'}
# {'loss': '0.488', 'epoch': 379, 'train': 'eval'}
# {'loss': '0.327', 'epoch': 380, 'train': 'train'}
# {'loss': '0.391', 'epoch': 380, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 381, 'train': 'train'}
# {'loss': '0.421', 'epoch': 381, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 382, 'train': 'train'}
# {'loss': '0.518', 'epoch': 382, 'train': 'eval'}
# {'loss': '0.334', 'epoch': 383, 'train': 'train'}
# {'loss': '0.527', 'epoch': 383, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 384, 'train': 'train'}
# {'loss': '0.455', 'epoch': 384, 'train': 'eval'}
# {'loss': '0.307', 'epoch': 385, 'train': 'train'}
# {'loss': '0.393', 'epoch': 385, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 386, 'train': 'train'}
# {'loss': '0.413', 'epoch': 386, 'train': 'eval'}
# {'loss': '0.305', 'epoch': 387, 'train': 'train'}
# {'loss': '0.439', 'epoch': 387, 'train': 'eval'}
# {'loss': '0.317', 'epoch': 388, 'train': 'train'}
# {'loss': '0.442', 'epoch': 388, 'train': 'eval'}
# {'loss': '0.312', 'epoch': 389, 'train': 'train'}
# {'loss': '0.433', 'epoch': 389, 'train': 'eval'}
# {'loss': '0.309', 'epoch': 390, 'train': 'train'}
# {'loss': '0.332', 'epoch': 390, 'train': 'eval'}
# {'loss': '0.295', 'epoch': 391, 'train': 'train'}
# {'loss': '0.408', 'epoch': 391, 'train': 'eval'}
# {'loss': '0.302', 'epoch': 392, 'train': 'train'}
# {'loss': '0.406', 'epoch': 392, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 393, 'train': 'train'}
# {'loss': '0.604', 'epoch': 393, 'train': 'eval'}
# {'loss': '0.309', 'epoch': 394, 'train': 'train'}
# {'loss': '0.389', 'epoch': 394, 'train': 'eval'}
# {'loss': '0.320', 'epoch': 395, 'train': 'train'}
# {'loss': '0.476', 'epoch': 395, 'train': 'eval'}
# {'loss': '0.292', 'epoch': 396, 'train': 'train'}
# {'loss': '0.396', 'epoch': 396, 'train': 'eval'}
# {'loss': '0.296', 'epoch': 397, 'train': 'train'}
# {'loss': '0.496', 'epoch': 397, 'train': 'eval'}
# {'loss': '0.300', 'epoch': 398, 'train': 'train'}
# {'loss': '0.476', 'epoch': 398, 'train': 'eval'}
# {'loss': '0.305', 'epoch': 399, 'train': 'train'}
# {'loss': '0.436', 'epoch': 399, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 400, 'train': 'train'}
# {'loss': '0.482', 'epoch': 400, 'train': 'eval'}
# {'loss': '0.295', 'epoch': 401, 'train': 'train'}
# {'loss': '0.396', 'epoch': 401, 'train': 'eval'}
# {'loss': '0.308', 'epoch': 402, 'train': 'train'}
# {'loss': '0.324', 'epoch': 402, 'train': 'eval'}
# {'loss': '0.287', 'epoch': 403, 'train': 'train'}
# {'loss': '0.461', 'epoch': 403, 'train': 'eval'}
# {'loss': '0.303', 'epoch': 404, 'train': 'train'}
# {'loss': '0.439', 'epoch': 404, 'train': 'eval'}
# {'loss': '0.284', 'epoch': 405, 'train': 'train'}
# {'loss': '0.466', 'epoch': 405, 'train': 'eval'}
# {'loss': '0.300', 'epoch': 406, 'train': 'train'}
# {'loss': '0.846', 'epoch': 406, 'train': 'eval'}
# {'loss': '0.306', 'epoch': 407, 'train': 'train'}
# {'loss': '1.015', 'epoch': 407, 'train': 'eval'}
# {'loss': '0.301', 'epoch': 408, 'train': 'train'}
# {'loss': '0.974', 'epoch': 408, 'train': 'eval'}
# {'loss': '0.299', 'epoch': 409, 'train': 'train'}
# {'loss': '0.863', 'epoch': 409, 'train': 'eval'}
# {'loss': '0.305', 'epoch': 410, 'train': 'train'}
# {'loss': '0.433', 'epoch': 410, 'train': 'eval'}
# {'loss': '0.277', 'epoch': 411, 'train': 'train'}
# {'loss': '0.441', 'epoch': 411, 'train': 'eval'}
# {'loss': '0.303', 'epoch': 412, 'train': 'train'}
# {'loss': '0.572', 'epoch': 412, 'train': 'eval'}
# {'loss': '0.284', 'epoch': 413, 'train': 'train'}
# {'loss': '0.437', 'epoch': 413, 'train': 'eval'}
# {'loss': '0.293', 'epoch': 414, 'train': 'train'}
# {'loss': '0.428', 'epoch': 414, 'train': 'eval'}
# {'loss': '0.285', 'epoch': 415, 'train': 'train'}
# {'loss': '0.532', 'epoch': 415, 'train': 'eval'}
# {'loss': '0.298', 'epoch': 416, 'train': 'train'}
# {'loss': '0.538', 'epoch': 416, 'train': 'eval'}
# {'loss': '0.282', 'epoch': 417, 'train': 'train'}
# {'loss': '0.586', 'epoch': 417, 'train': 'eval'}
# {'loss': '0.275', 'epoch': 418, 'train': 'train'}
# {'loss': '0.472', 'epoch': 418, 'train': 'eval'}
# {'loss': '0.286', 'epoch': 419, 'train': 'train'}
# {'loss': '0.486', 'epoch': 419, 'train': 'eval'}
# {'loss': '0.285', 'epoch': 420, 'train': 'train'}
# {'loss': '0.500', 'epoch': 420, 'train': 'eval'}
# {'loss': '0.286', 'epoch': 421, 'train': 'train'}
# {'loss': '0.537', 'epoch': 421, 'train': 'eval'}
# {'loss': '0.294', 'epoch': 422, 'train': 'train'}
# {'loss': '0.616', 'epoch': 422, 'train': 'eval'}
# {'loss': '0.286', 'epoch': 423, 'train': 'train'}
# {'loss': '0.675', 'epoch': 423, 'train': 'eval'}
# {'loss': '0.280', 'epoch': 424, 'train': 'train'}
# {'loss': '0.464', 'epoch': 424, 'train': 'eval'}
# {'loss': '0.268', 'epoch': 425, 'train': 'train'}
# {'loss': '0.468', 'epoch': 425, 'train': 'eval'}
# {'loss': '0.290', 'epoch': 426, 'train': 'train'}
# {'loss': '0.512', 'epoch': 426, 'train': 'eval'}
# {'loss': '0.277', 'epoch': 427, 'train': 'train'}
# {'loss': '0.511', 'epoch': 427, 'train': 'eval'}
# {'loss': '0.298', 'epoch': 428, 'train': 'train'}
# {'loss': '0.531', 'epoch': 428, 'train': 'eval'}
# {'loss': '0.268', 'epoch': 429, 'train': 'train'}
# {'loss': '0.621', 'epoch': 429, 'train': 'eval'}
# {'loss': '0.285', 'epoch': 430, 'train': 'train'}
# {'loss': '0.689', 'epoch': 430, 'train': 'eval'}
# {'loss': '0.282', 'epoch': 431, 'train': 'train'}
# {'loss': '0.583', 'epoch': 431, 'train': 'eval'}
# {'loss': '0.279', 'epoch': 432, 'train': 'train'}
# {'loss': '0.432', 'epoch': 432, 'train': 'eval'}
# {'loss': '0.281', 'epoch': 433, 'train': 'train'}
# {'loss': '0.496', 'epoch': 433, 'train': 'eval'}
# {'loss': '0.279', 'epoch': 434, 'train': 'train'}
# {'loss': '0.427', 'epoch': 434, 'train': 'eval'}
# {'loss': '0.285', 'epoch': 435, 'train': 'train'}
# {'loss': '0.580', 'epoch': 435, 'train': 'eval'}
# {'loss': '0.293', 'epoch': 436, 'train': 'train'}
# {'loss': '0.500', 'epoch': 436, 'train': 'eval'}
# {'loss': '0.287', 'epoch': 437, 'train': 'train'}
# {'loss': '0.518', 'epoch': 437, 'train': 'eval'}
# {'loss': '0.276', 'epoch': 438, 'train': 'train'}
# {'loss': '0.509', 'epoch': 438, 'train': 'eval'}
# {'loss': '0.278', 'epoch': 439, 'train': 'train'}
# {'loss': '0.620', 'epoch': 439, 'train': 'eval'}
# {'loss': '0.273', 'epoch': 440, 'train': 'train'}
# {'loss': '0.707', 'epoch': 440, 'train': 'eval'}
# {'loss': '0.277', 'epoch': 441, 'train': 'train'}
# {'loss': '0.763', 'epoch': 441, 'train': 'eval'}
# {'loss': '0.255', 'epoch': 442, 'train': 'train'}
# {'loss': '0.707', 'epoch': 442, 'train': 'eval'}
# {'loss': '0.268', 'epoch': 443, 'train': 'train'}
# {'loss': '0.553', 'epoch': 443, 'train': 'eval'}
# {'loss': '0.260', 'epoch': 444, 'train': 'train'}
# {'loss': '0.499', 'epoch': 444, 'train': 'eval'}
# {'loss': '0.261', 'epoch': 445, 'train': 'train'}
# {'loss': '0.518', 'epoch': 445, 'train': 'eval'}
# {'loss': '0.257', 'epoch': 446, 'train': 'train'}
# {'loss': '0.510', 'epoch': 446, 'train': 'eval'}
# {'loss': '0.269', 'epoch': 447, 'train': 'train'}
# {'loss': '0.501', 'epoch': 447, 'train': 'eval'}
# {'loss': '0.276', 'epoch': 448, 'train': 'train'}
# {'loss': '0.524', 'epoch': 448, 'train': 'eval'}
# {'loss': '0.278', 'epoch': 449, 'train': 'train'}
# {'loss': '0.550', 'epoch': 449, 'train': 'eval'}
# {'loss': '0.271', 'epoch': 450, 'train': 'train'}
# {'loss': '0.609', 'epoch': 450, 'train': 'eval'}
# {'loss': '0.253', 'epoch': 451, 'train': 'train'}
# {'loss': '0.672', 'epoch': 451, 'train': 'eval'}
# {'loss': '0.262', 'epoch': 452, 'train': 'train'}
# {'loss': '0.611', 'epoch': 452, 'train': 'eval'}
# {'loss': '0.250', 'epoch': 453, 'train': 'train'}
# {'loss': '0.631', 'epoch': 453, 'train': 'eval'}
# {'loss': '0.269', 'epoch': 454, 'train': 'train'}
# {'loss': '0.732', 'epoch': 454, 'train': 'eval'}
# {'loss': '0.248', 'epoch': 455, 'train': 'train'}
# {'loss': '0.648', 'epoch': 455, 'train': 'eval'}
# {'loss': '0.255', 'epoch': 456, 'train': 'train'}
# {'loss': '0.527', 'epoch': 456, 'train': 'eval'}
# {'loss': '0.242', 'epoch': 457, 'train': 'train'}
# {'loss': '0.614', 'epoch': 457, 'train': 'eval'}
# {'loss': '0.248', 'epoch': 458, 'train': 'train'}
# {'loss': '0.397', 'epoch': 458, 'train': 'eval'}
# {'loss': '0.243', 'epoch': 459, 'train': 'train'}
# {'loss': '0.445', 'epoch': 459, 'train': 'eval'}
# {'loss': '0.246', 'epoch': 460, 'train': 'train'}
# {'loss': '0.554', 'epoch': 460, 'train': 'eval'}
# {'loss': '0.251', 'epoch': 461, 'train': 'train'}
# {'loss': '0.484', 'epoch': 461, 'train': 'eval'}
# {'loss': '0.236', 'epoch': 462, 'train': 'train'}
# {'loss': '0.493', 'epoch': 462, 'train': 'eval'}
# {'loss': '0.246', 'epoch': 463, 'train': 'train'}
# {'loss': '0.498', 'epoch': 463, 'train': 'eval'}
# {'loss': '0.242', 'epoch': 464, 'train': 'train'}
# {'loss': '0.537', 'epoch': 464, 'train': 'eval'}
# {'loss': '0.255', 'epoch': 465, 'train': 'train'}
# {'loss': '0.581', 'epoch': 465, 'train': 'eval'}
# {'loss': '0.230', 'epoch': 466, 'train': 'train'}
# {'loss': '0.492', 'epoch': 466, 'train': 'eval'}
# {'loss': '0.244', 'epoch': 467, 'train': 'train'}
# {'loss': '0.404', 'epoch': 467, 'train': 'eval'}
# ...
# {'loss': '0.040', 'epoch': 1359, 'train': 'train'}
# {'loss': '2.524', 'epoch': 1359, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1360, 'train': 'train'}
# {'loss': '2.470', 'epoch': 1360, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 1361, 'train': 'train'}
# {'loss': '3.056', 'epoch': 1361, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1362, 'train': 'train'}
# {'loss': '3.159', 'epoch': 1362, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 1363, 'train': 'train'}
# {'loss': '2.141', 'epoch': 1363, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1364, 'train': 'train'}
# {'loss': '2.378', 'epoch': 1364, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1365, 'train': 'train'}
# {'loss': '2.114', 'epoch': 1365, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1366, 'train': 'train'}
# {'loss': '2.186', 'epoch': 1366, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1367, 'train': 'train'}
# {'loss': '1.852', 'epoch': 1367, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1368, 'train': 'train'}
# {'loss': '3.199', 'epoch': 1368, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1369, 'train': 'train'}
# {'loss': '2.654', 'epoch': 1369, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 1370, 'train': 'train'}
# {'loss': '2.843', 'epoch': 1370, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1371, 'train': 'train'}
# {'loss': '2.171', 'epoch': 1371, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1372, 'train': 'train'}
# {'loss': '2.413', 'epoch': 1372, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1373, 'train': 'train'}
# {'loss': '1.648', 'epoch': 1373, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1374, 'train': 'train'}
# {'loss': '2.983', 'epoch': 1374, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1375, 'train': 'train'}
# {'loss': '2.977', 'epoch': 1375, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1376, 'train': 'train'}
# {'loss': '1.972', 'epoch': 1376, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1377, 'train': 'train'}
# {'loss': '2.711', 'epoch': 1377, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1378, 'train': 'train'}
# {'loss': '2.898', 'epoch': 1378, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1379, 'train': 'train'}
# {'loss': '3.250', 'epoch': 1379, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 1380, 'train': 'train'}
# {'loss': '2.168', 'epoch': 1380, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1381, 'train': 'train'}
# {'loss': '2.798', 'epoch': 1381, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1382, 'train': 'train'}
# {'loss': '2.175', 'epoch': 1382, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1383, 'train': 'train'}
# {'loss': '1.956', 'epoch': 1383, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1384, 'train': 'train'}
# {'loss': '2.858', 'epoch': 1384, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1385, 'train': 'train'}
# {'loss': '2.121', 'epoch': 1385, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1386, 'train': 'train'}
# {'loss': '2.517', 'epoch': 1386, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1387, 'train': 'train'}
# {'loss': '2.443', 'epoch': 1387, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1388, 'train': 'train'}
# {'loss': '2.420', 'epoch': 1388, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1389, 'train': 'train'}
# {'loss': '2.189', 'epoch': 1389, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1390, 'train': 'train'}
# {'loss': '2.830', 'epoch': 1390, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1391, 'train': 'train'}
# {'loss': '2.373', 'epoch': 1391, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1392, 'train': 'train'}
# {'loss': '3.651', 'epoch': 1392, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1393, 'train': 'train'}
# {'loss': '2.165', 'epoch': 1393, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1394, 'train': 'train'}
# {'loss': '2.344', 'epoch': 1394, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1395, 'train': 'train'}
# {'loss': '2.217', 'epoch': 1395, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1396, 'train': 'train'}
# {'loss': '2.782', 'epoch': 1396, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1397, 'train': 'train'}
# {'loss': '2.394', 'epoch': 1397, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1398, 'train': 'train'}
# {'loss': '2.997', 'epoch': 1398, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1399, 'train': 'train'}
# {'loss': '3.192', 'epoch': 1399, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1400, 'train': 'train'}
# {'loss': '2.027', 'epoch': 1400, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1401, 'train': 'train'}
# {'loss': '3.457', 'epoch': 1401, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1402, 'train': 'train'}
# {'loss': '2.285', 'epoch': 1402, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1403, 'train': 'train'}
# {'loss': '3.661', 'epoch': 1403, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1404, 'train': 'train'}
# {'loss': '2.287', 'epoch': 1404, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1405, 'train': 'train'}
# {'loss': '2.180', 'epoch': 1405, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1406, 'train': 'train'}
# {'loss': '2.190', 'epoch': 1406, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1407, 'train': 'train'}
# {'loss': '2.826', 'epoch': 1407, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1408, 'train': 'train'}
# {'loss': '2.276', 'epoch': 1408, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1409, 'train': 'train'}
# {'loss': '2.237', 'epoch': 1409, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1410, 'train': 'train'}
# {'loss': '2.992', 'epoch': 1410, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1411, 'train': 'train'}
# {'loss': '2.339', 'epoch': 1411, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1412, 'train': 'train'}
# {'loss': '2.771', 'epoch': 1412, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1413, 'train': 'train'}
# {'loss': '3.088', 'epoch': 1413, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1414, 'train': 'train'}
# {'loss': '2.601', 'epoch': 1414, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1415, 'train': 'train'}
# {'loss': '2.509', 'epoch': 1415, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1416, 'train': 'train'}
# {'loss': '2.823', 'epoch': 1416, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 1417, 'train': 'train'}
# {'loss': '2.239', 'epoch': 1417, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1418, 'train': 'train'}
# {'loss': '2.268', 'epoch': 1418, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1419, 'train': 'train'}
# {'loss': '2.302', 'epoch': 1419, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1420, 'train': 'train'}
# {'loss': '2.698', 'epoch': 1420, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1421, 'train': 'train'}
# {'loss': '2.463', 'epoch': 1421, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1422, 'train': 'train'}
# {'loss': '2.831', 'epoch': 1422, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1423, 'train': 'train'}
# {'loss': '1.919', 'epoch': 1423, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1424, 'train': 'train'}
# {'loss': '2.878', 'epoch': 1424, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1425, 'train': 'train'}
# {'loss': '2.857', 'epoch': 1425, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1426, 'train': 'train'}
# {'loss': '2.591', 'epoch': 1426, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 1427, 'train': 'train'}
# {'loss': '2.840', 'epoch': 1427, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1428, 'train': 'train'}
# {'loss': '2.632', 'epoch': 1428, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1429, 'train': 'train'}
# {'loss': '3.239', 'epoch': 1429, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1430, 'train': 'train'}
# {'loss': '2.638', 'epoch': 1430, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1431, 'train': 'train'}
# {'loss': '2.602', 'epoch': 1431, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1432, 'train': 'train'}
# {'loss': '1.534', 'epoch': 1432, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1433, 'train': 'train'}
# {'loss': '1.475', 'epoch': 1433, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1434, 'train': 'train'}
# {'loss': '2.406', 'epoch': 1434, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1435, 'train': 'train'}
# {'loss': '2.788', 'epoch': 1435, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1436, 'train': 'train'}
# {'loss': '2.323', 'epoch': 1436, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1437, 'train': 'train'}
# {'loss': '2.521', 'epoch': 1437, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1438, 'train': 'train'}
# {'loss': '2.197', 'epoch': 1438, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1439, 'train': 'train'}
# {'loss': '3.021', 'epoch': 1439, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1440, 'train': 'train'}
# {'loss': '2.529', 'epoch': 1440, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1441, 'train': 'train'}
# {'loss': '2.795', 'epoch': 1441, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1442, 'train': 'train'}
# {'loss': '2.131', 'epoch': 1442, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1443, 'train': 'train'}
# {'loss': '3.189', 'epoch': 1443, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1444, 'train': 'train'}
# {'loss': '1.803', 'epoch': 1444, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1445, 'train': 'train'}
# {'loss': '2.627', 'epoch': 1445, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1446, 'train': 'train'}
# {'loss': '2.035', 'epoch': 1446, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1447, 'train': 'train'}
# {'loss': '3.657', 'epoch': 1447, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1448, 'train': 'train'}
# {'loss': '1.799', 'epoch': 1448, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1449, 'train': 'train'}
# {'loss': '3.142', 'epoch': 1449, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1450, 'train': 'train'}
# {'loss': '2.485', 'epoch': 1450, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1451, 'train': 'train'}
# {'loss': '2.469', 'epoch': 1451, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1452, 'train': 'train'}
# {'loss': '2.632', 'epoch': 1452, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1453, 'train': 'train'}
# {'loss': '1.692', 'epoch': 1453, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1454, 'train': 'train'}
# {'loss': '2.309', 'epoch': 1454, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1455, 'train': 'train'}
# {'loss': '1.977', 'epoch': 1455, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1456, 'train': 'train'}
# {'loss': '2.119', 'epoch': 1456, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1457, 'train': 'train'}
# {'loss': '2.199', 'epoch': 1457, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 1458, 'train': 'train'}
# {'loss': '2.672', 'epoch': 1458, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1459, 'train': 'train'}
# {'loss': '2.188', 'epoch': 1459, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1460, 'train': 'train'}
# {'loss': '2.527', 'epoch': 1460, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1461, 'train': 'train'}
# {'loss': '3.042', 'epoch': 1461, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1462, 'train': 'train'}
# {'loss': '2.097', 'epoch': 1462, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1463, 'train': 'train'}
# {'loss': '2.131', 'epoch': 1463, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1464, 'train': 'train'}
# {'loss': '2.276', 'epoch': 1464, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1465, 'train': 'train'}
# {'loss': '2.239', 'epoch': 1465, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1466, 'train': 'train'}
# {'loss': '2.447', 'epoch': 1466, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1467, 'train': 'train'}
# {'loss': '1.341', 'epoch': 1467, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1468, 'train': 'train'}
# {'loss': '1.533', 'epoch': 1468, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 1469, 'train': 'train'}
# {'loss': '3.105', 'epoch': 1469, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1470, 'train': 'train'}
# {'loss': '2.836', 'epoch': 1470, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1471, 'train': 'train'}
# {'loss': '3.481', 'epoch': 1471, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1472, 'train': 'train'}
# {'loss': '3.032', 'epoch': 1472, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1473, 'train': 'train'}
# {'loss': '3.389', 'epoch': 1473, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1474, 'train': 'train'}
# {'loss': '2.314', 'epoch': 1474, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 1475, 'train': 'train'}
# {'loss': '2.192', 'epoch': 1475, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1476, 'train': 'train'}
# {'loss': '2.099', 'epoch': 1476, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1477, 'train': 'train'}
# {'loss': '1.346', 'epoch': 1477, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1478, 'train': 'train'}
# {'loss': '2.343', 'epoch': 1478, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1479, 'train': 'train'}
# {'loss': '2.545', 'epoch': 1479, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1480, 'train': 'train'}
# {'loss': '3.121', 'epoch': 1480, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1481, 'train': 'train'}
# {'loss': '2.227', 'epoch': 1481, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1482, 'train': 'train'}
# {'loss': '2.462', 'epoch': 1482, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 1483, 'train': 'train'}
# {'loss': '3.126', 'epoch': 1483, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1484, 'train': 'train'}
# {'loss': '2.841', 'epoch': 1484, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1485, 'train': 'train'}
# {'loss': '2.829', 'epoch': 1485, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1486, 'train': 'train'}
# {'loss': '2.038', 'epoch': 1486, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1487, 'train': 'train'}
# {'loss': '3.156', 'epoch': 1487, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1488, 'train': 'train'}
# {'loss': '2.849', 'epoch': 1488, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 1489, 'train': 'train'}
# {'loss': '2.728', 'epoch': 1489, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 1490, 'train': 'train'}
# {'loss': '3.627', 'epoch': 1490, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1491, 'train': 'train'}
# {'loss': '3.559', 'epoch': 1491, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1492, 'train': 'train'}
# {'loss': '2.465', 'epoch': 1492, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 1493, 'train': 'train'}
# {'loss': '3.211', 'epoch': 1493, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1494, 'train': 'train'}
# {'loss': '2.602', 'epoch': 1494, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 1495, 'train': 'train'}
# {'loss': '2.373', 'epoch': 1495, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1496, 'train': 'train'}
# {'loss': '2.919', 'epoch': 1496, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 1497, 'train': 'train'}
# {'loss': '2.965', 'epoch': 1497, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 1498, 'train': 'train'}
# {'loss': '2.066', 'epoch': 1498, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 1499, 'train': 'train'}
# {'loss': '2.714', 'epoch': 1499, 'train': 'eval'}
# VBox(children=(Label(value='728.963 MB of 728.963 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▂▂▂▂▁▁▁▁▂▁▁▁▁▂▂▂▁▂▃▃▃▂▄▃▂▃▄▃▄▅▄▄▅█▄▄▆▇▇█</td></tr><tr><td>train_loss</td><td>█▇▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▂▂▂▁▁▁▁▂▁▁▁▁▂▂▂▁▂▃▃▃▂▄▃▂▃▄▃▄▅▄▄▅█▄▄▆▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>2.71412</td></tr><tr><td>train_loss</td><td>0.037</td></tr><tr><td>val_loss</td><td>2.714</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fiery-silence-2</strong> at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/39d9jmw4' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/39d9jmw4</a><br/> View project at: <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a><br/>Synced 6 W&B file(s), 1500 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240819_084921-39d9jmw4/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
lr = 0.5e-4
epochs = 1500
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
#wandbcb =  WandBCB(config={'lr':lr, 'epochs':epochs, 'comments':'default unet logging test'})
cbs = [DeviceCB(), ProgressCB(plot=True), wandbcb, BatchSchedCB(sched), MixedPrecision()]
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/dumbAI/wandb/run-20240819_095214-n3jgw1l0</code>
# Syncing run <strong><a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/n3jgw1l0' target="_blank">solar-snow-3</a></strong> to <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip</a>
#  View run at <a href='https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/n3jgw1l0' target="_blank">https://wandb.ai/dumbdude-none/ddpm_goldfish_64x64_clip/runs/n3jgw1l0</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='222' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.80% [222/1500 09:09&lt;52:46]
#     </div>
#
#
#
#     <div>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00&lt;00:00 2.241]
#     </div>
# {'loss': '0.040', 'epoch': 0, 'train': 'train'}
# {'loss': '2.347', 'epoch': 0, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 1, 'train': 'train'}
# {'loss': '3.127', 'epoch': 1, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 2, 'train': 'train'}
# {'loss': '2.283', 'epoch': 2, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 3, 'train': 'train'}
# {'loss': '1.878', 'epoch': 3, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 4, 'train': 'train'}
# {'loss': '2.825', 'epoch': 4, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 5, 'train': 'train'}
# {'loss': '3.135', 'epoch': 5, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 6, 'train': 'train'}
# {'loss': '2.129', 'epoch': 6, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 7, 'train': 'train'}
# {'loss': '2.461', 'epoch': 7, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 8, 'train': 'train'}
# {'loss': '2.966', 'epoch': 8, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 9, 'train': 'train'}
# {'loss': '3.429', 'epoch': 9, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 10, 'train': 'train'}
# {'loss': '2.467', 'epoch': 10, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 11, 'train': 'train'}
# {'loss': '2.516', 'epoch': 11, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 12, 'train': 'train'}
# {'loss': '1.720', 'epoch': 12, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 13, 'train': 'train'}
# {'loss': '2.657', 'epoch': 13, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 14, 'train': 'train'}
# {'loss': '2.585', 'epoch': 14, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 15, 'train': 'train'}
# {'loss': '1.748', 'epoch': 15, 'train': 'eval'}
# {'loss': '0.033', 'epoch': 16, 'train': 'train'}
# {'loss': '2.190', 'epoch': 16, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 17, 'train': 'train'}
# {'loss': '2.214', 'epoch': 17, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 18, 'train': 'train'}
# {'loss': '2.483', 'epoch': 18, 'train': 'eval'}
# {'loss': '0.033', 'epoch': 19, 'train': 'train'}
# /home/course22p2/miniai/datasets.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig,ax = plt.subplots(nrows, ncols, figsize=figsize, **kwargs)
# {'loss': '2.720', 'epoch': 19, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 20, 'train': 'train'}
# {'loss': '2.821', 'epoch': 20, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 21, 'train': 'train'}
# {'loss': '3.816', 'epoch': 21, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 22, 'train': 'train'}
# {'loss': '1.662', 'epoch': 22, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 23, 'train': 'train'}
# {'loss': '2.408', 'epoch': 23, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 24, 'train': 'train'}
# {'loss': '2.014', 'epoch': 24, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 25, 'train': 'train'}
# {'loss': '1.571', 'epoch': 25, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 26, 'train': 'train'}
# {'loss': '2.375', 'epoch': 26, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 27, 'train': 'train'}
# {'loss': '1.987', 'epoch': 27, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 28, 'train': 'train'}
# {'loss': '2.294', 'epoch': 28, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 29, 'train': 'train'}
# {'loss': '2.486', 'epoch': 29, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 30, 'train': 'train'}
# {'loss': '2.386', 'epoch': 30, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 31, 'train': 'train'}
# {'loss': '2.282', 'epoch': 31, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 32, 'train': 'train'}
# {'loss': '2.190', 'epoch': 32, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 33, 'train': 'train'}
# {'loss': '2.434', 'epoch': 33, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 34, 'train': 'train'}
# {'loss': '2.282', 'epoch': 34, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 35, 'train': 'train'}
# {'loss': '2.527', 'epoch': 35, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 36, 'train': 'train'}
# {'loss': '2.753', 'epoch': 36, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 37, 'train': 'train'}
# {'loss': '1.869', 'epoch': 37, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 38, 'train': 'train'}
# {'loss': '3.056', 'epoch': 38, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 39, 'train': 'train'}
# {'loss': '1.776', 'epoch': 39, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 40, 'train': 'train'}
# {'loss': '3.003', 'epoch': 40, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 41, 'train': 'train'}
# {'loss': '3.081', 'epoch': 41, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 42, 'train': 'train'}
# {'loss': '3.011', 'epoch': 42, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 43, 'train': 'train'}
# {'loss': '2.923', 'epoch': 43, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 44, 'train': 'train'}
# {'loss': '2.298', 'epoch': 44, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 45, 'train': 'train'}
# {'loss': '2.723', 'epoch': 45, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 46, 'train': 'train'}
# {'loss': '3.528', 'epoch': 46, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 47, 'train': 'train'}
# {'loss': '3.500', 'epoch': 47, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 48, 'train': 'train'}
# {'loss': '2.246', 'epoch': 48, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 49, 'train': 'train'}
# {'loss': '2.643', 'epoch': 49, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 50, 'train': 'train'}
# {'loss': '2.917', 'epoch': 50, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 51, 'train': 'train'}
# {'loss': '2.069', 'epoch': 51, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 52, 'train': 'train'}
# {'loss': '2.353', 'epoch': 52, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 53, 'train': 'train'}
# {'loss': '1.931', 'epoch': 53, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 54, 'train': 'train'}
# {'loss': '2.426', 'epoch': 54, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 55, 'train': 'train'}
# {'loss': '2.426', 'epoch': 55, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 56, 'train': 'train'}
# {'loss': '2.042', 'epoch': 56, 'train': 'eval'}
# {'loss': '0.034', 'epoch': 57, 'train': 'train'}
# {'loss': '2.097', 'epoch': 57, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 58, 'train': 'train'}
# {'loss': '2.235', 'epoch': 58, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 59, 'train': 'train'}
# {'loss': '2.898', 'epoch': 59, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 60, 'train': 'train'}
# {'loss': '2.303', 'epoch': 60, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 61, 'train': 'train'}
# {'loss': '2.746', 'epoch': 61, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 62, 'train': 'train'}
# {'loss': '2.856', 'epoch': 62, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 63, 'train': 'train'}
# {'loss': '1.769', 'epoch': 63, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 64, 'train': 'train'}
# {'loss': '3.543', 'epoch': 64, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 65, 'train': 'train'}
# {'loss': '2.098', 'epoch': 65, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 66, 'train': 'train'}
# {'loss': '2.309', 'epoch': 66, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 67, 'train': 'train'}
# {'loss': '3.429', 'epoch': 67, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 68, 'train': 'train'}
# {'loss': '2.413', 'epoch': 68, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 69, 'train': 'train'}
# {'loss': '2.691', 'epoch': 69, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 70, 'train': 'train'}
# {'loss': '1.953', 'epoch': 70, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 71, 'train': 'train'}
# {'loss': '2.161', 'epoch': 71, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 72, 'train': 'train'}
# {'loss': '2.815', 'epoch': 72, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 73, 'train': 'train'}
# {'loss': '2.938', 'epoch': 73, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 74, 'train': 'train'}
# {'loss': '3.333', 'epoch': 74, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 75, 'train': 'train'}
# {'loss': '1.817', 'epoch': 75, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 76, 'train': 'train'}
# {'loss': '2.919', 'epoch': 76, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 77, 'train': 'train'}
# {'loss': '2.782', 'epoch': 77, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 78, 'train': 'train'}
# {'loss': '2.503', 'epoch': 78, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 79, 'train': 'train'}
# {'loss': '2.649', 'epoch': 79, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 80, 'train': 'train'}
# {'loss': '2.371', 'epoch': 80, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 81, 'train': 'train'}
# {'loss': '3.464', 'epoch': 81, 'train': 'eval'}
# {'loss': '0.033', 'epoch': 82, 'train': 'train'}
# {'loss': '3.145', 'epoch': 82, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 83, 'train': 'train'}
# {'loss': '2.592', 'epoch': 83, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 84, 'train': 'train'}
# {'loss': '1.645', 'epoch': 84, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 85, 'train': 'train'}
# {'loss': '1.844', 'epoch': 85, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 86, 'train': 'train'}
# {'loss': '2.650', 'epoch': 86, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 87, 'train': 'train'}
# {'loss': '1.518', 'epoch': 87, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 88, 'train': 'train'}
# {'loss': '3.116', 'epoch': 88, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 89, 'train': 'train'}
# {'loss': '2.817', 'epoch': 89, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 90, 'train': 'train'}
# {'loss': '2.087', 'epoch': 90, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 91, 'train': 'train'}
# {'loss': '2.296', 'epoch': 91, 'train': 'eval'}
# {'loss': '0.035', 'epoch': 92, 'train': 'train'}
# {'loss': '2.772', 'epoch': 92, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 93, 'train': 'train'}
# {'loss': '2.810', 'epoch': 93, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 94, 'train': 'train'}
# {'loss': '3.159', 'epoch': 94, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 95, 'train': 'train'}
# {'loss': '2.284', 'epoch': 95, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 96, 'train': 'train'}
# {'loss': '2.748', 'epoch': 96, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 97, 'train': 'train'}
# {'loss': '2.032', 'epoch': 97, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 98, 'train': 'train'}
# {'loss': '1.868', 'epoch': 98, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 99, 'train': 'train'}
# {'loss': '1.643', 'epoch': 99, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 100, 'train': 'train'}
# {'loss': '2.559', 'epoch': 100, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 101, 'train': 'train'}
# {'loss': '2.752', 'epoch': 101, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 102, 'train': 'train'}
# {'loss': '3.062', 'epoch': 102, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 103, 'train': 'train'}
# {'loss': '2.401', 'epoch': 103, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 104, 'train': 'train'}
# {'loss': '3.040', 'epoch': 104, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 105, 'train': 'train'}
# {'loss': '3.381', 'epoch': 105, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 106, 'train': 'train'}
# {'loss': '2.226', 'epoch': 106, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 107, 'train': 'train'}
# {'loss': '3.052', 'epoch': 107, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 108, 'train': 'train'}
# {'loss': '3.020', 'epoch': 108, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 109, 'train': 'train'}
# {'loss': '2.929', 'epoch': 109, 'train': 'eval'}
# {'loss': '0.036', 'epoch': 110, 'train': 'train'}
# {'loss': '2.573', 'epoch': 110, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 111, 'train': 'train'}
# {'loss': '2.809', 'epoch': 111, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 112, 'train': 'train'}
# {'loss': '2.222', 'epoch': 112, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 113, 'train': 'train'}
# {'loss': '4.356', 'epoch': 113, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 114, 'train': 'train'}
# {'loss': '3.076', 'epoch': 114, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 115, 'train': 'train'}
# {'loss': '3.677', 'epoch': 115, 'train': 'eval'}
# {'loss': '0.039', 'epoch': 116, 'train': 'train'}
# {'loss': '2.240', 'epoch': 116, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 117, 'train': 'train'}
# {'loss': '2.353', 'epoch': 117, 'train': 'eval'}
# {'loss': '0.038', 'epoch': 118, 'train': 'train'}
# {'loss': '2.217', 'epoch': 118, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 119, 'train': 'train'}
# {'loss': '2.523', 'epoch': 119, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 120, 'train': 'train'}
# {'loss': '1.784', 'epoch': 120, 'train': 'eval'}
# {'loss': '0.037', 'epoch': 121, 'train': 'train'}
# {'loss': '2.410', 'epoch': 121, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 122, 'train': 'train'}
# {'loss': '3.955', 'epoch': 122, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 123, 'train': 'train'}
# {'loss': '2.846', 'epoch': 123, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 124, 'train': 'train'}
# {'loss': '2.460', 'epoch': 124, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 125, 'train': 'train'}
# {'loss': '2.393', 'epoch': 125, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 126, 'train': 'train'}
# {'loss': '3.005', 'epoch': 126, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 127, 'train': 'train'}
# {'loss': '1.984', 'epoch': 127, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 128, 'train': 'train'}
# {'loss': '3.018', 'epoch': 128, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 129, 'train': 'train'}
# {'loss': '2.045', 'epoch': 129, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 130, 'train': 'train'}
# {'loss': '2.667', 'epoch': 130, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 131, 'train': 'train'}
# {'loss': '2.501', 'epoch': 131, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 132, 'train': 'train'}
# {'loss': '2.877', 'epoch': 132, 'train': 'eval'}
# {'loss': '0.040', 'epoch': 133, 'train': 'train'}
# {'loss': '3.289', 'epoch': 133, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 134, 'train': 'train'}
# {'loss': '2.784', 'epoch': 134, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 135, 'train': 'train'}
# {'loss': '1.851', 'epoch': 135, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 136, 'train': 'train'}
# {'loss': '2.008', 'epoch': 136, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 137, 'train': 'train'}
# {'loss': '3.212', 'epoch': 137, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 138, 'train': 'train'}
# {'loss': '3.006', 'epoch': 138, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 139, 'train': 'train'}
# {'loss': '3.610', 'epoch': 139, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 140, 'train': 'train'}
# {'loss': '2.528', 'epoch': 140, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 141, 'train': 'train'}
# {'loss': '2.459', 'epoch': 141, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 142, 'train': 'train'}
# {'loss': '2.302', 'epoch': 142, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 143, 'train': 'train'}
# {'loss': '1.930', 'epoch': 143, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 144, 'train': 'train'}
# {'loss': '2.495', 'epoch': 144, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 145, 'train': 'train'}
# {'loss': '1.859', 'epoch': 145, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 146, 'train': 'train'}
# {'loss': '2.627', 'epoch': 146, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 147, 'train': 'train'}
# {'loss': '1.529', 'epoch': 147, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 148, 'train': 'train'}
# {'loss': '2.152', 'epoch': 148, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 149, 'train': 'train'}
# {'loss': '2.524', 'epoch': 149, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 150, 'train': 'train'}
# {'loss': '2.685', 'epoch': 150, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 151, 'train': 'train'}
# {'loss': '2.979', 'epoch': 151, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 152, 'train': 'train'}
# {'loss': '1.988', 'epoch': 152, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 153, 'train': 'train'}
# {'loss': '2.997', 'epoch': 153, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 154, 'train': 'train'}
# {'loss': '3.092', 'epoch': 154, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 155, 'train': 'train'}
# {'loss': '2.486', 'epoch': 155, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 156, 'train': 'train'}
# {'loss': '1.207', 'epoch': 156, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 157, 'train': 'train'}
# {'loss': '1.695', 'epoch': 157, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 158, 'train': 'train'}
# {'loss': '2.361', 'epoch': 158, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 159, 'train': 'train'}
# {'loss': '2.284', 'epoch': 159, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 160, 'train': 'train'}
# {'loss': '2.117', 'epoch': 160, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 161, 'train': 'train'}
# {'loss': '2.070', 'epoch': 161, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 162, 'train': 'train'}
# {'loss': '1.721', 'epoch': 162, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 163, 'train': 'train'}
# {'loss': '2.532', 'epoch': 163, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 164, 'train': 'train'}
# {'loss': '1.630', 'epoch': 164, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 165, 'train': 'train'}
# {'loss': '2.159', 'epoch': 165, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 166, 'train': 'train'}
# {'loss': '2.096', 'epoch': 166, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 167, 'train': 'train'}
# {'loss': '3.415', 'epoch': 167, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 168, 'train': 'train'}
# {'loss': '3.164', 'epoch': 168, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 169, 'train': 'train'}
# {'loss': '2.298', 'epoch': 169, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 170, 'train': 'train'}
# {'loss': '3.130', 'epoch': 170, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 171, 'train': 'train'}
# {'loss': '2.937', 'epoch': 171, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 172, 'train': 'train'}
# {'loss': '2.438', 'epoch': 172, 'train': 'eval'}
# {'loss': '0.041', 'epoch': 173, 'train': 'train'}
# {'loss': '2.252', 'epoch': 173, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 174, 'train': 'train'}
# {'loss': '1.570', 'epoch': 174, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 175, 'train': 'train'}
# {'loss': '2.692', 'epoch': 175, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 176, 'train': 'train'}
# {'loss': '2.187', 'epoch': 176, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 177, 'train': 'train'}
# {'loss': '1.520', 'epoch': 177, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 178, 'train': 'train'}
# {'loss': '2.262', 'epoch': 178, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 179, 'train': 'train'}
# {'loss': '1.952', 'epoch': 179, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 180, 'train': 'train'}
# {'loss': '2.173', 'epoch': 180, 'train': 'eval'}
# {'loss': '0.059', 'epoch': 181, 'train': 'train'}
# {'loss': '1.631', 'epoch': 181, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 182, 'train': 'train'}
# {'loss': '3.021', 'epoch': 182, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 183, 'train': 'train'}
# {'loss': '2.228', 'epoch': 183, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 184, 'train': 'train'}
# {'loss': '2.318', 'epoch': 184, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 185, 'train': 'train'}
# {'loss': '2.080', 'epoch': 185, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 186, 'train': 'train'}
# {'loss': '1.607', 'epoch': 186, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 187, 'train': 'train'}
# {'loss': '2.279', 'epoch': 187, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 188, 'train': 'train'}
# {'loss': '2.836', 'epoch': 188, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 189, 'train': 'train'}
# {'loss': '1.494', 'epoch': 189, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 190, 'train': 'train'}
# {'loss': '2.484', 'epoch': 190, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 191, 'train': 'train'}
# {'loss': '2.344', 'epoch': 191, 'train': 'eval'}
# {'loss': '0.051', 'epoch': 192, 'train': 'train'}
# {'loss': '1.548', 'epoch': 192, 'train': 'eval'}
# {'loss': '0.042', 'epoch': 193, 'train': 'train'}
# {'loss': '3.283', 'epoch': 193, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 194, 'train': 'train'}
# {'loss': '2.981', 'epoch': 194, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 195, 'train': 'train'}
# {'loss': '2.777', 'epoch': 195, 'train': 'eval'}
# {'loss': '0.049', 'epoch': 196, 'train': 'train'}
# {'loss': '2.758', 'epoch': 196, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 197, 'train': 'train'}
# {'loss': '1.224', 'epoch': 197, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 198, 'train': 'train'}
# {'loss': '2.720', 'epoch': 198, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 199, 'train': 'train'}
# {'loss': '3.073', 'epoch': 199, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 200, 'train': 'train'}
# {'loss': '2.042', 'epoch': 200, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 201, 'train': 'train'}
# {'loss': '1.912', 'epoch': 201, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 202, 'train': 'train'}
# {'loss': '2.219', 'epoch': 202, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 203, 'train': 'train'}
# {'loss': '2.706', 'epoch': 203, 'train': 'eval'}
# {'loss': '0.043', 'epoch': 204, 'train': 'train'}
# {'loss': '2.240', 'epoch': 204, 'train': 'eval'}
# {'loss': '0.054', 'epoch': 205, 'train': 'train'}
# {'loss': '1.960', 'epoch': 205, 'train': 'eval'}
# {'loss': '0.046', 'epoch': 206, 'train': 'train'}
# {'loss': '2.008', 'epoch': 206, 'train': 'eval'}
# {'loss': '0.044', 'epoch': 207, 'train': 'train'}
# {'loss': '1.881', 'epoch': 207, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 208, 'train': 'train'}
# {'loss': '1.828', 'epoch': 208, 'train': 'eval'}
# {'loss': '0.055', 'epoch': 209, 'train': 'train'}
# {'loss': '2.650', 'epoch': 209, 'train': 'eval'}
# {'loss': '0.047', 'epoch': 210, 'train': 'train'}
# {'loss': '1.824', 'epoch': 210, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 211, 'train': 'train'}
# {'loss': '2.035', 'epoch': 211, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 212, 'train': 'train'}
# {'loss': '1.815', 'epoch': 212, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 213, 'train': 'train'}
# {'loss': '2.593', 'epoch': 213, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 214, 'train': 'train'}
# {'loss': '2.328', 'epoch': 214, 'train': 'eval'}
# {'loss': '0.052', 'epoch': 215, 'train': 'train'}
# {'loss': '2.321', 'epoch': 215, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 216, 'train': 'train'}
# {'loss': '1.775', 'epoch': 216, 'train': 'eval'}
# {'loss': '0.053', 'epoch': 217, 'train': 'train'}
# {'loss': '2.970', 'epoch': 217, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 218, 'train': 'train'}
# {'loss': '3.371', 'epoch': 218, 'train': 'eval'}
# {'loss': '0.048', 'epoch': 219, 'train': 'train'}
# {'loss': '2.050', 'epoch': 219, 'train': 'eval'}
# {'loss': '0.050', 'epoch': 220, 'train': 'train'}
# {'loss': '2.096', 'epoch': 220, 'train': 'eval'}
# {'loss': '0.045', 'epoch': 221, 'train': 'train'}
# {'loss': '2.273', 'epoch': 221, 'train': 'eval'}
# {'loss': '0.058', 'epoch': 222, 'train': 'train'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/fastai_pyenv/lib/python3.10/site-packages/PIL/ImageFile.py:547, in _save(im, fp, tile, bufsize)
#     546 try:
# --> 547     fh = fp.fileno()
#     548     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 learn.fit(epochs)
#
# File ~/course22p2/miniai/learner.py:178, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     176     if lr is None: lr = self.lr
#     177     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 178     self._fit(train, valid)
#     179 finally:
#     180     for cb in cbs: self.cbs.remove(cb)
#
# File ~/course22p2/miniai/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/course22p2/miniai/learner.py:167, in Learner._fit(self, train, valid)
#     165 for self.epoch in self.epochs:
#     166     if train: self.one_epoch(True)
# --> 167     if valid: torch.no_grad()(self.one_epoch)(False)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/course22p2/miniai/learner.py:161, in Learner.one_epoch(self, training)
#     159 self.model.train(training)
#     160 self.dl = self.dls.train if training else self.dls.valid
# --> 161 self._one_epoch()
#
# File ~/course22p2/miniai/learner.py:130, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     128     o.callback(f'before_{self.nm}')
#     129     f(o, *args, **kwargs)
# --> 130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#     132 finally: o.callback(f'cleanup_{self.nm}')
#
# File ~/course22p2/miniai/learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File ~/course22p2/miniai/learner.py:69, in MetricsCB.after_epoch(self, learn)
#      67 log['epoch'] = learn.epoch
#      68 log['train'] = 'train' if learn.model.training else 'eval'
# ---> 69 self._log(log)
#
# Cell In[53], line 18, in WandBCB._log(self, d)
#      16 else:
#      17     wandb.log({'val_'+m:float(d[m]) for m in self.all_metrics})
# ---> 18     wandb.log({'samples':self.sample_figure(learn)})
#      19 print(d)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:450, in _run_decorator._noop.<locals>.wrapper(self, *args, **kwargs)
#     447         wandb.termwarn(message, repeat=False)
#     448         return cls.Dummy()
# --> 450 return func(self, *args, **kwargs)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:401, in _run_decorator._noop_on_finish.<locals>.decorator_fn.<locals>.wrapper_fn(self, *args, **kwargs)
#     398 @functools.wraps(func)
#     399 def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     400     if not getattr(self, "_is_finished", False):
# --> 401         return func(self, *args, **kwargs)
#     403     default_message = (
#     404         f"Run ({self.id}) is finished. The call to `{func.__name__}` will be ignored. "
#     405         f"Please make sure that you are using an active run."
#     406     )
#     407     resolved_message = message or default_message
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:391, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     389         raise e
#     390     cls._is_attaching = ""
# --> 391 return func(self, *args, **kwargs)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:1924, in Run.log(self, data, step, commit, sync)
#    1917 if self._settings._shared and step is not None:
#    1918     wandb.termwarn(
#    1919         "In shared mode, the use of `wandb.log` with the step argument is not supported "
#    1920         f"and will be ignored. Please refer to {wburls.get('wandb_define_metric')} "
#    1921         "on how to customize your x-axis.",
#    1922         repeat=False,
#    1923     )
# -> 1924 self._log(data=data, step=step, commit=commit)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:1645, in Run._log(self, data, step, commit)
#    1642 if any(not isinstance(key, str) for key in data.keys()):
#    1643     raise ValueError("Key values passed to `wandb.log` must be strings.")
# -> 1645 self._partial_history_callback(data, step, commit)
#    1647 if step is not None:
#    1648     if os.getpid() != self._init_pid or self._is_attached:
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:1517, in Run._partial_history_callback(self, row, step, commit)
#    1514 if self._backend and self._backend.interface:
#    1515     not_using_tensorboard = len(wandb.patched["tensorboard"]) == 0
# -> 1517     self._backend.interface.publish_partial_history(
#    1518         row,
#    1519         user_step=self._step,
#    1520         step=step,
#    1521         flush=commit,
#    1522         publish_step=not_using_tensorboard,
#    1523     )
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:626, in InterfaceBase.publish_partial_history(self, data, user_step, step, flush, publish_step, run)
#     615 def publish_partial_history(
#     616     self,
#     617     data: dict,
#    (...)
#     622     run: Optional["Run"] = None,
#     623 ) -> None:
#     624     run = run or self._run
# --> 626     data = history_dict_to_json(run, data, step=user_step, ignore_copy_err=True)
#     627     data.pop("_step", None)
#     629     # add timestamp to the history request, if not already present
#     630     # the timestamp might come from the tensorboard log logic
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/data_types/utils.py:52, in history_dict_to_json(run, payload, step, ignore_copy_err)
#      48         payload[key] = history_dict_to_json(
#      49             run, val, step=step, ignore_copy_err=ignore_copy_err
#      50         )
#      51     else:
# ---> 52         payload[key] = val_to_json(
#      53             run, key, val, namespace=step, ignore_copy_err=ignore_copy_err
#      54         )
#      56 return payload
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/data_types/utils.py:86, in val_to_json(run, key, val, namespace, ignore_copy_err)
#      83     val = wandb.Table(dataframe=val)
#      85 elif util.is_matplotlib_typename(typename) or util.is_plotly_typename(typename):
# ---> 86     val = Plotly.make_plot_media(val)
#      87 elif isinstance(val, (list, tuple, range)) and all(
#      88     isinstance(v, WBValue) for v in val
#      89 ):
#      90     assert run
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/data_types/plotly.py:48, in Plotly.make_plot_media(cls, val)
#      46 if util.is_matplotlib_typename(util.get_full_typename(val)):
#      47     if util.matplotlib_contains_images(val):
# ---> 48         return Image(val)
#      49     val = util.matplotlib_to_plotly(val)
#      50 return cls(val)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/data_types/image.py:179, in Image.__init__(self, data_or_path, mode, caption, grouping, classes, boxes, masks, file_type)
#     177         self._initialize_from_path(data_or_path)
#     178 else:
# --> 179     self._initialize_from_data(data_or_path, mode, file_type)
#     180 self._set_initialization_meta(
#     181     grouping, caption, classes, boxes, masks, file_type
#     182 )
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/wandb/sdk/data_types/image.py:336, in Image._initialize_from_data(self, data, mode, file_type)
#     334 tmp_path = os.path.join(MEDIA_TMP.name, runid.generate_id() + "." + self.format)
#     335 assert self._image is not None
# --> 336 self._image.save(tmp_path, transparency=None)
#     337 self._set_file(tmp_path, is_tmp=True)
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/PIL/Image.py:2568, in Image.save(self, fp, format, **params)
#    2565     fp = cast(IO[bytes], fp)
#    2567 try:
# -> 2568     save_handler(self, fp, filename)
#    2569 except Exception:
#    2570     if open_fp:
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/PIL/PngImagePlugin.py:1431, in _save(im, fp, filename, chunk, save_all)
#    1427     im = _write_multiple_frames(
#    1428         im, fp, chunk, mode, rawmode, default_image, append_images
#    1429     )
#    1430 if im:
# -> 1431     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1433 if info:
#    1434     for info_chunk in info.chunks:
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/PIL/ImageFile.py:551, in _save(im, fp, tile, bufsize)
#     549     _encode_tile(im, fp, tile, bufsize, fh)
#     550 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 551     _encode_tile(im, fp, tile, bufsize, None, exc)
#     552 if hasattr(fp, "flush"):
#     553     fp.flush()
#
# File ~/fastai_pyenv/lib/python3.10/site-packages/PIL/ImageFile.py:570, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     567 if exc:
#     568     # compress to Python file-compatible object
#     569     while True:
# --> 570         errcode, data = encoder.encode(bufsize)[1:]
#     571         fp.write(data)
#     572         if errcode:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Sampling

# %%
from miniai.fid import ImageEval

# %% [markdown]
# cmodel = torch.load('models/data_aug2.pkl')
# del(cmodel[8])
# del(cmodel[7])
#
# @inplace
# def transformi(b): b[xl] = [F.pad(TF.to_tensor(o), (2,2,2,2))*2-1 for o in b[xl]]
#
# bs = 2048
# tds = dsd.with_transform(transformi)
# dls = DataLoaders.from_dd(tds, bs, num_workers=fc.defaults.cpus)
#
# dt = dls.train
# xb,yb = next(iter(dt))
#
# ie = ImageEval(cmodel, dls, cbs=[DeviceCB()])

# %%
sz = (64,4,8,8)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)

# %%
preds = sample(ddim_step, model, sz, steps=100, eta=1.)
s = to_cpu(vae.decode(preds[-1].cuda()*5))
s = s['sample'].clamp(0,1)
s.min(),s.max(),s.shape

# %%
show_images(s[:25].clamp(0,1), imsize=1.5)
